# %% [markdown]
# # Gemma 3 - 4B - Evaluation

# %% [markdown]
# | Parameter        | Value                        | Description                                                                                   |
# |------------------|------------------------------|-----------------------------------------------------------------------------------------------|
# | trainer_name     | GemmaTrainer                 | Trainer class name                                                                            |
# | model_id         | google/gemma-3-4b-it         | Model ID for Gemma, path to pretrained model (if any)                                         |
# | type             | LLM                          | Type of model (convML for conventional ML, convDL for deep learning, LLM for large language models) |
# | mode             | inference                    | Mode of operation                                                                             |
# | verbose          | 2                            | Verbosity level                                                                               |
# | quantization     | false                        | Whether to use quantization                                                                   |
# | tuning           | false                        | Whether to use prompt tuning                                                                  |
# | num_epochs       | 10                           | Number of epochs for training                                                                 |
# | max_new_tokens   | 300                          | Maximum number of new tokens to generate                                                      |
# | max_length       | 30000                        | Maximum length of input sequences                                                             |
# | do_sample        | true                         | Whether to sample new tokens (false = greedy decoding)                                        |
# | temperature      | 0.4                          | Temperature for sampling (0.0 = greedy sampling)                                              |

# %%
import pandas as pd
import numpy as np
import os
import sys
import matplotlib.pyplot as plt

sys.path.append(r"C:\Users\janbe\OneDrive\Dokumente\GitRepos\pulse")
from src.eval.llm_analyzer import LLMAnalyzer
from src.eval.pulse_score import PULSEScoreCalculator

# %%
model_id = "gemma3"
base_output_dir = (
    r"C:\Users\janbe\OneDrive\Dokumente\GitRepos\pulse\output_to_keep\results_benchmark"
)
model_output_dir = os.path.join(base_output_dir, "llms", model_id)
results_output_dir = os.path.join(base_output_dir, r"results_output")
results_output_jsons = os.path.join(results_output_dir, "jsons")
results_json_path = f"{model_id}_results.json"

prompt_approaches = os.listdir(model_output_dir)
for i, approach in enumerate(prompt_approaches, 1):
    print(f"{i}. {approach}")


best_prompt_approach = None
results_dict = {}
mdata_dict = {}
cost_df = pd.DataFrame()

for prompt_approach in prompt_approaches:
    if not os.path.isdir(os.path.join(model_output_dir, prompt_approach)):
        continue

    print("=" * 50)
    print(f"\nPrompting Approach {prompt_approach}\n")

    cat_files = LLMAnalyzer.categorize_files(
        [os.path.join(model_output_dir, prompt_approach)],
        verbose=False,
    )
    df_mdata = LLMAnalyzer.load_metadata(
        cat_files["metadata_files"], verbose=True
    )

    summary = LLMAnalyzer.print_approach_summary(
        df_mdata, input_token_cost=0, output_token_cost=0
    )

    # Filter for final prediction step if agent is used
    if "Step Name" in df_mdata.columns:
        df_mdata = df_mdata[df_mdata["Step Name"] == "final_prediction"].reset_index(
            drop=True
        )

    ps = PULSEScoreCalculator()
    pulse_score = ps.calculate_pulse_score_from_raw_data(
        df=df_mdata,
    )
    pulse_score["model_id"] = model_id
    pulse_score["prompting_id"] = prompt_approach
    pulse_score_temp = pulse_score["overall"]["overall_score"]
    results_dict[prompt_approach] = pulse_score
    mdata_dict[prompt_approach] = df_mdata
    cost_df[prompt_approach] = [
        summary["input_cost"].sum(),
        summary["output_cost"].sum(),
        summary["thinking_cost"].sum(),
        summary["total_cost"].sum(),
    ]

    cost_df.index = ["input_cost", "output_cost", "thinking_cost", "total_cost"]
    if best_prompt_approach is None or pulse_score_temp > best_prompt_approach[1]:

        best_prompt_approach = (prompt_approach, pulse_score_temp)

display(cost_df)
print(
    f"\nBest prompt approach: {best_prompt_approach[0]} with PULSE score: {best_prompt_approach[1]}"
)

# Save results as json. Uses pulse-result format
json_output_path = os.path.join(results_output_jsons, f"{model_id}_results.json")
final_json = LLMAnalyzer.save_results_dict_as_json(results_dict, json_output_path)
# Out:
# 1. clinical_workflow_agent_preprocessor
# 2. collaborative_reasoning_agent_preprocessor
# 3. hybrid_reasoning_agent_preprocessor
# 4. liu_2023_few_shot_preprocessor
# 5. sarvari_2024_aggregation_preprocessor
# 6. zhu_2024a_cot_preprocessor
# 7. zhu_2024b_one_shot_preprocessor
# 8. zhu_2024b_zero_shot_preprocessor
# 9. zhu_2024c_categorization_summary_agent_preprocessor
# ==================================================
#
# Prompting Approach clinical_workflow_agent_preprocessor
#
# Extracting metadata from files:
# Model Name: Gemma3, Task: aki, Dataset: eicu, Timestamp: 20250710_104626
# Model Name: Gemma3, Task: aki, Dataset: hirid, Timestamp: 20250710_104626
# Model Name: Gemma3, Task: aki, Dataset: miiv, Timestamp: 20250710_104626
# Model Name: Gemma3, Task: mortality, Dataset: eicu, Timestamp: 20250710_104626
# Model Name: Gemma3, Task: mortality, Dataset: hirid, Timestamp: 20250710_104626
# Model Name: Gemma3, Task: mortality, Dataset: miiv, Timestamp: 20250710_104626
# Model Name: Gemma3, Task: sepsis, Dataset: eicu, Timestamp: 20250713_075022
# Model Name: Gemma3, Task: sepsis, Dataset: hirid, Timestamp: 20250713_075022
# Model Name: Gemma3, Task: sepsis, Dataset: miiv, Timestamp: 20250713_075022
#
# =====Overall=====:
# Number of Samples: 6189
# Number of Requests: 36747
# Total Input Tokens: 35673216
# Total Output Tokens: 5950251
# Total Thinking Tokens: 0
# Average Thinking Tokens: 0.00
# Total Cost (USD): $0.00
# =================
# Preparing data for Gemma3 PULSE score calculation...
# Model Type: LLM
# ✓ No invalid predictions detected
# ✅ Data format is correct for PULSE calculation!
#
# Data distribution by task:
#
# AKI:
#   Total samples: 2950/2950
#   Positive labels: 693
#   Valid predictions: 2950
#   Positive predictions: 2392.0
#   Probability range: [0.050, 0.990]
#   Probability mean: 0.729
#   Probability std: 0.267
#   Probability median: 0.850
#
# MORTALITY:
#   Total samples: 300/300
#   Positive labels: 30
#   Valid predictions: 300
#   Positive predictions: 282.0
#   Probability range: [0.220, 0.980]
#   Probability mean: 0.793
#   Probability std: 0.132
#   Probability median: 0.850
#
# SEPSIS:
#   Total samples: 2939/2939
#   Positive labels: 145
#   Valid predictions: 2939
#   Positive predictions: 2929.0
#   Probability range: [0.150, 0.990]
#   Probability mean: 0.911
#   Probability std: 0.063
#   Probability median: 0.920
#
# Data types and unique values:
#   Target Label: int64, values: [0 1]
#   Predicted Diagnosis: object, values: ['not-aki' 'aki' 'mortality' 'not-mortality' 'sepsis' 'not-sepsis']
#
# Data source information:
#   • Predictions from explicit prediction column
#   • Tasks: aki, mortality, sepsis
#   • Datasets: eicu, hirid, miiv
#
# ✅ PULSE scores calculated successfully for Gemma3!
# PULSE SCORE DETAILED REPORT
# Model Type: LLM
# Weights: AUPRC=0.33, AUROC=0.33, MCC=0.34
#
# OVERALL SCORES
# --------------------------------------------------
#               Metric      Value
# 0      overall_score  43.499029
# 1        overall_aki  44.244010
# 2       overall_eicu  42.609232
# 3  overall_mortality  49.694361
# 4      overall_hirid  42.557236
# 5     overall_sepsis  36.558716
# 6       overall_miiv  45.330619
#
# TASK DATASET SCORES
# --------------------------------------------------
#                  pulse_score     auprc     auroc       mcc       ccf
# aki_eicu           45.373697  0.336911  0.550873  0.531078  0.958191
# aki_hirid          44.540383  0.269814  0.594985  0.521391  0.962709
# aki_miiv           42.817951  0.257331  0.549721  0.529176  0.959512
# mortality_eicu     49.612342  0.144203  0.802611  0.553026  0.991300
# mortality_hirid    42.557390  0.195534  0.564351  0.517667  0.997200
# mortality_miiv     56.913351  0.429763  0.750947  0.532471  0.997300
# sepsis_eicu        32.841657  0.040856  0.434118  0.505075  0.999847
# sepsis_hirid       40.573936  0.089274  0.615620  0.509188  1.000000
# sepsis_miiv        36.260556  0.020909  0.558052  0.505126  0.999465
# ==================================================
#
# Prompting Approach collaborative_reasoning_agent_preprocessor
#
# Extracting metadata from files:
# Model Name: Gemma3, Task: aki, Dataset: eicu, Timestamp: 20250715_075728
# Model Name: Gemma3, Task: aki, Dataset: hirid, Timestamp: 20250715_075728
# Model Name: Gemma3, Task: aki, Dataset: miiv, Timestamp: 20250715_075728
# Model Name: Gemma3, Task: mortality, Dataset: eicu, Timestamp: 20250715_075728
# Model Name: Gemma3, Task: mortality, Dataset: hirid, Timestamp: 20250715_075728
# Model Name: Gemma3, Task: mortality, Dataset: miiv, Timestamp: 20250715_075728
# Model Name: Gemma3, Task: sepsis, Dataset: eicu, Timestamp: 20250715_075728
# Model Name: Gemma3, Task: sepsis, Dataset: hirid, Timestamp: 20250715_075728
# Model Name: Gemma3, Task: sepsis, Dataset: miiv, Timestamp: 20250715_075728
#
# =====Overall=====:
# Number of Samples: 6189
# Number of Requests: 30945
# Total Input Tokens: 30532122
# Total Output Tokens: 5119966
# Total Thinking Tokens: 0
# Average Thinking Tokens: 0.00
# Total Cost (USD): $0.00
# =================
# Preparing data for Gemma3 PULSE score calculation...
# Model Type: LLM
# ✓ No invalid predictions detected
# ✅ Data format is correct for PULSE calculation!
#
# Data distribution by task:
#
# AKI:
#   Total samples: 2950/2950
#   Positive labels: 693
#   Valid predictions: 2950
#   Positive predictions: 2936.0
#   Probability range: [0.320, 0.980]
#   Probability mean: 0.903
#   Probability std: 0.070
#   Probability median: 0.920
#
# MORTALITY:
#   Total samples: 300/300
#   Positive labels: 30
#   Valid predictions: 300
#   Positive predictions: 300.0
#   Probability range: [0.750, 0.950]
#   Probability mean: 0.884
#   Probability std: 0.049
#   Probability median: 0.880
#
# SEPSIS:
#   Total samples: 2939/2939
#   Positive labels: 145
#   Valid predictions: 2939
#   Positive predictions: 2939.0
#   Probability range: [0.780, 0.980]
#   Probability mean: 0.936
#   Probability std: 0.024
#   Probability median: 0.950
#
# Data types and unique values:
#   Target Label: int64, values: [0 1]
#   Predicted Diagnosis: object, values: ['aki' 'not-aki' 'mortality' 'sepsis']
#
# Data source information:
#   • Predictions from explicit prediction column
#   • Tasks: aki, mortality, sepsis
#   • Datasets: eicu, hirid, miiv
#
# ✅ PULSE scores calculated successfully for Gemma3!
# PULSE SCORE DETAILED REPORT
# Model Type: LLM
# Weights: AUPRC=0.33, AUROC=0.33, MCC=0.34
#
# OVERALL SCORES
# --------------------------------------------------
#               Metric      Value
# 0      overall_score  45.775318
# 1        overall_aki  46.394583
# 2       overall_eicu  43.935946
# 3  overall_mortality  51.568838
# 4      overall_hirid  43.658711
# 5     overall_sepsis  39.362535
# 6       overall_miiv  49.731299
#
# TASK DATASET SCORES
# --------------------------------------------------
#                  pulse_score     auprc     auroc       mcc       ccf
# aki_eicu           46.986745  0.357033  0.537560  0.520655  0.994980
# aki_hirid          43.625604  0.289313  0.510779  0.507017  0.999633
# aki_miiv           48.571398  0.389576  0.570635  0.498694  0.998537
# mortality_eicu     49.201141  0.197758  0.778034  0.500000  1.000000
# mortality_hirid    46.781107  0.394797  0.507661  0.500000  1.000000
# mortality_miiv     58.724265  0.477440  0.786932  0.500000  1.000000
# sepsis_eicu        35.619951  0.038392  0.525849  0.500000  1.000000
# sepsis_hirid       40.569421  0.178755  0.535470  0.500000  1.000000
# sepsis_miiv        41.898233  0.277704  0.476788  0.500000  1.000000
# ==================================================
#
# Prompting Approach hybrid_reasoning_agent_preprocessor
#
# Extracting metadata from files:
# Model Name: Gemma3, Task: aki, Dataset: eicu, Timestamp: 20250707_104634
# Model Name: Gemma3, Task: aki, Dataset: hirid, Timestamp: 20250707_104634
# Model Name: Gemma3, Task: aki, Dataset: miiv, Timestamp: 20250707_104634
# Model Name: Gemma3, Task: mortality, Dataset: eicu, Timestamp: 20250707_104634
# Model Name: Gemma3, Task: mortality, Dataset: hirid, Timestamp: 20250707_104634
# Model Name: Gemma3, Task: mortality, Dataset: miiv, Timestamp: 20250707_104634
# Model Name: Gemma3, Task: sepsis, Dataset: eicu, Timestamp: 20250707_104634
# Model Name: Gemma3, Task: sepsis, Dataset: hirid, Timestamp: 20250707_104634
# Model Name: Gemma3, Task: sepsis, Dataset: miiv, Timestamp: 20250713_205353
#
# =====Overall=====:
# Number of Samples: 6189
# Number of Requests: 28129
# Total Input Tokens: 20185246
# Total Output Tokens: 4307445
# Total Thinking Tokens: 0
# Average Thinking Tokens: 0.00
# Total Cost (USD): $0.00
# =================
# Preparing data for Gemma3 PULSE score calculation...
# Model Type: LLM
# ✓ No invalid predictions detected
# ✅ Data format is correct for PULSE calculation!
#
# Data distribution by task:
#
# AKI:
#   Total samples: 2950/2950
#   Positive labels: 693
#   Valid predictions: 2950
#   Positive predictions: 2511.0
#   Probability range: [0.070, 0.980]
#   Probability mean: 0.747
#   Probability std: 0.228
#   Probability median: 0.850
#
# MORTALITY:
#   Total samples: 300/300
#   Positive labels: 30
#   Valid predictions: 300
#   Positive predictions: 209.0
#   Probability range: [0.050, 1.000]
#   Probability mean: 0.580
#   Probability std: 0.262
#   Probability median: 0.750
#
# SEPSIS:
#   Total samples: 2939/2939
#   Positive labels: 145
#   Valid predictions: 2939
#   Positive predictions: 988.0
#   Probability range: [0.120, 0.950]
#   Probability mean: 0.375
#   Probability std: 0.344
#   Probability median: 0.120
#
# Data types and unique values:
#   Target Label: int64, values: [0 1]
#   Predicted Diagnosis: object, values: ['not-aki' 'aki' 'mortality' 'not-mortality' 'not-sepsis' 'sepsis']
#
# Data source information:
#   • Predictions from explicit prediction column
#   • Tasks: aki, mortality, sepsis
#   • Datasets: eicu, hirid, miiv
#
# ✅ PULSE scores calculated successfully for Gemma3!
# PULSE SCORE DETAILED REPORT
# Model Type: LLM
# Weights: AUPRC=0.33, AUROC=0.33, MCC=0.34
#
# OVERALL SCORES
# --------------------------------------------------
#               Metric      Value
# 0      overall_score  49.323885
# 1        overall_aki  53.685937
# 2       overall_eicu  45.309264
# 3  overall_mortality  53.096464
# 4      overall_hirid  51.143984
# 5     overall_sepsis  41.189253
# 6       overall_miiv  51.518406
#
# TASK DATASET SCORES
# --------------------------------------------------
#                  pulse_score     auprc     auroc       mcc       ccf
# aki_eicu           53.294250  0.429336  0.623154  0.573748  0.982571
# aki_hirid          53.275795  0.373478  0.694074  0.566089  0.977963
# aki_miiv           54.487765  0.415823  0.670638  0.596273  0.970803
# mortality_eicu     44.160514  0.116589  0.695853  0.564270  0.960100
# mortality_hirid    54.839928  0.349020  0.732380  0.604194  0.975300
# mortality_miiv     60.288950  0.528068  0.750947  0.581387  0.972800
# sepsis_eicu        38.473029  0.064994  0.562279  0.525375  0.997673
# sepsis_hirid       45.316228  0.163607  0.641986  0.552240  0.999020
# sepsis_miiv        39.778503  0.066791  0.568725  0.553486  0.999697
# ==================================================
#
# Prompting Approach liu_2023_few_shot_preprocessor
#
# Extracting metadata from files:
# Model Name: Gemma3, Task: aki, Dataset: eicu, Timestamp: 20250701_095525
# Model Name: Gemma3, Task: aki, Dataset: hirid, Timestamp: 20250701_095525
# Model Name: Gemma3, Task: aki, Dataset: miiv, Timestamp: 20250701_095525
# Model Name: Gemma3, Task: mortality, Dataset: eicu, Timestamp: 20250701_095525
# Model Name: Gemma3, Task: mortality, Dataset: hirid, Timestamp: 20250701_095525
# Model Name: Gemma3, Task: mortality, Dataset: miiv, Timestamp: 20250701_095525
# Model Name: Gemma3, Task: sepsis, Dataset: eicu, Timestamp: 20250701_095525
# Model Name: Gemma3, Task: sepsis, Dataset: hirid, Timestamp: 20250701_095525
# Model Name: Gemma3, Task: sepsis, Dataset: miiv, Timestamp: 20250701_095525
#
# =====Overall=====:
# Number of Samples: 6189
# Number of Requests: 6189
# Total Input Tokens: 65614131
# Total Output Tokens: 658749
# Total Thinking Tokens: 0
# Average Thinking Tokens: 0.00
# Total Cost (USD): $0.00
# =================
# Preparing data for Gemma3 PULSE score calculation...
# Model Type: LLM
# ✓ No invalid predictions detected
# ✅ Data format is correct for PULSE calculation!
#
# Data distribution by task:
#
# AKI:
#   Total samples: 2950/2950
#   Positive labels: 693
#   Valid predictions: 2950
#   Positive predictions: 2947.0
#   Probability range: [0.080, 0.980]
#   Probability mean: 0.840
#   Probability std: 0.052
#   Probability median: 0.850
#
# MORTALITY:
#   Total samples: 300/300
#   Positive labels: 30
#   Valid predictions: 300
#   Positive predictions: 300.0
#   Probability range: [0.650, 0.950]
#   Probability mean: 0.909
#   Probability std: 0.065
#   Probability median: 0.950
#
# SEPSIS:
#   Total samples: 2939/2939
#   Positive labels: 145
#   Valid predictions: 2939
#   Positive predictions: 2837.0
#   Probability range: [0.320, 0.950]
#   Probability mean: 0.657
#   Probability std: 0.089
#   Probability median: 0.650
#
# Data types and unique values:
#   Target Label: int64, values: [0 1]
#   Predicted Diagnosis: object, values: ['not-aki' 'aki' 'mortality' 'not-mortality' 'not-sepsis' 'sepsis']
#
# Data source information:
#   • Predictions from explicit prediction column
#   • Tasks: aki, mortality, sepsis
#   • Datasets: eicu, hirid, miiv
#
# ✅ PULSE scores calculated successfully for Gemma3!
# PULSE SCORE DETAILED REPORT
# Model Type: LLM
# Weights: AUPRC=0.33, AUROC=0.33, MCC=0.34
#
# OVERALL SCORES
# --------------------------------------------------
#               Metric      Value
# 0      overall_score  33.385594
# 1        overall_aki  28.291796
# 2       overall_eicu  31.373749
# 3  overall_mortality  41.168589
# 4      overall_hirid  36.242085
# 5     overall_sepsis  30.696398
# 6       overall_miiv  32.540949
#
# TASK DATASET SCORES
# --------------------------------------------------
#                  pulse_score     auprc     auroc       mcc       ccf
# aki_eicu           29.257712  0.337343  0.466643  0.500000  0.672104
# aki_hirid          24.847639  0.153931  0.469444  0.487120  0.669145
# aki_miiv           30.770036  0.336357  0.488895  0.500000  0.695630
# mortality_eicu     32.643748  0.186194  0.325653  0.500000  0.963200
# mortality_hirid    51.678855  0.525609  0.582737  0.500000  0.964600
# mortality_miiv     39.183164  0.249395  0.422822  0.500000  1.000000
# sepsis_eicu        32.219787  0.125493  0.508814  0.485773  0.860378
# sepsis_hirid       32.199761  0.136051  0.493112  0.477068  0.870671
# sepsis_miiv        27.669646  0.012690  0.448187  0.505734  0.853899
# ==================================================
#
# Prompting Approach sarvari_2024_aggregation_preprocessor
#
# Extracting metadata from files:
# Model Name: Gemma3, Task: aki, Dataset: eicu, Timestamp: 20250703_100254
# Model Name: Gemma3, Task: aki, Dataset: hirid, Timestamp: 20250703_100254
# Model Name: Gemma3, Task: aki, Dataset: miiv, Timestamp: 20250703_100254
# Model Name: Gemma3, Task: mortality, Dataset: eicu, Timestamp: 20250703_100254
# Model Name: Gemma3, Task: mortality, Dataset: hirid, Timestamp: 20250703_100254
# Model Name: Gemma3, Task: mortality, Dataset: miiv, Timestamp: 20250703_100254
# Model Name: Gemma3, Task: sepsis, Dataset: eicu, Timestamp: 20250703_100254
# Model Name: Gemma3, Task: sepsis, Dataset: hirid, Timestamp: 20250703_100254
# Model Name: Gemma3, Task: sepsis, Dataset: miiv, Timestamp: 20250703_100254
#
# =====Overall=====:
# Number of Samples: 6189
# Number of Requests: 6189
# Total Input Tokens: 13727829
# Total Output Tokens: 718497
# Total Thinking Tokens: 0
# Average Thinking Tokens: 0.00
# Total Cost (USD): $0.00
# =================
# Preparing data for Gemma3 PULSE score calculation...
# Model Type: LLM
# ✓ No invalid predictions detected
# ✅ Data format is correct for PULSE calculation!
#
# Data distribution by task:
#
# AKI:
#   Total samples: 2950/2950
#   Positive labels: 693
#   Valid predictions: 2950
#   Positive predictions: 2950.0
#   Probability range: [0.650, 0.950]
#   Probability mean: 0.892
#   Probability std: 0.054
#   Probability median: 0.850
#
# MORTALITY:
#   Total samples: 300/300
#   Positive labels: 30
#   Valid predictions: 300
#   Positive predictions: 300.0
#   Probability range: [0.750, 0.850]
#   Probability mean: 0.850
#   Probability std: 0.006
#   Probability median: 0.850
#
# SEPSIS:
#   Total samples: 2939/2939
#   Positive labels: 145
#   Valid predictions: 2939
#   Positive predictions: 2935.0
#   Probability range: [0.150, 0.950]
#   Probability mean: 0.752
#   Probability std: 0.141
#   Probability median: 0.650
#
# Data types and unique values:
#   Target Label: int64, values: [0 1]
#   Predicted Diagnosis: object, values: ['not-aki' 'aki' 'mortality' 'sepsis' 'not-sepsis' 'not-diagnosis']
#
# Data source information:
#   • Predictions from explicit prediction column
#   • Tasks: aki, mortality, sepsis
#   • Datasets: eicu, hirid, miiv
#
# ✅ PULSE scores calculated successfully for Gemma3!
# PULSE SCORE DETAILED REPORT
# Model Type: LLM
# Weights: AUPRC=0.33, AUROC=0.33, MCC=0.34
#
# OVERALL SCORES
# --------------------------------------------------
#               Metric      Value
# 0      overall_score  40.770454
# 1        overall_aki  30.788193
# 2       overall_eicu  39.944467
# 3  overall_mortality  51.719167
# 4      overall_hirid  42.988007
# 5     overall_sepsis  39.804002
# 6       overall_miiv  39.378887
#
# TASK DATASET SCORES
# --------------------------------------------------
#                  pulse_score     auprc     auroc       mcc       ccf
# aki_eicu           31.810531  0.472759  0.492552  0.500000  0.651118
# aki_hirid          29.899696  0.232683  0.486890  0.500000  0.733809
# aki_miiv           30.654351  0.381376  0.461352  0.500000  0.684096
# mortality_eicu     51.155000  0.535000  0.500000  0.500000  1.000000
# mortality_hirid    51.815000  0.555000  0.500000  0.500000  1.000000
# mortality_miiv     52.187500  0.560606  0.505682  0.500000  1.000000
# sepsis_eicu        36.867870  0.205375  0.534708  0.505075  0.886347
# sepsis_hirid       47.249326  0.418490  0.633967  0.500000  0.913364
# sepsis_miiv        35.294810  0.163842  0.523523  0.503621  0.886667
# ==================================================
#
# Prompting Approach zhu_2024a_cot_preprocessor
#
# Extracting metadata from files:
# Model Name: Gemma3, Task: aki, Dataset: eicu, Timestamp: 20250708_092150
# Model Name: Gemma3, Task: aki, Dataset: hirid, Timestamp: 20250708_092150
# Model Name: Gemma3, Task: aki, Dataset: miiv, Timestamp: 20250708_092150
# Model Name: Gemma3, Task: mortality, Dataset: eicu, Timestamp: 20250708_092150
# Model Name: Gemma3, Task: mortality, Dataset: hirid, Timestamp: 20250708_092150
# Model Name: Gemma3, Task: mortality, Dataset: miiv, Timestamp: 20250708_092150
# Model Name: Gemma3, Task: sepsis, Dataset: eicu, Timestamp: 20250708_092150
# Model Name: Gemma3, Task: sepsis, Dataset: hirid, Timestamp: 20250708_092150
# Model Name: Gemma3, Task: sepsis, Dataset: miiv, Timestamp: 20250712_231001
#
# =====Overall=====:
# Number of Samples: 6189
# Number of Requests: 6189
# Total Input Tokens: 29923268
# Total Output Tokens: 947749
# Total Thinking Tokens: 0
# Average Thinking Tokens: 0.00
# Total Cost (USD): $0.00
# =================
# Preparing data for Gemma3 PULSE score calculation...
# Model Type: LLM
# ✓ No invalid predictions detected
# ✅ Data format is correct for PULSE calculation!
#
# Data distribution by task:
#
# AKI:
#   Total samples: 2950/2950
#   Positive labels: 693
#   Valid predictions: 2950
#   Positive predictions: 2948.0
#   Probability range: [0.320, 0.950]
#   Probability mean: 0.815
#   Probability std: 0.053
#   Probability median: 0.780
#
# MORTALITY:
#   Total samples: 300/300
#   Positive labels: 30
#   Valid predictions: 300
#   Positive predictions: 300.0
#   Probability range: [0.750, 0.780]
#   Probability mean: 0.766
#   Probability std: 0.015
#   Probability median: 0.780
#
# SEPSIS:
#   Total samples: 2939/2939
#   Positive labels: 145
#   Valid predictions: 2939
#   Positive predictions: 2939.0
#   Probability range: [0.780, 0.950]
#   Probability mean: 0.876
#   Probability std: 0.026
#   Probability median: 0.880
#
# Data types and unique values:
#   Target Label: int64, values: [0 1]
#   Predicted Diagnosis: object, values: ['aki' 'not-aki' 'mortality' 'sepsis']
#
# Data source information:
#   • Predictions from explicit prediction column
#   • Tasks: aki, mortality, sepsis
#   • Datasets: eicu, hirid, miiv
#
# ✅ PULSE scores calculated successfully for Gemma3!
# PULSE SCORE DETAILED REPORT
# Model Type: LLM
# Weights: AUPRC=0.33, AUROC=0.33, MCC=0.34
#
# OVERALL SCORES
# --------------------------------------------------
#               Metric      Value
# 0      overall_score  41.630809
# 1        overall_aki  41.040587
# 2       overall_eicu  40.714591
# 3  overall_mortality  47.218802
# 4      overall_hirid  41.425723
# 5     overall_sepsis  36.633037
# 6       overall_miiv  42.752112
#
# TASK DATASET SCORES
# --------------------------------------------------
#                  pulse_score     auprc     auroc       mcc  ccf
# aki_eicu           39.964165  0.293871  0.436701  0.466332  1.0
# aki_hirid          36.688648  0.158250  0.438375  0.500000  1.0
# aki_miiv           46.468946  0.320009  0.572989  0.500000  1.0
# mortality_eicu     45.807551  0.339930  0.533026  0.500000  1.0
# mortality_hirid    48.997679  0.376675  0.592952  0.500000  1.0
# mortality_miiv     46.851176  0.412157  0.492424  0.500000  1.0
# sepsis_eicu        36.372056  0.062859  0.524173  0.500000  1.0
# sepsis_hirid       38.590841  0.132742  0.521526  0.500000  1.0
# sepsis_miiv        34.936214  0.013470  0.530052  0.500000  1.0
# ==================================================
#
# Prompting Approach zhu_2024b_one_shot_preprocessor
#
# Extracting metadata from files:
# Model Name: Gemma3, Task: aki, Dataset: eicu, Timestamp: 20250701_100532
# Model Name: Gemma3, Task: aki, Dataset: hirid, Timestamp: 20250701_100532
# Model Name: Gemma3, Task: aki, Dataset: miiv, Timestamp: 20250701_100532
# Model Name: Gemma3, Task: mortality, Dataset: eicu, Timestamp: 20250701_100532
# Model Name: Gemma3, Task: mortality, Dataset: hirid, Timestamp: 20250701_100532
# Model Name: Gemma3, Task: mortality, Dataset: miiv, Timestamp: 20250701_100532
# Model Name: Gemma3, Task: sepsis, Dataset: eicu, Timestamp: 20250701_100532
# Model Name: Gemma3, Task: sepsis, Dataset: hirid, Timestamp: 20250701_100532
# Model Name: Gemma3, Task: sepsis, Dataset: miiv, Timestamp: 20250701_100532
#
# =====Overall=====:
# Number of Samples: 6189
# Number of Requests: 6189
# Total Input Tokens: 43545640
# Total Output Tokens: 674420
# Total Thinking Tokens: 0
# Average Thinking Tokens: 0.00
# Total Cost (USD): $0.00
# =================
# Preparing data for Gemma3 PULSE score calculation...
# Model Type: LLM
# ✓ No invalid predictions detected
# ✅ Data format is correct for PULSE calculation!
#
# Data distribution by task:
#
# AKI:
#   Total samples: 2950/2950
#   Positive labels: 693
#   Valid predictions: 2950
#   Positive predictions: 2941.0
#   Probability range: [0.320, 0.950]
#   Probability mean: 0.717
#   Probability std: 0.066
#   Probability median: 0.750
#
# MORTALITY:
#   Total samples: 300/300
#   Positive labels: 30
#   Valid predictions: 300
#   Positive predictions: 300.0
#   Probability range: [0.650, 0.950]
#   Probability mean: 0.866
#   Probability std: 0.067
#   Probability median: 0.850
#
# SEPSIS:
#   Total samples: 2939/2939
#   Positive labels: 145
#   Valid predictions: 2939
#   Positive predictions: 2939.0
#   Probability range: [0.650, 0.950]
#   Probability mean: 0.652
#   Probability std: 0.024
#   Probability median: 0.650
#
# Data types and unique values:
#   Target Label: int64, values: [0 1]
#   Predicted Diagnosis: object, values: ['not-aki' 'aki' 'mortality' 'not-mortality' 'not-sepsis' 'sepsis']
#
# Data source information:
#   • Predictions from explicit prediction column
#   • Tasks: aki, mortality, sepsis
#   • Datasets: eicu, hirid, miiv
#
# ✅ PULSE scores calculated successfully for Gemma3!
# PULSE SCORE DETAILED REPORT
# Model Type: LLM
# Weights: AUPRC=0.33, AUROC=0.33, MCC=0.34
#
# OVERALL SCORES
# --------------------------------------------------
#               Metric      Value
# 0      overall_score  34.469151
# 1        overall_aki  30.841096
# 2       overall_eicu  29.449310
# 3  overall_mortality  42.499352
# 4      overall_hirid  38.618057
# 5     overall_sepsis  30.067006
# 6       overall_miiv  35.340087
#
# TASK DATASET SCORES
# --------------------------------------------------
#                  pulse_score     auprc     auroc       mcc       ccf
# aki_eicu           30.440378  0.257280  0.445795  0.500000  0.757195
# aki_hirid          30.099592  0.138860  0.443801  0.506632  0.825703
# aki_miiv           31.983318  0.253298  0.471760  0.500000  0.781474
# mortality_eicu     29.430230  0.038056  0.358679  0.500000  0.978000
# mortality_hirid    52.622827  0.462195  0.631767  0.500000  0.991000
# mortality_miiv     45.445000  0.297576  0.564394  0.500000  1.000000
# sepsis_eicu        28.477322  0.023980  0.476420  0.500000  0.849735
# sepsis_hirid       33.131753  0.155194  0.509762  0.500000  0.850764
# sepsis_miiv        28.591944  0.012626  0.491192  0.500000  0.850293
# ==================================================
#
# Prompting Approach zhu_2024b_zero_shot_preprocessor
#
# Extracting metadata from files:
# Model Name: Gemma3, Task: aki, Dataset: eicu, Timestamp: 20250703_202636
# Model Name: Gemma3, Task: aki, Dataset: hirid, Timestamp: 20250703_202636
# Model Name: Gemma3, Task: aki, Dataset: miiv, Timestamp: 20250703_202636
# Model Name: Gemma3, Task: mortality, Dataset: eicu, Timestamp: 20250703_202636
# Model Name: Gemma3, Task: mortality, Dataset: hirid, Timestamp: 20250703_202636
# Model Name: Gemma3, Task: mortality, Dataset: miiv, Timestamp: 20250703_202636
# Model Name: Gemma3, Task: sepsis, Dataset: eicu, Timestamp: 20250703_202636
# Model Name: Gemma3, Task: sepsis, Dataset: hirid, Timestamp: 20250703_202636
# Model Name: Gemma3, Task: sepsis, Dataset: miiv, Timestamp: 20250703_202636
#
# =====Overall=====:
# Number of Samples: 6189
# Number of Requests: 6189
# Total Input Tokens: 26545274
# Total Output Tokens: 890462
# Total Thinking Tokens: 0
# Average Thinking Tokens: 0.00
# Total Cost (USD): $0.00
# =================
# Preparing data for Gemma3 PULSE score calculation...
# Model Type: LLM
# ✓ No invalid predictions detected
# ✅ Data format is correct for PULSE calculation!
#
# Data distribution by task:
#
# AKI:
#   Total samples: 2950/2950
#   Positive labels: 693
#   Valid predictions: 2950
#   Positive predictions: 2878.0
#   Probability range: [0.150, 0.950]
#   Probability mean: 0.930
#   Probability std: 0.111
#   Probability median: 0.950
#
# MORTALITY:
#   Total samples: 300/300
#   Positive labels: 30
#   Valid predictions: 300
#   Positive predictions: 300.0
#   Probability range: [0.650, 0.950]
#   Probability mean: 0.855
#   Probability std: 0.018
#   Probability median: 0.850
#
# SEPSIS:
#   Total samples: 2939/2939
#   Positive labels: 145
#   Valid predictions: 2939
#   Positive predictions: 2885.0
#   Probability range: [0.150, 0.950]
#   Probability mean: 0.937
#   Probability std: 0.092
#   Probability median: 0.950
#
# Data types and unique values:
#   Target Label: int64, values: [0 1]
#   Predicted Diagnosis: object, values: ['aki' 'not-aki' 'mortality' 'not-mortality' 'sepsis' 'not-sepsis'
#  'not-diagnosis']
#
# Data source information:
#   • Predictions from explicit prediction column
#   • Tasks: aki, mortality, sepsis
#   • Datasets: eicu, hirid, miiv
#
# ✅ PULSE scores calculated successfully for Gemma3!
# PULSE SCORE DETAILED REPORT
# Model Type: LLM
# Weights: AUPRC=0.33, AUROC=0.33, MCC=0.34
#
# OVERALL SCORES
# --------------------------------------------------
#               Metric      Value
# 0      overall_score  48.893086
# 1        overall_aki  53.285075
# 2       overall_eicu  45.408399
# 3  overall_mortality  41.998780
# 4      overall_hirid  50.056502
# 5     overall_sepsis  51.395402
# 6       overall_miiv  51.214356
#
# TASK DATASET SCORES
# --------------------------------------------------
#                  pulse_score     auprc     auroc       mcc       ccf
# aki_eicu           54.331551  0.627211  0.511570  0.493431  0.999543
# aki_hirid          52.483153  0.573682  0.504528  0.497125  1.000000
# aki_miiv           53.040521  0.564879  0.510165  0.516590  1.000000
# mortality_eicu     30.892785  0.035303  0.387097  0.500000  0.998500
# mortality_hirid    45.607508  0.302032  0.564862  0.500000  1.000000
# mortality_miiv     49.496048  0.376774  0.607955  0.500000  1.000000
# sepsis_eicu        51.000860  0.524029  0.501072  0.505075  1.000000
# sepsis_hirid       52.078846  0.532240  0.512521  0.517697  1.000000
# sepsis_miiv        51.106499  0.512913  0.511399  0.510315  0.999091
# ==================================================
#
# Prompting Approach zhu_2024c_categorization_summary_agent_preprocessor
#
# Extracting metadata from files:
# Model Name: Gemma3, Task: aki, Dataset: eicu, Timestamp: 20250714_111531
# Model Name: Gemma3, Task: aki, Dataset: hirid, Timestamp: 20250721_105730
# Model Name: Gemma3, Task: aki, Dataset: miiv, Timestamp: 20250714_111531
# Model Name: Gemma3, Task: mortality, Dataset: eicu, Timestamp: 20250714_111531
# Model Name: Gemma3, Task: mortality, Dataset: hirid, Timestamp: 20250714_111531
# Model Name: Gemma3, Task: mortality, Dataset: miiv, Timestamp: 20250714_111531
# Model Name: Gemma3, Task: sepsis, Dataset: eicu, Timestamp: 20250714_111531
# Model Name: Gemma3, Task: sepsis, Dataset: hirid, Timestamp: 20250714_111531
# Model Name: Gemma3, Task: sepsis, Dataset: miiv, Timestamp: 20250714_111531
#
# =====Overall=====:
# Number of Samples: 6189
# Number of Requests: 12378
# Total Input Tokens: 6230048
# Total Output Tokens: 1691859
# Total Thinking Tokens: 0
# Average Thinking Tokens: 0.00
# Total Cost (USD): $0.00
# =================
# Preparing data for Gemma3 PULSE score calculation...
# Model Type: LLM
# ✓ No invalid predictions detected
# ✅ Data format is correct for PULSE calculation!
#
# Data distribution by task:
#
# AKI:
#   Total samples: 2950/2950
#   Positive labels: 693
#   Valid predictions: 2950
#   Positive predictions: 794.0
#   Probability range: [0.150, 0.950]
#   Probability mean: 0.414
#   Probability std: 0.193
#   Probability median: 0.320
#
# MORTALITY:
#   Total samples: 300/300
#   Positive labels: 30
#   Valid predictions: 300
#   Positive predictions: 97.0
#   Probability range: [0.350, 0.850]
#   Probability mean: 0.505
#   Probability std: 0.160
#   Probability median: 0.450
#
# SEPSIS:
#   Total samples: 2939/2939
#   Positive labels: 145
#   Valid predictions: 2939
#   Positive predictions: 2257.0
#   Probability range: [0.350, 0.950]
#   Probability mean: 0.629
#   Probability std: 0.131
#   Probability median: 0.650
#
# Data types and unique values:
#   Target Label: int64, values: [0 1]
#   Predicted Diagnosis: object, values: ['not-aki' 'aki' 'not-diagnosis' 'diagnosis' 'mortality' 'not-mortality'
#  'sepsis' 'not-sepsis']
#
# Data source information:
#   • Predictions from explicit prediction column
#   • Tasks: aki, mortality, sepsis
#   • Datasets: eicu, hirid, miiv
#
# ✅ PULSE scores calculated successfully for Gemma3!
# PULSE SCORE DETAILED REPORT
# Model Type: LLM
# Weights: AUPRC=0.33, AUROC=0.33, MCC=0.34
#
# OVERALL SCORES
# --------------------------------------------------
#               Metric      Value
# 0      overall_score  39.113439
# 1        overall_aki  43.820754
# 2       overall_eicu  35.738203
# 3  overall_mortality  36.681212
# 4      overall_hirid  40.033350
# 5     overall_sepsis  36.838351
# 6       overall_miiv  41.568764
#
# TASK DATASET SCORES
# --------------------------------------------------
#                  pulse_score     auprc     auroc       mcc       ccf
# aki_eicu           46.818392  0.364811  0.519950  0.529446  0.991951
# aki_hirid          41.183762  0.184809  0.528535  0.533606  0.988024
# aki_miiv           43.460108  0.277768  0.515825  0.519865  0.990793
# mortality_eicu     26.561613  0.043077  0.327957  0.425029  0.995000
# mortality_hirid    42.009500  0.197538  0.553626  0.523030  0.986800
# mortality_miiv     41.472524  0.260179  0.493845  0.495791  0.993600
# sepsis_eicu        33.834604  0.048135  0.520946  0.496576  0.948724
# sepsis_hirid       36.906789  0.126638  0.539666  0.526112  0.925542
# sepsis_miiv        39.773661  0.040062  0.672560  0.540310  0.949545
#                clinical_workflow_agent_preprocessor  \
# input_cost                                      0.0
# output_cost                                     0.0
# thinking_cost                                   0.0
# total_cost                                      0.0
#
#                collaborative_reasoning_agent_preprocessor  \
# input_cost                                            0.0
# output_cost                                           0.0
# thinking_cost                                         0.0
# total_cost                                            0.0
#
#                hybrid_reasoning_agent_preprocessor  \
# input_cost                                     0.0
# output_cost                                    0.0
# thinking_cost                                  0.0
# total_cost                                     0.0
#
#                liu_2023_few_shot_preprocessor  \
# input_cost                                0.0
# output_cost                               0.0
# thinking_cost                             0.0
# total_cost                                0.0
#
#                sarvari_2024_aggregation_preprocessor  \
# input_cost                                       0.0
# output_cost                                      0.0
# thinking_cost                                    0.0
# total_cost                                       0.0
#
#                zhu_2024a_cot_preprocessor  zhu_2024b_one_shot_preprocessor  \
# input_cost                            0.0                              0.0
# output_cost                           0.0                              0.0
# thinking_cost                         0.0                              0.0
# total_cost                            0.0                              0.0
#
#                zhu_2024b_zero_shot_preprocessor  \
# input_cost                                  0.0
# output_cost                                 0.0
# thinking_cost                               0.0
# total_cost                                  0.0
#
#                zhu_2024c_categorization_summary_agent_preprocessor
# input_cost                                                   0.0
# output_cost                                                  0.0
# thinking_cost                                                0.0
# total_cost                                                   0.0
# Best prompt approach: hybrid_reasoning_agent_preprocessor with PULSE score: 49.3238846079404
# Saved 81 result entries to C:\Users\janbe\OneDrive\Dokumente\GitRepos\pulse\output_to_keep\results_benchmark\results_output\jsons\gemma3_results.json

# %% [markdown]
# ## Model Metrics

# %%
df_results = LLMAnalyzer.load_metrics_from_prompt_approaches(model_output_dir, prompt_approaches)

# %%
LLMAnalyzer.plot_metrics(
    df_results, group=["prompting_id"], title_prefix="Gemma 3 4B - ",
)
# Out:
# C:\Users\janbe\OneDrive\Dokumente\GitRepos\pulse\src\eval\llm_analyzer.py:1162: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   agg_df = plot_df.groupby(["Group", "Metric"], as_index=False).agg(

# %%
LLMAnalyzer.plot_metrics(
    df_results,
    group=["task_id", "prompting_id"],
    title_prefix="Gemma 3 4B - ",
)
# Out:
# C:\Users\janbe\OneDrive\Dokumente\GitRepos\pulse\src\eval\llm_analyzer.py:1162: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   agg_df = plot_df.groupby(["Group", "Metric"], as_index=False).agg(

# %%
# Zero-Shot Distribution Analysis
df_mdata = mdata_dict["zhu_2024b_zero_shot_preprocessor"]

# %%
LLMAnalyzer.plot_prediction_distribution(df_mdata, data_filter={"task": "sepsis"})
# Out:
# --- Prediction Distribution Statistics ---
# Total Records: 2939
# Ground Truth Positive Samples: 145
# Ground Truth Negative Samples: 2794
# Mean Predicted Probability (Average of All Predictions): 0.937
# Std Predicted Probability: 0.092
# Calibration Error (|Mean Pred. Prob. - Ground Truth Pos. Rate|): 0.888
# True Positives: 144
# True Negatives: 53
# False Positives: 2741
# False Negatives: 1
# Accuracy (at 0.5 threshold): 0.067
# AUPRC: 0.522
