# %% [markdown]
# # System Message Test
# Goal: Get best system message for all models, tasks, and datasets
#
# Overall Summary:
# - System message 1 shows the best performance accross all models and tasks
# - a positive and negative example helps the model to respond in the wanted way
# - for some models, many probability values do not match with the predicted label. The provided guidance in System Message 3-5 further increased the number of mismatches.
# - very bad performance across the board
# - clustering of probability values observed for all models except Deepseek-R1.
#
# ---

# %%
import pandas as pd
import numpy as np
import os
import sys
import re
import json
import matplotlib.pyplot as plt
import sys

sys.path.append(r"C:\Users\janbe\OneDrive\Dokumente\GitRepos\pulse")
from src.eval.metrics import calculate_all_metrics
from src.eval.pulse_score import PULSEScoreCalculator
from src.eval.llm_analyzer import VARIABLE_NAMES

# %%
outputfolder_path_list = [
    r"C:\Users\janbe\OneDrive\Dokumente\GitRepos\pulse\output_to_keep\sys_msgs_test"
]

SYSTEM_MESSAGE_COLORS = {
    0: "#4ECDC4",  
    1: "#FFE066",  
    2: "#A569BD",  
    3: "#5DADE2",  
    4: "#F39C12",  
}

# %%
def categorize_files(outputfolder_path_list):
    """
    Categorize files in the output folders into metrics report files, metadata files, and log files.

    Args:
        outputfolder_path_list (list): List of output folder paths.

    Returns:
        dict: A dictionary containing categorized files.
    """
    file_list = []
    for outputfolder_path in outputfolder_path_list:
        # List all files in the folder and its subfolders
        for root, dirs, files in os.walk(outputfolder_path):
            for file in files:
                file_list.append(os.path.join(root, file))

    categorized_files = {
        "metrics_report_files": [f for f in file_list if "metrics_report" in f],
        "metadata_files": [f for f in file_list if "metadata" in f],
        "log_files": [f for f in file_list if "log" in f],
    }

    print("Metrics Report Files:")
    for file in categorized_files["metrics_report_files"]:
        print(file)
    print("\nMetadata Files:")
    for file in categorized_files["metadata_files"]:
        print(file)
    print("\nLog Files:")
    for file in categorized_files["log_files"]:
        print(file)

    return categorized_files

# %%
def load_metadata(metadata_path_list):
    """
    Load metadata from a CSV file into a DataFrame.
    
    Args:
        metadata_path (str): Path to the metadata CSV file.
        
    Returns:
        pd.DataFrame: DataFrame containing the metadata.
    """
    df_mdata = pd.DataFrame()
    for m_path in metadata_path_list:
        try:
            df = pd.read_csv(m_path)
            match1 = re.search(
                r"\\([0-9]{8}_[0-9]{6})_[^\\]+\\([^_]+)_([^_]+)_([^_]+)_output_metadata\.csv$", m_path
            )
            match2 = re.search(
                r"\\([0-9]{8}_[0-9]{6})_[^\\]+\\([^_]+)_([^_]+)_([^_]+)_([^_]+)_([^_]+)_metadata\.csv$",
                m_path,
            )

            if match1:
                timestamp, model_name, task, dataset = match1.groups()
                print(f"Model Name: {model_name}, Task: {task}, Dataset: {dataset}, Timestamp: {timestamp}")
                # Add extracted metadata to the DataFrame
                df['model_name'] = model_name
                df['task'] = task
                df['dataset'] = dataset
                df['timestamp'] = timestamp

            elif match2:
                timestamp, model_name, task, dataset, _ , _ = match2.groups()
                print(
                    f"Model Name: {model_name}, Task: {task}, Dataset: {dataset}, Timestamp: {timestamp}"
                )
                # Add extracted metadata to the DataFrame
                df["model_name"] = model_name
                df["task"] = task
                df["dataset"] = dataset
                df["timestamp"] = timestamp

            else:
                print("Failed to extract metadata details from the path. Using default values.")
                df['model_name'] = "Unknown"
                df['task'] = "Unknown"
                df['dataset'] = "Unknown"
                df['timestamp'] = "Unknown"

            # Append the DataFrame to the main DataFrame
            df_mdata = pd.concat([df_mdata, df], ignore_index=True)

        except Exception as e:
            print(f"Error loading metadata: {e}")
            continue
    return df_mdata

# %%
def load_metrics_report_as_df(metrics_report_path):
    """
    Load metrics report from a JSON file and return it as a DataFrame.
    
    Args:
        metrics_report_path (str): Path to the metrics report JSON file.
        
    Returns:
        pd.DataFrame: DataFrame containing the metrics report.
    """
    try:
        with open(metrics_report_path, 'r') as f:
            metrics_report = json.load(f)
        df = pd.DataFrame(metrics_report)
        return df
    except Exception as e:
        print(f"Error loading metrics report: {e}")
        return None

# %%
def get_predictions_by_model_task_dataset(df, model, task, dataset):
    """
    Filter predictions DataFrame by model, task, and dataset.

    Args:
        df (DataFrame): DataFrame containing predictions.
        model (str): Model name to filter by.
        task (str): Task name to filter by.
        dataset (str): Dataset name to filter by.

    Returns:
        DataFrame: Filtered DataFrame with predictions.
    """
    return df[
        (df["model_name"] == model) & (df["task"] == task) & (df["dataset"] == dataset)
    ]


def get_predictions_by_task_dataset(df, task, dataset):
    """
    Filter predictions DataFrame by task and dataset.

    Args:
        df (DataFrame): DataFrame containing predictions.
        task (str): Task name to filter by.
        dataset (str): Dataset name to filter by.

    Returns:
        DataFrame: Filtered DataFrame with predictions.
    """
    return df[(df["task"] == task) & (df["dataset"] == dataset)]


def get_predictions_by_model(df, model):
    """
    Filter predictions DataFrame by model.

    Args:
        df (DataFrame): DataFrame containing predictions.
        model (str): Model name to filter by.

    Returns:
        DataFrame: Filtered DataFrame with predictions.
    """
    return df[df["model_name"] == model]

# %%
def plot_metrics_all_sys_msgs(df, titel_prefix):
    # Calculate all metrics for each unique System Message Index
    metrics_by_sys_msg_idx = {}

    for idx in df["System Message Index"].unique():
        subset = df[df["System Message Index"] == idx]
        y_true = subset['Target Label'].values
        y_pred = subset['Predicted Probability'].values
        metrics = calculate_all_metrics(y_true, y_pred)
        metrics_by_sys_msg_idx[idx] = metrics

    # Prepare data for plotting
    indices = list(metrics_by_sys_msg_idx.keys())
    metrics_names = list(next(iter(metrics_by_sys_msg_idx.values())).keys())

    # Create a grouped bar plot: x-axis = metric, bars = System Message Index
    bar_width = 0.2
    x = np.arange(len(metrics_names))

    plt.figure(figsize=(14, 6))
    for i, idx in enumerate(indices):
        values = [metrics_by_sys_msg_idx[idx][metric] for metric in metrics_names]
        plt.bar(x + i * bar_width, values, width=bar_width, label=f'System Msg {idx}')

    plt.xticks(x + bar_width * (len(indices) - 1) / 2, metrics_names, rotation=45, ha='right')
    plt.ylabel('Metric Value')
    plt.title(f"{titel_prefix} - Metrics by System Message (Grouped by Metric)")
    plt.grid(axis='y', linestyle='--', alpha=0.7)
    plt.legend()
    plt.tight_layout()
    plt.show()

def plot_metrics(df, titel_prefix=""):
    """
    Plot metrics from the DataFrame, grouped by model.

    Args:
        df (DataFrame): DataFrame containing metrics.
        titel_prefix (str): Prefix for the plot title.
    """
    if df.empty:
        print("No data to plot.")
        return

    metrics = ["auprc", "auroc", "mcc", "mcc_2"]
    metric_labels = ["AUPRC", "AUROC", "MCC1", "MCC2"]

    # Prepare data for plotting
    plot_data = []
    for idx, row in df.iterrows():
        for metric, label in zip(metrics, metric_labels):
            if metric in df.columns:
                plot_data.append(
                    {
                        "Model": row.get("model_id", f"Model{idx}"),
                        "Metric": label,
                        "Value": row[metric],
                    }
                )

    plot_df = pd.DataFrame(plot_data)

    # Pivot so each model is a group, each metric is a bar
    pivot_df = plot_df.pivot(index="Model", columns="Metric", values="Value")

    ax = pivot_df.plot(
        kind="bar", figsize=(4, 4), width=0.5, edgecolor="black", colormap="Set1"
    )
    plt.grid(axis="y", linestyle="--", alpha=0.7)
    plt.title(f"{titel_prefix}Metrics")
    plt.xlabel("Model")
    plt.ylabel("Value")
    plt.ylim(0, 1)
    plt.xticks(rotation=30, ha="right")
    plt.legend(metric_labels, frameon=False)
    plt.tight_layout()
    plt.show()

# %%
cat_files = categorize_files(outputfolder_path_list)
# Out:
# Metrics Report Files:
# C:\Users\janbe\OneDrive\Dokumente\GitRepos\pulse\output_to_keep\sys_msgs_test\20250608_180109_gemma3_sysmsgtest\Gemma3_metrics_report.json
# C:\Users\janbe\OneDrive\Dokumente\GitRepos\pulse\output_to_keep\sys_msgs_test\20250608_181930_llama38b_sys_msgs_test\Llama3_metrics_report.json
# C:\Users\janbe\OneDrive\Dokumente\GitRepos\pulse\output_to_keep\sys_msgs_test\20250608_182848_mistral7b_sysmsgtest\Mistral_metrics_report.json
# C:\Users\janbe\OneDrive\Dokumente\GitRepos\pulse\output_to_keep\sys_msgs_test\20250613_112431_sysmsgtest_DeepseekR1Llama8b_mortality_aki\DeepseekR1Llama8b_metrics_report.json
#
# Metadata Files:
# C:\Users\janbe\OneDrive\Dokumente\GitRepos\pulse\output_to_keep\sys_msgs_test\20250608_180109_gemma3_sysmsgtest\Gemma3_aki_eicu_20250616_135330_metadata.csv
# C:\Users\janbe\OneDrive\Dokumente\GitRepos\pulse\output_to_keep\sys_msgs_test\20250608_180109_gemma3_sysmsgtest\Gemma3_aki_eicu_20250617_131621_metadata.csv
# C:\Users\janbe\OneDrive\Dokumente\GitRepos\pulse\output_to_keep\sys_msgs_test\20250608_180109_gemma3_sysmsgtest\Gemma3_mortality_eicu_20250608_180109_metadata.csv
# C:\Users\janbe\OneDrive\Dokumente\GitRepos\pulse\output_to_keep\sys_msgs_test\20250608_180109_gemma3_sysmsgtest\Gemma3_sepsis_eicu_20250618_191905_metadata.csv
# C:\Users\janbe\OneDrive\Dokumente\GitRepos\pulse\output_to_keep\sys_msgs_test\20250608_180109_gemma3_sysmsgtest\Gemma3_sepsis_eicu_20250618_210113_metadata.csv
# C:\Users\janbe\OneDrive\Dokumente\GitRepos\pulse\output_to_keep\sys_msgs_test\20250608_180109_gemma3_sysmsgtest\Gemma3_sepsis_eicu_20250619_102359_metadata.csv
# C:\Users\janbe\OneDrive\Dokumente\GitRepos\pulse\output_to_keep\sys_msgs_test\20250608_181930_llama38b_sys_msgs_test\Llama3_aki_eicu_20250608_181930_metadata.csv
# C:\Users\janbe\OneDrive\Dokumente\GitRepos\pulse\output_to_keep\sys_msgs_test\20250608_181930_llama38b_sys_msgs_test\Llama3_mortality_eicu_20250608_181930_metadata.csv
# C:\Users\janbe\OneDrive\Dokumente\GitRepos\pulse\output_to_keep\sys_msgs_test\20250608_181930_llama38b_sys_msgs_test\Llama3_sepsis_eicu_20250608_181930_metadata.csv
# C:\Users\janbe\OneDrive\Dokumente\GitRepos\pulse\output_to_keep\sys_msgs_test\20250608_182848_mistral7b_sysmsgtest\Mistral_aki_eicu_output_metadata.csv
# C:\Users\janbe\OneDrive\Dokumente\GitRepos\pulse\output_to_keep\sys_msgs_test\20250608_182848_mistral7b_sysmsgtest\Mistral_mortality_eicu_output_metadata.csv
# C:\Users\janbe\OneDrive\Dokumente\GitRepos\pulse\output_to_keep\sys_msgs_test\20250608_182848_mistral7b_sysmsgtest\Mistral_sepsis_eicu_output_metadata.csv
# C:\Users\janbe\OneDrive\Dokumente\GitRepos\pulse\output_to_keep\sys_msgs_test\20250613_112431_sysmsgtest_DeepseekR1Llama8b_mortality_aki\DeepseekR1Llama8b_aki_eicu_20250613_112431_metadata.csv
# C:\Users\janbe\OneDrive\Dokumente\GitRepos\pulse\output_to_keep\sys_msgs_test\20250613_112431_sysmsgtest_DeepseekR1Llama8b_mortality_aki\DeepseekR1Llama8b_mortality_eicu_20250613_112431_metadata.csv
# C:\Users\janbe\OneDrive\Dokumente\GitRepos\pulse\output_to_keep\sys_msgs_test\20250613_112431_sysmsgtest_DeepseekR1Llama8b_mortality_aki\DeepseekR1Llama8b_sepsis_eicu_20250616_152929_metadata.csv
#
# Log Files:
# C:\Users\janbe\OneDrive\Dokumente\GitRepos\pulse\output_to_keep\sys_msgs_test\20250608_180109_gemma3_sysmsgtest\log_20250608_180109.log
# C:\Users\janbe\OneDrive\Dokumente\GitRepos\pulse\output_to_keep\sys_msgs_test\20250608_180109_gemma3_sysmsgtest\log_20250616_135330.log
# C:\Users\janbe\OneDrive\Dokumente\GitRepos\pulse\output_to_keep\sys_msgs_test\20250608_180109_gemma3_sysmsgtest\log_20250617_131621.log
# C:\Users\janbe\OneDrive\Dokumente\GitRepos\pulse\output_to_keep\sys_msgs_test\20250608_180109_gemma3_sysmsgtest\log_20250618_191905.log
# C:\Users\janbe\OneDrive\Dokumente\GitRepos\pulse\output_to_keep\sys_msgs_test\20250608_180109_gemma3_sysmsgtest\log_20250618_210113.log
# C:\Users\janbe\OneDrive\Dokumente\GitRepos\pulse\output_to_keep\sys_msgs_test\20250608_180109_gemma3_sysmsgtest\log_20250619_102359.log
# C:\Users\janbe\OneDrive\Dokumente\GitRepos\pulse\output_to_keep\sys_msgs_test\20250608_181930_llama38b_sys_msgs_test\log_20250608_181930.log
# C:\Users\janbe\OneDrive\Dokumente\GitRepos\pulse\output_to_keep\sys_msgs_test\20250608_182848_mistral7b_sysmsgtest\log_20250608_182848.log
# C:\Users\janbe\OneDrive\Dokumente\GitRepos\pulse\output_to_keep\sys_msgs_test\20250613_112431_sysmsgtest_DeepseekR1Llama8b_mortality_aki\log_20250613_112431.log
# C:\Users\janbe\OneDrive\Dokumente\GitRepos\pulse\output_to_keep\sys_msgs_test\20250613_112431_sysmsgtest_DeepseekR1Llama8b_mortality_aki\log_20250616_152929.log

# %%
df_metadata = load_metadata(cat_files["metadata_files"])
# Out:
# Model Name: Gemma3, Task: aki, Dataset: eicu, Timestamp: 20250608_180109
# Model Name: Gemma3, Task: aki, Dataset: eicu, Timestamp: 20250608_180109
# Model Name: Gemma3, Task: mortality, Dataset: eicu, Timestamp: 20250608_180109
# Model Name: Gemma3, Task: sepsis, Dataset: eicu, Timestamp: 20250608_180109
# Model Name: Gemma3, Task: sepsis, Dataset: eicu, Timestamp: 20250608_180109
# Model Name: Gemma3, Task: sepsis, Dataset: eicu, Timestamp: 20250608_180109
# Model Name: Llama3, Task: aki, Dataset: eicu, Timestamp: 20250608_181930
# Model Name: Llama3, Task: mortality, Dataset: eicu, Timestamp: 20250608_181930
# Model Name: Llama3, Task: sepsis, Dataset: eicu, Timestamp: 20250608_181930
# Model Name: Mistral, Task: aki, Dataset: eicu, Timestamp: 20250608_182848
# Model Name: Mistral, Task: mortality, Dataset: eicu, Timestamp: 20250608_182848
# Model Name: Mistral, Task: sepsis, Dataset: eicu, Timestamp: 20250608_182848
# Model Name: DeepseekR1Llama8b, Task: aki, Dataset: eicu, Timestamp: 20250613_112431
# Model Name: DeepseekR1Llama8b, Task: mortality, Dataset: eicu, Timestamp: 20250613_112431
# Model Name: DeepseekR1Llama8b, Task: sepsis, Dataset: eicu, Timestamp: 20250613_112431

# %%
df_metadata["Predicted Probability from Diagnosis"] = df_metadata["Predicted Diagnosis"].apply(
    lambda x: 1.0 if "not" not in x.lower() else 0.0
)
df_metadata
# Out:
#                                             Input Prompt  Target Label  \
# 0                                                    NaN             0
# 1                                                    NaN             0
# 2                                                    NaN             0
# 3                                                    NaN             0
# 4                                                    NaN             0
# ...                                                  ...           ...
# 41266  You are an experienced doctor in Intensive Car...             0
# 41267  You are an experienced doctor in Intensive Car...             0
# 41268  You are an experienced doctor in Intensive Car...             0
# 41269  You are an experienced doctor in Intensive Car...             0
# 41270  You are an experienced doctor in Intensive Car...             0
#
#        Predicted Probability Predicted Diagnosis  \
# 0                       0.85           diagnosis
# 1                       0.75                 aki
# 2                       0.78                 aki
# 3                       0.78                 aki
# 4                       0.75                 aki
# ...                      ...                 ...
# 41266                   0.80           diagnosis
# 41267                   0.12          not-sepsis
# 41268                   0.85              sepsis
# 41269                   0.60              sepsis
# 41270                   0.12          not-sepsis
#
#                                    Predicted Explanation  Tokenization Time  \
# 0      The patient exhibits several concerning signs ...           0.006900
# 1      Acute kidney injury is possible. Creatinine is...           0.005500
# 2      Likely acute kidney injury. Creatinine is stab...           0.004600
# 3      Likely acute kidney injury. Creatinine is stab...           0.004400
# 4      Likely acute kidney injury. Creatinine is stab...           0.004700
# ...                                                  ...                ...
# 41266  Elevated C-Reactive Protein (CRP) and high neu...           0.005817
# 41267  The patient's SOFA score is 0, which does not ...           0.006450
# 41268  Patient meets SOFA criteria with a score of 3,...           0.006494
# 41269  Patient shows signs of sepsis: elevated C-Reac...           0.006686
# 41270  Patient shows no signs of sepsis: temperature ...           0.006796
#
#        Inference Time  Input Tokens  Output Tokens  \
# 0           22.422400          3786            300
# 1           21.579100          3957            300
# 2           21.529500          4052            300
# 3           21.559600          4084            300
# 4           21.624700          4158            300
# ...               ...           ...            ...
# 41266       29.650258          3134            990
# 41267       23.098510          3323            768
# 41268       36.840308          3408           1232
# 41269       67.152123          3439           2238
# 41270       29.286654          3513            973
#
#                                           System Message  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 41266  You are a helpful assistant and experienced me...
# 41267  You are a helpful assistant and experienced me...
# 41268  You are a helpful assistant and experienced me...
# 41269  You are a helpful assistant and experienced me...
# 41270  You are a helpful assistant and experienced me...
#
#        System Message Index         model_name    task dataset  \
# 0                         0             Gemma3     aki    eicu
# 1                         1             Gemma3     aki    eicu
# 2                         2             Gemma3     aki    eicu
# 3                         3             Gemma3     aki    eicu
# 4                         4             Gemma3     aki    eicu
# ...                     ...                ...     ...     ...
# 41266                     0  DeepseekR1Llama8b  sepsis    eicu
# 41267                     1  DeepseekR1Llama8b  sepsis    eicu
# 41268                     2  DeepseekR1Llama8b  sepsis    eicu
# 41269                     3  DeepseekR1Llama8b  sepsis    eicu
# 41270                     4  DeepseekR1Llama8b  sepsis    eicu
#
#              timestamp  Predicted Probability from Diagnosis
# 0      20250608_180109                                   1.0
# 1      20250608_180109                                   1.0
# 2      20250608_180109                                   1.0
# 3      20250608_180109                                   1.0
# 4      20250608_180109                                   1.0
# ...                ...                                   ...
# 41266  20250613_112431                                   1.0
# 41267  20250613_112431                                   0.0
# 41268  20250613_112431                                   1.0
# 41269  20250613_112431                                   1.0
# 41270  20250613_112431                                   0.0
#
# [41271 rows x 16 columns]

# %% [markdown]
# ---
# ### Experiment Summary
# Metrics averaged over all models, tasks and datasets for the 5 different system messages

# %%
df_metrics_by_model_task_dataset = (
    df_metadata.groupby(["model_name", "task", "dataset", "System Message Index"])
    .apply(
        lambda x: {
            **calculate_all_metrics(
                x["Target Label"].values, 
                x["Predicted Probability"].values
            ),
            "mcc_2": calculate_all_metrics(
                x["Target Label"].values, 
                x["Predicted Probability from Diagnosis"].values
            )["mcc"],
        }
    )
    .reset_index()
)

metrics_expanded = df_metrics_by_model_task_dataset[0].apply(pd.Series)
df_metrics_by_model_task_dataset = pd.concat([df_metrics_by_model_task_dataset.drop(columns=0), metrics_expanded], axis=1)
df_metrics_by_model_task_dataset["pulse_score"] = (
    df_metrics_by_model_task_dataset["pulse_score"] / 100.0
)
# Out:
# C:\Users\janbe\AppData\Local\Temp\ipykernel_39200\1493680470.py:3: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(

# %%
df_metrics_by_model_task_dataset
# Out:
#            model_name       task dataset  System Message Index  auroc  auprc  \
# 0   DeepseekR1Llama8b        aki    eicu                     0  0.556  0.353
# 1   DeepseekR1Llama8b        aki    eicu                     1  0.586  0.392
# 2   DeepseekR1Llama8b        aki    eicu                     2  0.567  0.403
# 3   DeepseekR1Llama8b        aki    eicu                     3  0.562  0.392
# 4   DeepseekR1Llama8b        aki    eicu                     4  0.588  0.436
# 5   DeepseekR1Llama8b  mortality    eicu                     0  0.790  0.169
# 6   DeepseekR1Llama8b  mortality    eicu                     1  0.661  0.234
# 7   DeepseekR1Llama8b  mortality    eicu                     2  0.674  0.137
# 8   DeepseekR1Llama8b  mortality    eicu                     3  0.663  0.094
# 9   DeepseekR1Llama8b  mortality    eicu                     4  0.651  0.119
# 10  DeepseekR1Llama8b     sepsis    eicu                     0  0.578  0.092
# 11  DeepseekR1Llama8b     sepsis    eicu                     1  0.520  0.054
# 12  DeepseekR1Llama8b     sepsis    eicu                     2  0.516  0.102
# 13  DeepseekR1Llama8b     sepsis    eicu                     3  0.510  0.047
# 14  DeepseekR1Llama8b     sepsis    eicu                     4  0.594  0.076
# 15             Gemma3        aki    eicu                     0  0.529  0.543
# 16             Gemma3        aki    eicu                     1  0.610  0.279
# 17             Gemma3        aki    eicu                     2  0.585  0.437
# 18             Gemma3        aki    eicu                     3  0.583  0.442
# 19             Gemma3        aki    eicu                     4  0.604  0.439
# 20             Gemma3  mortality    eicu                     0  0.350  0.117
# 21             Gemma3  mortality    eicu                     1  0.505  0.535
# 22             Gemma3  mortality    eicu                     2  0.441  0.330
# 23             Gemma3  mortality    eicu                     3  0.396  0.327
# 24             Gemma3  mortality    eicu                     4  0.447  0.331
# 25             Gemma3     sepsis    eicu                     0  0.585  0.479
# 26             Gemma3     sepsis    eicu                     1  0.611  0.035
# 27             Gemma3     sepsis    eicu                     2  0.480  0.041
# 28             Gemma3     sepsis    eicu                     3  0.515  0.044
# 29             Gemma3     sepsis    eicu                     4  0.523  0.045
# 30             Llama3        aki    eicu                     0  0.542  0.521
# 31             Llama3        aki    eicu                     1  0.506  0.360
# 32             Llama3        aki    eicu                     2  0.520  0.396
# 33             Llama3        aki    eicu                     3  0.525  0.408
# 34             Llama3        aki    eicu                     4  0.542  0.380
# 35             Llama3  mortality    eicu                     0  0.666  0.377
# 36             Llama3  mortality    eicu                     1  0.500  0.535
# 37             Llama3  mortality    eicu                     2  0.500  0.535
# 38             Llama3  mortality    eicu                     3  0.489  0.035
# 39             Llama3  mortality    eicu                     4  0.555  0.226
# 40             Llama3     sepsis    eicu                     0  0.391  0.171
# 41             Llama3     sepsis    eicu                     1  0.545  0.052
# 42             Llama3     sepsis    eicu                     2  0.548  0.306
# 43             Llama3     sepsis    eicu                     3  0.571  0.408
# 44             Llama3     sepsis    eicu                     4  0.561  0.326
# 45            Mistral        aki    eicu                     0  0.514  0.311
# 46            Mistral        aki    eicu                     1  0.480  0.489
# 47            Mistral        aki    eicu                     2  0.525  0.328
# 48            Mistral        aki    eicu                     3  0.560  0.360
# 49            Mistral        aki    eicu                     4  0.501  0.340
# 50            Mistral  mortality    eicu                     0  0.511  0.536
# 51            Mistral  mortality    eicu                     1  0.416  0.192
# 52            Mistral  mortality    eicu                     2  0.288  0.044
# 53            Mistral  mortality    eicu                     3  0.329  0.041
# 54            Mistral  mortality    eicu                     4  0.386  0.049
# 55            Mistral     sepsis    eicu                     0  0.491  0.106
# 56            Mistral     sepsis    eicu                     1  0.478  0.024
# 57            Mistral     sepsis    eicu                     2  0.487  0.024
# 58            Mistral     sepsis    eicu                     3  0.489  0.024
# 59            Mistral     sepsis    eicu                     4  0.480  0.024
#
#     normalized_auprc  pulse_score  specificity  f1_score  accuracy  \
# 0              1.140      0.48632        0.772     0.348     0.631
# 1              1.264      0.51353        0.820     0.342     0.655
# 2              1.301      0.51197        0.803     0.359     0.651
# 3              1.264      0.50660        0.803     0.359     0.651
# 4              1.406      0.53521        0.834     0.367     0.671
# 5              2.409      0.51437        0.462     0.190     0.490
# 6              3.344      0.49434        0.613     0.208     0.620
# 7              1.951      0.46115        0.559     0.189     0.570
# 8              1.342      0.44859        0.613     0.208     0.620
# 9              1.703      0.44494        0.527     0.179     0.540
# 10             1.921      0.39824        0.523     0.104     0.526
# 11             1.134      0.36384        0.569     0.097     0.565
# 12             2.126      0.37425        0.577     0.087     0.569
# 13             0.986      0.34962        0.622     0.072     0.607
# 14             1.589      0.40325        0.647     0.120     0.641
# 15             1.752      0.52529        0.004     0.473     0.312
# 16             0.902      0.47754        0.196     0.476     0.405
# 17             1.410      0.52211        0.180     0.478     0.399
# 18             1.424      0.52200        0.161     0.478     0.390
# 19             1.417      0.53130        0.108     0.484     0.370
# 20             1.678      0.32433        0.000     0.131     0.070
# 21             7.648      0.51344        0.000     0.131     0.070
# 22             4.716      0.42441        0.000     0.131     0.070
# 23             4.674      0.40875        0.000     0.131     0.070
# 24             4.722      0.42660        0.000     0.131     0.070
# 25             9.971      0.52109        0.000     0.092     0.048
# 26             0.738      0.39149        0.045     0.096     0.091
# 27             0.855      0.34855        0.029     0.094     0.076
# 28             0.925      0.35970        0.019     0.093     0.066
# 29             0.935      0.36225        0.017     0.093     0.064
# 30             1.680      0.53250        0.489     0.431     0.519
# 31             1.160      0.46218        0.972     0.077     0.684
# 32             1.277      0.48272        0.972     0.094     0.687
# 33             1.318      0.49458        0.953     0.163     0.688
# 34             1.226      0.49007        0.819     0.315     0.646
# 35             5.386      0.54444        0.742     0.229     0.730
# 36             7.643      0.51155        0.000     0.131     0.070
# 37             7.643      0.51155        0.000     0.131     0.070
# 38             0.500      0.34300        0.000     0.131     0.070
# 39             3.235      0.42797        0.000     0.131     0.070
# 40             3.568      0.33694        0.153     0.071     0.178
# 41             1.081      0.37569        0.325     0.104     0.347
# 42             6.370      0.45793        0.403     0.101     0.416
# 43             8.499      0.50055        0.263     0.101     0.290
# 44             6.807      0.47316        0.071     0.098     0.115
# 45             1.003      0.44915        0.851     0.239     0.643
# 46             1.577      0.48956        0.000     0.473     0.310
# 47             1.059      0.46434        0.857     0.267     0.654
# 48             1.160      0.48453        0.878     0.236     0.659
# 49             1.098      0.45044        0.476     0.400     0.496
# 50             7.653      0.51533        0.000     0.131     0.070
# 51             2.747      0.37083        0.000     0.131     0.070
# 52             0.631      0.28430        0.011     0.132     0.080
# 53             0.586      0.29203        0.000     0.131     0.070
# 54             0.698      0.31361        0.000     0.131     0.070
# 55             2.220      0.36387        0.818     0.062     0.786
# 56             0.500      0.32769        0.956     0.000     0.910
# 57             0.500      0.33262        0.974     0.000     0.928
# 58             0.500      0.33355        0.977     0.000     0.931
# 59             0.501      0.32872        0.959     0.000     0.913
#
#     balanced_accuracy  precision  recall    mcc  kappa  minpse  mcc_2
# 0               0.545      0.385   0.318  0.095  0.094   0.383  0.100
# 1               0.554      0.419   0.289  0.123  0.119   0.382  0.137
# 2               0.559      0.417   0.315  0.128  0.126   0.401  0.125
# 3               0.559      0.417   0.315  0.128  0.126   0.368  0.122
# 4               0.571      0.454   0.308  0.161  0.156   0.413  0.165
# 5               0.660      0.107   0.857  0.164  0.075   0.194  0.164
# 6               0.664      0.122   0.714  0.170  0.101   0.135  0.121
# 7               0.637      0.109   0.714  0.140  0.076   0.375  0.114
# 8               0.664      0.122   0.714  0.170  0.101   0.128  0.189
# 9               0.621      0.102   0.714  0.123  0.064   0.235  0.121
# 10              0.549      0.057   0.574  0.042  0.018   0.065  0.033
# 11              0.529      0.054   0.489  0.025  0.012   0.054  0.023
# 12              0.501      0.048   0.426  0.001  0.000   0.067  0.017
# 13              0.470      0.041   0.319 -0.026 -0.014   0.070 -0.010
# 14              0.579      0.068   0.511  0.070  0.039   0.069  0.029
# 15              0.501      0.310   0.997  0.008  0.001   0.331  0.008
# 16              0.534      0.328   0.872  0.083  0.047   0.409  0.083
# 17              0.534      0.327   0.889  0.086  0.046   0.334  0.086
# 18              0.531      0.325   0.902  0.083  0.042   0.329  0.083
# 19              0.531      0.324   0.954  0.100  0.040   0.356  0.100
# 20              0.500      0.070   1.000  0.000  0.000   0.071 -0.028
# 21              0.500      0.070   1.000  0.000  0.000   0.071  0.109
# 22              0.500      0.070   1.000  0.000  0.000   0.071  0.064
# 23              0.500      0.070   1.000  0.000  0.000   0.070  0.073
# 24              0.500      0.070   1.000  0.000  0.000   0.070 -0.154
# 25              0.500      0.048   1.000  0.000  0.000   0.059  0.000
# 26              0.523      0.050   1.000  0.048  0.005   0.064  0.048
# 27              0.515      0.049   1.000  0.038  0.003   0.049  0.038
# 28              0.510      0.049   1.000  0.031  0.002   0.054  0.031
# 29              0.509      0.049   1.000  0.029  0.002   0.056  0.029
# 30              0.538      0.340   0.587  0.070  0.063   0.346  0.070
# 31              0.507      0.406   0.043  0.038  0.019   0.310  0.038
# 32              0.512      0.457   0.052  0.061  0.032   0.310  0.061
# 33              0.526      0.484   0.098  0.098  0.066   0.310  0.098
# 34              0.541      0.394   0.262  0.093  0.089   0.311  0.093
# 35              0.657      0.143   0.571  0.178  0.131   0.160  0.178
# 36              0.500      0.070   1.000  0.000  0.000   0.070  0.000
# 37              0.500      0.070   1.000  0.000  0.000   0.070  0.000
# 38              0.500      0.070   1.000  0.000  0.000   0.070  0.000
# 39              0.500      0.070   1.000  0.000  0.000   0.143  0.000
# 40              0.406      0.038   0.660 -0.108 -0.021   0.048 -0.108
# 41              0.556      0.055   0.787  0.051  0.015   0.055  0.051
# 42              0.542      0.054   0.681  0.037  0.013   0.056  0.037
# 43              0.546      0.054   0.830  0.045  0.012   0.059  0.045
# 44              0.535      0.051   1.000  0.060  0.007   0.057  0.060
# 45              0.516      0.353   0.180  0.040  0.036   0.310  0.040
# 46              0.500      0.310   1.000  0.000  0.000   0.310  0.098
# 47              0.530      0.390   0.203  0.076  0.070   0.319  0.088
# 48              0.524      0.385   0.170  0.065  0.057   0.338  0.064
# 49              0.508      0.317   0.541  0.015  0.014   0.321  0.070
# 50              0.500      0.070   1.000  0.000  0.000   0.071  0.000
# 51              0.500      0.070   1.000  0.000  0.000   0.070  0.261
# 52              0.505      0.071   1.000  0.028  0.002   0.071  0.228
# 53              0.500      0.070   1.000  0.000  0.000   0.070 -0.096
# 54              0.500      0.070   1.000  0.000  0.000   0.070  0.094
# 55              0.483      0.040   0.149 -0.018 -0.014   0.048 -0.018
# 56              0.478      0.000   0.000 -0.047 -0.047   0.048 -0.038
# 57              0.487      0.000   0.000 -0.036 -0.034   0.048 -0.036
# 58              0.489      0.000   0.000 -0.033 -0.031   0.048 -0.033
# 59              0.480      0.000   0.000 -0.045 -0.045   0.048 -0.045

# %%
# Create subplots combining all the analyses
fig, axes = plt.subplots(2, 2, figsize=(10, 8))

# Define the tasks and corresponding axes
tasks_and_positions = [
    ("all_data", (0, 0), "Overall"),
    ("mortality", (0, 1), "Mortality"),
    ("aki", (1, 0), "AKI"),
    ("sepsis", (1, 1), "Sepsis")
]

metrics_to_plot = ["auroc", "auprc", "mcc_2", "pulse_score"]
colors = ["#1f77b4", "#ff7f0e", "#2ca02c", "#d62728"]

# Store handles and labels for shared legend
legend_handles = []
legend_labels = []

for task, (row, col), title in tasks_and_positions:
    ax = axes[row, col]
    
    # Filter data based on task
    if task == "all_data":
        df_filtered = df_metrics_by_model_task_dataset.copy()
    else:
        df_filtered = df_metrics_by_model_task_dataset[
            df_metrics_by_model_task_dataset["task"] == task
        ].copy()
    
    # Plot metrics for this task
    for i, metric in enumerate(metrics_to_plot):
        if metric not in df_filtered.columns:
            continue
            
        # Group by System Message Index and aggregate
        grouped = df_filtered.groupby("System Message Index")[metric].agg(
            ["mean", "min", "max"]
        )
        
        if grouped.empty:
            continue
            
        x = grouped.index + 1
        y_mean = grouped["mean"]
        y_min = grouped["min"]
        y_max = grouped["max"]
        
        color = colors[i % len(colors)]
        line = ax.plot(x, y_mean, marker="o", label=VARIABLE_NAMES.get(metric,metric), color=color, linestyle="--")
        ax.fill_between(x, y_min, y_max, alpha=0.2, color=color)
        
        # Collect legend information from first subplot only
        if task == "all_data":
            legend_handles.append(line[0])
            legend_labels.append(VARIABLE_NAMES.get(metric,metric))
    
    # Customize each subplot
    ax.set_xticks(np.arange(1, df_filtered["System Message Index"].max() + 2))
    ax.set_xlim(0.8, df_filtered["System Message Index"].max() + 1.2)
    ax.set_ylim(-0.2, 1)
    ax.set_title(title)
    ax.grid(True, alpha=0.7)
    
    # Only show x-label on bottom row
    if row == 1:  # Bottom row
        ax.set_xlabel("System Message")
    else:
        ax.set_xlabel("")
    
    # Only show y-label on left column
    if col == 0:  # Left column
        ax.set_ylabel("Metric Value")
    else:
        ax.set_ylabel("")
    
    # Print summary for each subplot
    print(f"{title}:")
    print(f"  - Total combinations: {len(df_filtered)}")
    print(f"  - Models: {df_filtered['model_name'].nunique()}")
    print(f"  - Tasks: {df_filtered['task'].nunique()}")
    # Print min, max, mean for each System Message Index in this task
    for idx in sorted(df_filtered["System Message Index"].unique()):
        msg_metrics = df_filtered[df_filtered["System Message Index"] == idx][metrics_to_plot]
        msg_min = msg_metrics.min().round(3).to_dict()
        msg_max = msg_metrics.max().round(3).to_dict()
        msg_mean = msg_metrics.mean().round(3).to_dict()
        print(f"    System Message {idx+1}:")
        print(f"      min: {msg_min}")
        print(f"      max: {msg_max}")
        print(f"      mean: {msg_mean}")
        difference = {k: round(msg_max[k] - msg_min[k], 3) for k in msg_max.keys()}
        print(f"      max-min: {difference}")
    print(f"  - Datasets: {df_filtered['dataset'].nunique()}")
    print()

# Add shared legend below the subplots
fig.legend(legend_handles, legend_labels,
           loc='lower center', 
           bbox_to_anchor=(0.5, -0.02), 
           ncol=4, 
           frameon=False,
           )

# Adjust layout to make room for legend
plt.tight_layout()
plt.subplots_adjust(bottom=0.1)

# Save the combined plot
plt.savefig(r"plots/metrics_by_system_message.png", bbox_inches="tight", dpi=300)
print("Combined subplot saved to: plots/metrics_by_system_message.png")

plt.show()
# Out:
# Overall:
#   - Total combinations: 60
#   - Models: 4
#   - Tasks: 3
#     System Message 1:
#       min: {'auroc': 0.35, 'auprc': 0.092, 'mcc_2': -0.108, 'pulse_score': 0.324}
#       max: {'auroc': 0.79, 'auprc': 0.543, 'mcc_2': 0.178, 'pulse_score': 0.544}
#       mean: {'auroc': 0.542, 'auprc': 0.315, 'mcc_2': 0.037, 'pulse_score': 0.459}
#       max-min: {'auroc': 0.44, 'auprc': 0.451, 'mcc_2': 0.286, 'pulse_score': 0.22}
#     System Message 2:
#       min: {'auroc': 0.416, 'auprc': 0.024, 'mcc_2': -0.038, 'pulse_score': 0.328}
#       max: {'auroc': 0.661, 'auprc': 0.535, 'mcc_2': 0.261, 'pulse_score': 0.514}
#       mean: {'auroc': 0.535, 'auprc': 0.265, 'mcc_2': 0.078, 'pulse_score': 0.441}
#       max-min: {'auroc': 0.245, 'auprc': 0.511, 'mcc_2': 0.299, 'pulse_score': 0.186}
#     System Message 3:
#       min: {'auroc': 0.288, 'auprc': 0.024, 'mcc_2': -0.036, 'pulse_score': 0.284}
#       max: {'auroc': 0.674, 'auprc': 0.535, 'mcc_2': 0.228, 'pulse_score': 0.522}
#       mean: {'auroc': 0.511, 'auprc': 0.257, 'mcc_2': 0.068, 'pulse_score': 0.431}
#       max-min: {'auroc': 0.386, 'auprc': 0.511, 'mcc_2': 0.264, 'pulse_score': 0.238}
#     System Message 4:
#       min: {'auroc': 0.329, 'auprc': 0.024, 'mcc_2': -0.096, 'pulse_score': 0.292}
#       max: {'auroc': 0.663, 'auprc': 0.442, 'mcc_2': 0.189, 'pulse_score': 0.522}
#       mean: {'auroc': 0.516, 'auprc': 0.218, 'mcc_2': 0.047, 'pulse_score': 0.42}
#       max-min: {'auroc': 0.334, 'auprc': 0.418, 'mcc_2': 0.285, 'pulse_score': 0.23}
#     System Message 5:
#       min: {'auroc': 0.386, 'auprc': 0.024, 'mcc_2': -0.154, 'pulse_score': 0.314}
#       max: {'auroc': 0.651, 'auprc': 0.439, 'mcc_2': 0.165, 'pulse_score': 0.535}
#       mean: {'auroc': 0.536, 'auprc': 0.233, 'mcc_2': 0.047, 'pulse_score': 0.432}
#       max-min: {'auroc': 0.265, 'auprc': 0.415, 'mcc_2': 0.319, 'pulse_score': 0.221}
#   - Datasets: 1
#
# Mortality:
#   - Total combinations: 20
#   - Models: 4
#   - Tasks: 1
#     System Message 1:
#       min: {'auroc': 0.35, 'auprc': 0.117, 'mcc_2': -0.028, 'pulse_score': 0.324}
#       max: {'auroc': 0.79, 'auprc': 0.536, 'mcc_2': 0.178, 'pulse_score': 0.544}
#       mean: {'auroc': 0.579, 'auprc': 0.3, 'mcc_2': 0.078, 'pulse_score': 0.475}
#       max-min: {'auroc': 0.44, 'auprc': 0.419, 'mcc_2': 0.206, 'pulse_score': 0.22}
#     System Message 2:
#       min: {'auroc': 0.416, 'auprc': 0.192, 'mcc_2': 0.0, 'pulse_score': 0.371}
#       max: {'auroc': 0.661, 'auprc': 0.535, 'mcc_2': 0.261, 'pulse_score': 0.513}
#       mean: {'auroc': 0.52, 'auprc': 0.374, 'mcc_2': 0.123, 'pulse_score': 0.473}
#       max-min: {'auroc': 0.245, 'auprc': 0.343, 'mcc_2': 0.261, 'pulse_score': 0.142}
#     System Message 3:
#       min: {'auroc': 0.288, 'auprc': 0.044, 'mcc_2': 0.0, 'pulse_score': 0.284}
#       max: {'auroc': 0.674, 'auprc': 0.535, 'mcc_2': 0.228, 'pulse_score': 0.512}
#       mean: {'auroc': 0.476, 'auprc': 0.262, 'mcc_2': 0.102, 'pulse_score': 0.42}
#       max-min: {'auroc': 0.386, 'auprc': 0.491, 'mcc_2': 0.228, 'pulse_score': 0.228}
#     System Message 4:
#       min: {'auroc': 0.329, 'auprc': 0.035, 'mcc_2': -0.096, 'pulse_score': 0.292}
#       max: {'auroc': 0.663, 'auprc': 0.327, 'mcc_2': 0.189, 'pulse_score': 0.449}
#       mean: {'auroc': 0.469, 'auprc': 0.124, 'mcc_2': 0.042, 'pulse_score': 0.373}
#       max-min: {'auroc': 0.334, 'auprc': 0.292, 'mcc_2': 0.285, 'pulse_score': 0.157}
#     System Message 5:
#       min: {'auroc': 0.386, 'auprc': 0.049, 'mcc_2': -0.154, 'pulse_score': 0.314}
#       max: {'auroc': 0.651, 'auprc': 0.331, 'mcc_2': 0.121, 'pulse_score': 0.445}
#       mean: {'auroc': 0.51, 'auprc': 0.181, 'mcc_2': 0.015, 'pulse_score': 0.403}
#       max-min: {'auroc': 0.265, 'auprc': 0.282, 'mcc_2': 0.275, 'pulse_score': 0.131}
#   - Datasets: 1
#
# AKI:
#   - Total combinations: 20
#   - Models: 4
#   - Tasks: 1
#     System Message 1:
#       min: {'auroc': 0.514, 'auprc': 0.311, 'mcc_2': 0.008, 'pulse_score': 0.449}
#       max: {'auroc': 0.556, 'auprc': 0.543, 'mcc_2': 0.1, 'pulse_score': 0.532}
#       mean: {'auroc': 0.535, 'auprc': 0.432, 'mcc_2': 0.055, 'pulse_score': 0.498}
#       max-min: {'auroc': 0.042, 'auprc': 0.232, 'mcc_2': 0.092, 'pulse_score': 0.083}
#     System Message 2:
#       min: {'auroc': 0.48, 'auprc': 0.279, 'mcc_2': 0.038, 'pulse_score': 0.462}
#       max: {'auroc': 0.61, 'auprc': 0.489, 'mcc_2': 0.137, 'pulse_score': 0.514}
#       mean: {'auroc': 0.546, 'auprc': 0.38, 'mcc_2': 0.089, 'pulse_score': 0.486}
#       max-min: {'auroc': 0.13, 'auprc': 0.21, 'mcc_2': 0.099, 'pulse_score': 0.052}
#     System Message 3:
#       min: {'auroc': 0.52, 'auprc': 0.328, 'mcc_2': 0.061, 'pulse_score': 0.464}
#       max: {'auroc': 0.585, 'auprc': 0.437, 'mcc_2': 0.125, 'pulse_score': 0.522}
#       mean: {'auroc': 0.549, 'auprc': 0.391, 'mcc_2': 0.09, 'pulse_score': 0.495}
#       max-min: {'auroc': 0.065, 'auprc': 0.109, 'mcc_2': 0.064, 'pulse_score': 0.058}
#     System Message 4:
#       min: {'auroc': 0.525, 'auprc': 0.36, 'mcc_2': 0.064, 'pulse_score': 0.485}
#       max: {'auroc': 0.583, 'auprc': 0.442, 'mcc_2': 0.122, 'pulse_score': 0.522}
#       mean: {'auroc': 0.558, 'auprc': 0.4, 'mcc_2': 0.092, 'pulse_score': 0.502}
#       max-min: {'auroc': 0.058, 'auprc': 0.082, 'mcc_2': 0.058, 'pulse_score': 0.037}
#     System Message 5:
#       min: {'auroc': 0.501, 'auprc': 0.34, 'mcc_2': 0.07, 'pulse_score': 0.45}
#       max: {'auroc': 0.604, 'auprc': 0.439, 'mcc_2': 0.165, 'pulse_score': 0.535}
#       mean: {'auroc': 0.559, 'auprc': 0.399, 'mcc_2': 0.107, 'pulse_score': 0.502}
#       max-min: {'auroc': 0.103, 'auprc': 0.099, 'mcc_2': 0.095, 'pulse_score': 0.085}
#   - Datasets: 1
#
# Sepsis:
#   - Total combinations: 20
#   - Models: 4
#   - Tasks: 1
#     System Message 1:
#       min: {'auroc': 0.391, 'auprc': 0.092, 'mcc_2': -0.108, 'pulse_score': 0.337}
#       max: {'auroc': 0.585, 'auprc': 0.479, 'mcc_2': 0.033, 'pulse_score': 0.521}
#       mean: {'auroc': 0.511, 'auprc': 0.212, 'mcc_2': -0.023, 'pulse_score': 0.405}
#       max-min: {'auroc': 0.194, 'auprc': 0.387, 'mcc_2': 0.141, 'pulse_score': 0.184}
#     System Message 2:
#       min: {'auroc': 0.478, 'auprc': 0.024, 'mcc_2': -0.038, 'pulse_score': 0.328}
#       max: {'auroc': 0.611, 'auprc': 0.054, 'mcc_2': 0.051, 'pulse_score': 0.391}
#       mean: {'auroc': 0.538, 'auprc': 0.041, 'mcc_2': 0.021, 'pulse_score': 0.365}
#       max-min: {'auroc': 0.133, 'auprc': 0.03, 'mcc_2': 0.089, 'pulse_score': 0.063}
#     System Message 3:
#       min: {'auroc': 0.48, 'auprc': 0.024, 'mcc_2': -0.036, 'pulse_score': 0.333}
#       max: {'auroc': 0.548, 'auprc': 0.306, 'mcc_2': 0.038, 'pulse_score': 0.458}
#       mean: {'auroc': 0.508, 'auprc': 0.118, 'mcc_2': 0.014, 'pulse_score': 0.378}
#       max-min: {'auroc': 0.068, 'auprc': 0.282, 'mcc_2': 0.074, 'pulse_score': 0.125}
#     System Message 4:
#       min: {'auroc': 0.489, 'auprc': 0.024, 'mcc_2': -0.033, 'pulse_score': 0.334}
#       max: {'auroc': 0.571, 'auprc': 0.408, 'mcc_2': 0.045, 'pulse_score': 0.501}
#       mean: {'auroc': 0.521, 'auprc': 0.131, 'mcc_2': 0.008, 'pulse_score': 0.386}
#       max-min: {'auroc': 0.082, 'auprc': 0.384, 'mcc_2': 0.078, 'pulse_score': 0.167}
#     System Message 5:
#       min: {'auroc': 0.48, 'auprc': 0.024, 'mcc_2': -0.045, 'pulse_score': 0.329}
#       max: {'auroc': 0.594, 'auprc': 0.326, 'mcc_2': 0.06, 'pulse_score': 0.473}
#       mean: {'auroc': 0.54, 'auprc': 0.118, 'mcc_2': 0.018, 'pulse_score': 0.392}
#       max-min: {'auroc': 0.114, 'auprc': 0.302, 'mcc_2': 0.105, 'pulse_score': 0.144}
#   - Datasets: 1
#
# Combined subplot saved to: plots/metrics_by_system_message.png

# %%
metrics_to_plot = ["mcc", "mcc_2"]  # , "normalized_auprc"]"auroc", "auprc",
# Use more visually distinct and colorblind-friendly colors
colors = [ '#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd', '#8c564b', '#e377c2', '#7f7f7f', '#bcbd22', '#17becf']

plt.figure(figsize=(8, 5))

for metric, color in zip(metrics_to_plot, ["#2ca02c", "#1c5338"]):
    # group by System Message Index and aggregate across model-task-dataset combinations
    grouped = df_metrics_by_model_task_dataset.groupby("System Message Index")[metric].agg(['mean', 'min', 'max'])
    x = grouped.index + 1
    y_mean = grouped['mean']
    y_min = grouped['min']
    y_max = grouped['max']
    plt.plot(x, y_mean, marker="o", label=metric, color=color, linestyle='--')
    plt.fill_between(x, y_min, y_max, alpha=0.2, color=color)

plt.xlabel("System Message")
plt.xticks(np.arange(1, 6))
plt.xlim(0.8, df_metrics_by_model_task_dataset["System Message Index"].max() + 1.2)
# plt.ylim(0,1)
plt.ylabel("Metric Value")
plt.title("Averaged Mathew Correlation Coefficient (MCC) by System Message Index (mean ± min/max) - Per Model-Task-Dataset")
plt.legend()
plt.grid(True, alpha=0.7)
plt.tight_layout()
plt.annotate(
    "Note: mcc_2 is calculated from the Diagnosis converted classification label.\nMetrics calculated per model-task-dataset combination.",
    xy=(0.5, -0.18),
    xycoords="axes fraction",
    ha="center",
    fontsize=10,
    color="gray"
)
plt.show()

# %% [markdown]
# Average Tokenization time, Average Inference Time, Average Input Tokens, Average Output Tokens for each model, task, and dataset

# %%
df_m = df_metadata.groupby(["model_name", "task", "dataset"]).agg({
    "Tokenization Time": "mean",
    "Inference Time": "mean",
    "Input Tokens": "mean",
    "Output Tokens": "mean"
}).reset_index().sort_values(by=["model_name", "task", "dataset"])

# Create a summary DataFrame with means for each model, task, dataset, and system message
df_m_sysmsg = df_metadata.groupby(
    ["model_name", "dataset", "System Message Index"]
).agg({
    "Tokenization Time": "mean",
    "Inference Time": "mean",
    "Input Tokens": "mean",
    "Output Tokens": "mean"
}).reset_index().sort_values(by=["model_name", "dataset", "System Message Index"])
df_m_sysmsg
# Out:
#            model_name dataset  System Message Index  Tokenization Time  \
# 0   DeepseekR1Llama8b    eicu                     0           0.006063
# 1   DeepseekR1Llama8b    eicu                     1           0.006388
# 2   DeepseekR1Llama8b    eicu                     2           0.006497
# 3   DeepseekR1Llama8b    eicu                     3           0.006550
# 4   DeepseekR1Llama8b    eicu                     4           0.006745
# 5              Gemma3    eicu                     0           0.004455
# 6              Gemma3    eicu                     1           0.004556
# 7              Gemma3    eicu                     2           0.004674
# 8              Gemma3    eicu                     3           0.004741
# 9              Gemma3    eicu                     4           0.004833
# 10             Llama3    eicu                     0           0.006481
# 11             Llama3    eicu                     1           0.006779
# 12             Llama3    eicu                     2           0.006929
# 13             Llama3    eicu                     3           0.007012
# 14             Llama3    eicu                     4           0.007131
# 15            Mistral    eicu                     0           0.012213
# 16            Mistral    eicu                     1           0.012988
# 17            Mistral    eicu                     2           0.013497
# 18            Mistral    eicu                     3           0.013729
# 19            Mistral    eicu                     4           0.014065
#
#     Inference Time  Input Tokens  Output Tokens
# 0        36.989068   3352.328488    1276.894864
# 1        30.262617   3525.758721    1064.339147
# 2        28.412935   3610.758721    1010.777132
# 3        28.031225   3641.758721    1009.978682
# 4        29.271420   3714.231589    1035.947674
# 5        16.761177   4094.840039     300.000000
# 6        16.820628   4276.918041     300.000000
# 7        16.766127   4371.918041     300.000000
# 8        16.792537   4403.918041     300.000000
# 9        16.923084   4478.963628     300.000000
# 10        4.239527   3382.328488     138.366764
# 11        3.204667   3555.758721     101.590116
# 12        3.339280   3640.758721     106.178779
# 13        3.444601   3671.758721     109.436047
# 14        3.554442   3744.231589     112.642926
# 15        4.598556   4369.834302     141.562984
# 16        4.137018   4588.931202     123.910853
# 17        4.069453   4695.931202     121.248547
# 18        4.342836   4734.931202     130.264050
# 19        4.166717   4821.024225     124.077519

# %%
metrics = ["Input Tokens", "Output Tokens", "Inference Time"]
ylabels = ["Input Tokens", "Output Tokens", "Inference Time (s)"]
titles = [
    "Mean Input Tokens by Model and System Message - eICU",
    "Mean Output Tokens by Model and System Message - eICU",
    "Mean Inference Time by Model and System Message - eICU",
]

for metric, ylabel, title in zip(metrics, ylabels, titles):
    plt.figure(figsize=(8, 5))
    for idx in sorted(df_m_sysmsg["System Message Index"].unique()):
        df_plot = df_m_sysmsg[df_m_sysmsg["System Message Index"] == idx]
        plt.plot(
            df_plot["model_name"],
            df_plot[metric],
            marker="o",
            label=f"sys.msg. {idx}",
            color=SYSTEM_MESSAGE_COLORS.get(idx, "#000000")
        )
    plt.ylabel(ylabel)
    plt.title(title)
    plt.xticks(rotation=45, ha="right")
    plt.legend(title="System Msg Idx")
    plt.grid(axis="y", linestyle="--", alpha=0.7)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ---

# %% [markdown]
# ### Mistral 7B
#
# Summary:
# - System Message 0 response not using correct label
# - System Message 1 has best performance

# %%
df_mistral7b = get_predictions_by_model(df_metadata, "Mistral")
df_mistral7b["Predicted Probability Diagnosis"] = df_mistral7b["Predicted Diagnosis"].apply(lambda x: 0 if "not" in x else 1)
df_mistral7b
# Out:
# C:\Users\janbe\AppData\Local\Temp\ipykernel_39200\1449084726.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_mistral7b["Predicted Probability Diagnosis"] = df_mistral7b["Predicted Diagnosis"].apply(lambda x: 0 if "not" in x else 1)
#                                             Input Prompt  Target Label  \
# 20631  You are an experienced doctor in Intensive Car...             0
# 20632  You are an experienced doctor in Intensive Car...             0
# 20633  You are an experienced doctor in Intensive Car...             0
# 20634  You are an experienced doctor in Intensive Car...             0
# 20635  You are an experienced doctor in Intensive Car...             0
# ...                                                  ...           ...
# 30946  You are an experienced doctor in Intensive Car...             0
# 30947  You are an experienced doctor in Intensive Car...             0
# 30948  You are an experienced doctor in Intensive Car...             0
# 30949  You are an experienced doctor in Intensive Car...             0
# 30950  You are an experienced doctor in Intensive Car...             0
#
#        Predicted Probability Predicted Diagnosis  \
# 20631                   0.00       not-diagnosis
# 20632                   0.95             not-aki
# 20633                   0.10             not-aki
# 20634                   0.10             not-aki
# 20635                   0.10             not-aki
# ...                      ...                 ...
# 30946                   0.85           diagnosis
# 30947                   0.12          not-sepsis
# 30948                   0.12          not-sepsis
# 30949                   0.12          not-sepsis
# 30950                   0.12          not-sepsis
#
#                                    Predicted Explanation  Tokenization Time  \
# 20631  The patient's creatinine level is within the n...           0.011632
# 20632  The patient's creatinine levels remained stabl...           0.012297
# 20633  Kidney function appears stable based on creati...           0.012798
# 20634  Kidney function appears stable based on creati...           0.013072
# 20635  Kidney function appears stable based on creati...           0.013340
# ...                                                  ...                ...
# 30946  The patient's SOFA score increased from 0 to 4...           0.011584
# 30947  The patient shows no signs of sepsis as indica...           0.012363
# 30948  The patient shows no signs of sepsis as indica...           0.012687
# 30949  The patient shows no signs of sepsis as their ...           0.013175
# 30950  The patient shows no signs of sepsis as their ...           0.013431
#
#        Inference Time  Input Tokens  Output Tokens  \
# 20631        5.051853          4062            158
# 20632        6.061033          4266            193
# 20633        4.051667          4373            124
# 20634        4.229980          4412            130
# 20635        4.755879          4496            148
# ...               ...           ...            ...
# 30946        3.811822          4057            120
# 30947        2.967897          4293             89
# 30948        3.639697          4400            112
# 30949        2.572721          4439             75
# 30950        2.810036          4527             83
#
#                                           System Message  \
# 20631  You are a helpful assistant and experienced me...
# 20632  You are a helpful assistant and experienced me...
# 20633  You are a helpful assistant and experienced me...
# 20634  You are a helpful assistant and experienced me...
# 20635  You are a helpful assistant and experienced me...
# ...                                                  ...
# 30946  You are a helpful assistant and experienced me...
# 30947  You are a helpful assistant and experienced me...
# 30948  You are a helpful assistant and experienced me...
# 30949  You are a helpful assistant and experienced me...
# 30950  You are a helpful assistant and experienced me...
#
#        System Message Index model_name    task dataset        timestamp  \
# 20631                     0    Mistral     aki    eicu  20250608_182848
# 20632                     1    Mistral     aki    eicu  20250608_182848
# 20633                     2    Mistral     aki    eicu  20250608_182848
# 20634                     3    Mistral     aki    eicu  20250608_182848
# 20635                     4    Mistral     aki    eicu  20250608_182848
# ...                     ...        ...     ...     ...              ...
# 30946                     0    Mistral  sepsis    eicu  20250608_182848
# 30947                     1    Mistral  sepsis    eicu  20250608_182848
# 30948                     2    Mistral  sepsis    eicu  20250608_182848
# 30949                     3    Mistral  sepsis    eicu  20250608_182848
# 30950                     4    Mistral  sepsis    eicu  20250608_182848
#
#        Predicted Probability from Diagnosis  Predicted Probability Diagnosis
# 20631                                   0.0                                0
# 20632                                   0.0                                0
# 20633                                   0.0                                0
# 20634                                   0.0                                0
# 20635                                   0.0                                0
# ...                                     ...                              ...
# 30946                                   1.0                                1
# 30947                                   0.0                                0
# 30948                                   0.0                                0
# 30949                                   0.0                                0
# 30950                                   0.0                                0
#
# [10320 rows x 17 columns]

# %%
counter = 0
for idx, group in df_mistral7b.groupby("System Message Index"):
    # Check for probability < 0.5 and "not" not in diagnosis
    mask_low = group["Predicted Probability"] < 0.5
    for diag in group.loc[mask_low, "Predicted Diagnosis"]:
        if "not" not in diag:
            counter += 1
    # Check for probability > 0.5 and "not" not in diagnosis
    mask_high = group["Predicted Probability"] > 0.5
    for diag in group.loc[mask_high, "Predicted Diagnosis"]:
        if "not" in diag:
            counter += 1

    print(
        f"{counter}/{len(group)} predictions for system message {idx} are inconsistent with the probability."
    )
# Out:
# 100/2064 predictions for system message 0 are inconsistent with the probability.
# 1095/2064 predictions for system message 1 are inconsistent with the probability.
# 1203/2064 predictions for system message 2 are inconsistent with the probability.
# 1315/2064 predictions for system message 3 are inconsistent with the probability.
# 1650/2064 predictions for system message 4 are inconsistent with the probability.

# %% [markdown]
# Averaged Metrics over Tasks and Datasets

# %%
# Group by System Message Index and calculate metrics
df_mistral7b_grouped = (
    df_mistral7b.groupby("System Message Index")
    .apply(
        lambda x: {
            **calculate_all_metrics(
                x["Target Label"].values, x["Predicted Probability"].values
            ),
            "mcc_2": calculate_all_metrics(
                x["Target Label"].values, x["Predicted Probability Diagnosis"].values
            )["mcc"],
        }
    )
    .reset_index()
)
# Expand the metrics dictionary into separate columns
metrics_df = df_mistral7b_grouped[0].apply(pd.Series)
df_mistral7b_grouped = pd.concat(
    [df_mistral7b_grouped.drop(columns=0), metrics_df], axis=1
)
df_mistral7b_grouped["model_id"] = "Mistral-7B"
# Display the grouped DataFrame
df_mistral7b_grouped
# Out:
# C:\Users\janbe\AppData\Local\Temp\ipykernel_39200\2460239889.py:4: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(
#    System Message Index  auroc  auprc  normalized_auprc  pulse_score  \
# 0                     0  0.481  0.163             0.940       37.933
# 1                     1  0.705  0.443             2.548       59.974
# 2                     2  0.369  0.150             0.864       35.398
# 3                     3  0.369  0.152             0.877       35.148
# 4                     4  0.500  0.237             1.365       44.021
#
#    specificity  f1_score  accuracy  balanced_accuracy  precision  recall  \
# 0        0.787     0.174     0.683              0.489      0.159   0.192
# 1        0.523     0.420     0.583              0.696      0.277   0.869
# 2        0.875     0.215     0.756              0.534      0.245   0.192
# 3        0.884     0.192     0.759              0.524      0.230   0.164
# 4        0.714     0.338     0.673              0.597      0.261   0.479
#
#      mcc  kappa  minpse  mcc_2    model_id
# 0 -0.020 -0.020   0.174  0.014  Mistral-7B
# 1  0.299  0.213   0.304  0.118  Mistral-7B
# 2  0.074  0.073   0.192  0.132  Mistral-7B
# 3  0.056  0.055   0.174  0.095  Mistral-7B
# 4  0.157  0.145   0.261  0.153  Mistral-7B

# %% [markdown]
# ### Llama-3 8B
#
# Summary:
# - System message 0 has best performance
# - System Message 0 does not reply with correct label
# - probability and label consistent for all samples

# %%
df_llama3_8b = get_predictions_by_model(df_metadata, "Llama3")
df_llama3_8b.head()
# Out:
#                                             Input Prompt  Target Label  \
# 10311  You are an experienced doctor in Intensive Car...             0
# 10312  You are an experienced doctor in Intensive Car...             0
# 10313  You are an experienced doctor in Intensive Car...             0
# 10314  You are an experienced doctor in Intensive Car...             0
# 10315  You are an experienced doctor in Intensive Car...             0
#
#        Predicted Probability Predicted Diagnosis  \
# 10311                   0.00       not-diagnosis
# 10312                   0.00             not-aki
# 10313                   0.05             not-aki
# 10314                   0.05             not-aki
# 10315                   0.05             not-aki
#
#                                    Predicted Explanation  Tokenization Time  \
# 10311  Based on the provided data, the patient's crea...           0.006283
# 10312  Kidney function stable: creatinine 0.9 mg/dL (...           0.005769
# 10313  Kidney function stable: creatinine 0.9 mg/dL (...           0.005815
# 10314  Kidney function stable: creatinine 0.9 mg/dL (...           0.005694
# 10315  Kidney function stable: creatinine 0.9 mg/dL (...           0.005774
#
#        Inference Time  Input Tokens  Output Tokens  \
# 10311        2.981291          3155             95
# 10312        1.995243          3315             61
# 10313        2.001122          3400             61
# 10314        2.054575          3431             63
# 10315        2.038414          3502             61
#
#                                           System Message  \
# 10311  You are a helpful assistant and experienced me...
# 10312  You are a helpful assistant and experienced me...
# 10313  You are a helpful assistant and experienced me...
# 10314  You are a helpful assistant and experienced me...
# 10315  You are a helpful assistant and experienced me...
#
#        System Message Index model_name task dataset        timestamp  \
# 10311                     0     Llama3  aki    eicu  20250608_181930
# 10312                     1     Llama3  aki    eicu  20250608_181930
# 10313                     2     Llama3  aki    eicu  20250608_181930
# 10314                     3     Llama3  aki    eicu  20250608_181930
# 10315                     4     Llama3  aki    eicu  20250608_181930
#
#        Predicted Probability from Diagnosis
# 10311                                   0.0
# 10312                                   0.0
# 10313                                   0.0
# 10314                                   0.0
# 10315                                   0.0

# %%
counter = 0
for idx, group in df_llama3_8b.groupby("System Message Index"):
    # Check for probability < 0.5 and "not" not in diagnosis
    mask_low = group["Predicted Probability"] < 0.5
    for diag in group.loc[mask_low, "Predicted Diagnosis"]:
        if "not" not in diag:
            counter += 1
    # Check for probability > 0.5 and "not" not in diagnosis
    mask_high = group["Predicted Probability"] > 0.5
    for diag in group.loc[mask_high, "Predicted Diagnosis"]:
        if "not" in diag:
            counter += 1

    print(
        f"{counter}/{len(group)} predictions for system message {idx} are inconsistent with the probability."
    )
# Out:
# 0/2064 predictions for system message 0 are inconsistent with the probability.
# 0/2064 predictions for system message 1 are inconsistent with the probability.
# 0/2064 predictions for system message 2 are inconsistent with the probability.
# 0/2064 predictions for system message 3 are inconsistent with the probability.
# 0/2064 predictions for system message 4 are inconsistent with the probability.

# %% [markdown]
# Averaged Metrics over Tasks and Datasets

# %%
# Group by System Message Index and calculate metrics
df_llama3_8b_grouped = (
    df_llama3_8b.groupby("System Message Index")
    .apply(
        lambda x: calculate_all_metrics(
            x["Target Label"].values, x["Predicted Probability"].values
        )
    )
    .reset_index()
)
# Expand the metrics dictionary into separate columns
metrics_df = df_llama3_8b_grouped[0].apply(pd.Series)
df_llama3_8b_grouped = pd.concat(
    [df_llama3_8b_grouped.drop(columns=0), metrics_df], axis=1
)
# Display the grouped DataFrame
df_llama3_8b_grouped
# Out:
# C:\Users\janbe\AppData\Local\Temp\ipykernel_39200\2564300095.py:4: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(
#    System Message Index  auroc  auprc  normalized_auprc  pulse_score  \
# 0                     0  0.510  0.396             2.275       45.731
# 1                     1  0.367  0.142             0.815       30.138
# 2                     2  0.308  0.149             0.859       28.870
# 3                     3  0.324  0.166             0.952       29.719
# 4                     4  0.369  0.179             1.029       31.640
#
#    specificity  f1_score  accuracy  balanced_accuracy  precision  recall  \
# 0        0.319     0.247     0.367              0.458      0.156   0.596
# 1        0.565     0.098     0.494              0.362      0.071   0.159
# 2        0.608     0.102     0.529              0.380      0.076   0.153
# 3        0.523     0.122     0.469              0.367      0.085   0.212
# 4        0.365     0.170     0.366              0.369      0.110   0.373
#
#      mcc  kappa  minpse
# 0 -0.068 -0.040   0.207
# 1 -0.215 -0.186   0.174
# 2 -0.190 -0.171   0.174
# 3 -0.203 -0.168   0.174
# 4 -0.202 -0.135   0.174

# %% [markdown]
# ### Gemma 3
#
# Summary:
# - System Message 1 was not sufficient for the model to understand how to phrase the output
# - long inference time of ca. 40sec
# - System Message 2 with the best performance
# - many misclassified samples (probabilities and label not matching)

# %%
df_gemma3_12b = get_predictions_by_model(df_metadata, "Gemma3")
df_gemma3_12b.tail()
# Out:
#       Input Prompt  Target Label  Predicted Probability Predicted Diagnosis  \
# 10306          NaN             0                   0.85           diagnosis
# 10307          NaN             0                   0.78              sepsis
# 10308          NaN             0                   0.78              sepsis
# 10309          NaN             0                   0.78              sepsis
# 10310          NaN             0                   0.78              sepsis
#
#                                    Predicted Explanation  Tokenization Time  \
# 10306  The patient exhibits several concerning signs ...             0.0034
# 10307  Patient exhibits concerning signs suggestive o...             0.0036
# 10308  Patient exhibits concerning signs for sepsis. ...             0.0037
# 10309  Patient exhibits concerning signs for sepsis. ...             0.0040
# 10310  Patient exhibits concerning signs suggestive o...             0.0039
#
#        Inference Time  Input Tokens  Output Tokens System Message  \
# 10306          8.2341          3803            300            NaN
# 10307          8.2341          3998            300            NaN
# 10308          8.3317          4093            300            NaN
# 10309          8.3617          4125            300            NaN
# 10310          8.3856          4201            300            NaN
#
#        System Message Index model_name    task dataset        timestamp  \
# 10306                     0     Gemma3  sepsis    eicu  20250608_180109
# 10307                     1     Gemma3  sepsis    eicu  20250608_180109
# 10308                     2     Gemma3  sepsis    eicu  20250608_180109
# 10309                     3     Gemma3  sepsis    eicu  20250608_180109
# 10310                     4     Gemma3  sepsis    eicu  20250608_180109
#
#        Predicted Probability from Diagnosis
# 10306                                   1.0
# 10307                                   1.0
# 10308                                   1.0
# 10309                                   1.0
# 10310                                   1.0

# %%
counter = 0
for idx, group in df_gemma3_12b.groupby("System Message Index"):
    # Check for probability < 0.5 and "not" not in diagnosis
    mask_low = group["Predicted Probability"] < 0.5
    for diag in group.loc[mask_low, "Predicted Diagnosis"]:
        if "not" not in diag:
            counter += 1
    # Check for probability > 0.5 and "not" not in diagnosis
    mask_high = group["Predicted Probability"] > 0.5
    for diag in group.loc[mask_high, "Predicted Diagnosis"]:
        if "not" in diag:
            counter += 1

    print(
        f"{counter}/{len(df_gemma3_12b)} predictions for system message {idx} are inconsistent with the probability."
    )
# Out:
# 99/10311 predictions for system message 0 are inconsistent with the probability.
# 132/10311 predictions for system message 1 are inconsistent with the probability.
# 172/10311 predictions for system message 2 are inconsistent with the probability.
# 228/10311 predictions for system message 3 are inconsistent with the probability.
# 304/10311 predictions for system message 4 are inconsistent with the probability.

# %% [markdown]
# ### DeepSeek-R1-Distill-Llama-8B
#
# Summary:
# - System message 1 with best performance
# - a lot of inconsisten probability/label pairs

# %%
df_deepseekr1_llama8b = get_predictions_by_model(df_metadata, "DeepseekR1Llama8b")
df_deepseekr1_llama8b.head()
# Out:
#                                             Input Prompt  Target Label  \
# 30951  You are an experienced doctor in Intensive Car...             0
# 30952  You are an experienced doctor in Intensive Car...             0
# 30953  You are an experienced doctor in Intensive Car...             0
# 30954  You are an experienced doctor in Intensive Car...             0
# 30955  You are an experienced doctor in Intensive Car...             0
#
#        Predicted Probability Predicted Diagnosis  \
# 30951                   0.00       not-diagnosis
# 30952                   0.10             not-aki
# 30953                   0.20             not-aki
# 30954                   0.20             not-aki
# 30955                   0.08             not-aki
#
#                                    Predicted Explanation  Tokenization Time  \
# 30951  The patient's serum creatinine and blood urea ...           0.006719
# 30952  Kidney function appears stable: creatinine rem...           0.005799
# 30953  Urine output remains above the threshold, and ...           0.005626
# 30954  Creatinine and BUN within normal limits, urine...           0.005679
# 30955  Kidney function stable: creatinine 0.90 mg/dL ...           0.005858
#
#        Inference Time  Input Tokens  Output Tokens  \
# 30951       18.120857          3125            762
# 30952       17.041536          3285            712
# 30953       18.262427          3370            765
# 30954       14.153721          3401            592
# 30955       14.778650          3472            616
#
#                                           System Message  \
# 30951  You are a helpful assistant and experienced me...
# 30952  You are a helpful assistant and experienced me...
# 30953  You are a helpful assistant and experienced me...
# 30954  You are a helpful assistant and experienced me...
# 30955  You are a helpful assistant and experienced me...
#
#        System Message Index         model_name task dataset        timestamp  \
# 30951                     0  DeepseekR1Llama8b  aki    eicu  20250613_112431
# 30952                     1  DeepseekR1Llama8b  aki    eicu  20250613_112431
# 30953                     2  DeepseekR1Llama8b  aki    eicu  20250613_112431
# 30954                     3  DeepseekR1Llama8b  aki    eicu  20250613_112431
# 30955                     4  DeepseekR1Llama8b  aki    eicu  20250613_112431
#
#        Predicted Probability from Diagnosis
# 30951                                   0.0
# 30952                                   0.0
# 30953                                   0.0
# 30954                                   0.0
# 30955                                   0.0

# %%
counter = 0
for idx, group in df_gemma3_12b.groupby("System Message Index"):
    # Check for probability < 0.5 and "not" not in diagnosis
    mask_low = group["Predicted Probability"] < 0.5
    for diag in group.loc[mask_low, "Predicted Diagnosis"]:
        if "not" not in diag:
            counter += 1
    # Check for probability > 0.5 and "not" not in diagnosis
    mask_high = group["Predicted Probability"] > 0.5
    for diag in group.loc[mask_high, "Predicted Diagnosis"]:
        if "not" in diag:
            counter += 1

    print(
        f"{counter}/{len(df_gemma3_12b)} predictions for system message {idx} are inconsistent with the probability."
    )
# Out:
# 99/10311 predictions for system message 0 are inconsistent with the probability.
# 132/10311 predictions for system message 1 are inconsistent with the probability.
# 172/10311 predictions for system message 2 are inconsistent with the probability.
# 228/10311 predictions for system message 3 are inconsistent with the probability.
# 304/10311 predictions for system message 4 are inconsistent with the probability.

# %% [markdown]
# Averaged Metrics over Tasks and Datasets

# %%
# Group by System Message Index and calculate metrics
df_deepseekr1_llama8b_grouped = (
    df_deepseekr1_llama8b.groupby("System Message Index")
    .apply(
        lambda x: calculate_all_metrics(
            x["Target Label"].values, x["Predicted Probability"].values
        )
    )
    .reset_index()
)
# Expand the metrics dictionary into separate columns
metrics_df = df_deepseekr1_llama8b_grouped[0].apply(pd.Series)
df_deepseekr1_llama8b_grouped = pd.concat(
    [df_deepseekr1_llama8b_grouped.drop(columns=0), metrics_df], axis=1
)
# Display the grouped DataFrame
df_deepseekr1_llama8b_grouped
# Out:
# C:\Users\janbe\AppData\Local\Temp\ipykernel_39200\1958634007.py:4: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(
#    System Message Index  auroc  auprc  normalized_auprc  pulse_score  \
# 0                     0  0.491  0.179             1.029       38.846
# 1                     1  0.477  0.197             1.130       39.170
# 2                     2  0.487  0.189             1.089       39.362
# 3                     3  0.494  0.193             1.111       39.915
# 4                     4  0.525  0.207             1.192       41.979
#
#    specificity  f1_score  accuracy  balanced_accuracy  precision  recall  \
# 0        0.619     0.228     0.574              0.490      0.167   0.362
# 1        0.672     0.224     0.611              0.497      0.172   0.323
# 2        0.666     0.230     0.609              0.501      0.175   0.337
# 3        0.693     0.232     0.629              0.508      0.182   0.323
# 4        0.715     0.254     0.650              0.529      0.202   0.343
#
#      mcc  kappa  minpse
# 0 -0.015 -0.013   0.177
# 1 -0.004 -0.004   0.217
# 2  0.002  0.002   0.200
# 3  0.013  0.013   0.213
# 4  0.048  0.045   0.243

# %% [markdown]
# ---
# ## Distribution of predicted probabilities when using System Message N for all models and tasks

# %%
from src.eval.llm_analyzer import LLMAnalyzer

# %%
# Plot distribution of predicted probabilities for each model and system message using LLMAnalyzer
for model in df_metadata["model_name"].unique():
    print(f"\n{'='*60}")
    print(f"Model: {model}")
    print(f"{'='*60}")
    
    # Get data for this model
    df_model = df_metadata[df_metadata["model_name"] == model]
    
    # Plot for each system message
    for sysmsg_idx in sorted(df_model["System Message Index"].unique()):
        df_model_sysmsg = df_model[df_model["System Message Index"] == sysmsg_idx]
        
        print(f"\nSystem Message Index: {sysmsg_idx} (n={len(df_model_sysmsg)})")
        print(f"Title: {model} - System Message {sysmsg_idx}")
        
        # Use LLMAnalyzer to create density distribution plot
        plot = LLMAnalyzer.plot_density_distribution_all_tasks(
            df_model_sysmsg, 
            figsize=(12, 4), 
            ylim=(0, 10)
        )
        
        # Print some basic statistics
        mean_prob = df_model_sysmsg['Predicted Probability'].mean()
        median_prob = df_model_sysmsg['Predicted Probability'].median()
        std_prob = df_model_sysmsg['Predicted Probability'].std()
        unique_vals = df_model_sysmsg['Predicted Probability'].nunique()
        
        print(f"  - Mean probability: {mean_prob:.3f}")
        print(f"  - Median probability: {median_prob:.3f}")
        print(f"  - Standard deviation: {std_prob:.3f}")
        print(f"  - Unique probability values: {unique_vals}")
        print(f"  - Min: {df_model_sysmsg['Predicted Probability'].min():.3f}")
        print(f"  - Max: {df_model_sysmsg['Predicted Probability'].max():.3f}")
        
        # Show distribution of target labels for context
        target_dist = df_model_sysmsg['Target Label'].value_counts()
        print(f"  - Target distribution: {target_dist.to_dict()}")
        print(f"  - Tasks in data: {df_model_sysmsg['task'].unique()}")
        print(f"  - Datasets in data: {df_model_sysmsg['dataset'].unique()}")
# Out:
# ============================================================
# Model: Gemma3
# ============================================================
#
# System Message Index: 0 (n=2063)
# Title: Gemma3 - System Message 0
#   - Mean probability: 0.910
#   - Median probability: 0.950
#   - Standard deviation: 0.064
#   - Unique probability values: 8
#   - Min: 0.250
#   - Max: 0.950
#   - Target distribution: {0: 1704, 1: 359}
#   - Tasks in data: ['aki' 'mortality' 'sepsis']
#   - Datasets in data: ['eicu']
#
# System Message Index: 1 (n=2062)
# Title: Gemma3 - System Message 1
#   - Mean probability: 0.823
#   - Median probability: 0.950
#   - Standard deviation: 0.203
#   - Unique probability values: 11
#   - Min: 0.250
#   - Max: 0.980
#   - Target distribution: {0: 1703, 1: 359}
#   - Tasks in data: ['aki' 'mortality' 'sepsis']
#   - Datasets in data: ['eicu']
#
# System Message Index: 2 (n=2062)
# Title: Gemma3 - System Message 2
#   - Mean probability: 0.785
#   - Median probability: 0.780
#   - Standard deviation: 0.152
#   - Unique probability values: 13
#   - Min: 0.250
#   - Max: 0.980
#   - Target distribution: {0: 1703, 1: 359}
#   - Tasks in data: ['aki' 'mortality' 'sepsis']
#   - Datasets in data: ['eicu']
#
# System Message Index: 3 (n=2062)
# Title: Gemma3 - System Message 3
#   - Mean probability: 0.790
#   - Median probability: 0.780
#   - Standard deviation: 0.144
#   - Unique probability values: 13
#   - Min: 0.250
#   - Max: 0.980
#   - Target distribution: {0: 1703, 1: 359}
#   - Tasks in data: ['aki' 'mortality' 'sepsis']
#   - Datasets in data: ['eicu']
#
# System Message Index: 4 (n=2062)
# Title: Gemma3 - System Message 4
#   - Mean probability: 0.796
#   - Median probability: 0.780
#   - Standard deviation: 0.124
#   - Unique probability values: 10
#   - Min: 0.250
#   - Max: 0.980
#   - Target distribution: {0: 1703, 1: 359}
#   - Tasks in data: ['aki' 'mortality' 'sepsis']
#   - Datasets in data: ['eicu']
#
# ============================================================
# Model: Llama3
# ============================================================
#
# System Message Index: 0 (n=2064)
# Title: Llama3 - System Message 0
#   - Mean probability: 0.610
#   - Median probability: 0.850
#   - Standard deviation: 0.434
#   - Unique probability values: 3
#   - Min: 0.000
#   - Max: 0.950
#   - Target distribution: {0: 1705, 1: 359}
#   - Tasks in data: ['aki' 'mortality' 'sepsis']
#   - Datasets in data: ['eicu']
#
# System Message Index: 1 (n=2064)
# Title: Llama3 - System Message 1
#   - Mean probability: 0.333
#   - Median probability: 0.000
#   - Standard deviation: 0.419
#   - Unique probability values: 4
#   - Min: 0.000
#   - Max: 0.950
#   - Target distribution: {0: 1705, 1: 359}
#   - Tasks in data: ['aki' 'mortality' 'sepsis']
#   - Datasets in data: ['eicu']
#
# System Message Index: 2 (n=2064)
# Title: Llama3 - System Message 2
#   - Mean probability: 0.376
#   - Median probability: 0.200
#   - Standard deviation: 0.387
#   - Unique probability values: 9
#   - Min: 0.050
#   - Max: 0.950
#   - Target distribution: {0: 1705, 1: 359}
#   - Tasks in data: ['aki' 'mortality' 'sepsis']
#   - Datasets in data: ['eicu']
#
# System Message Index: 3 (n=2064)
# Title: Llama3 - System Message 3
#   - Mean probability: 0.435
#   - Median probability: 0.200
#   - Standard deviation: 0.409
#   - Unique probability values: 9
#   - Min: 0.050
#   - Max: 0.950
#   - Target distribution: {0: 1705, 1: 359}
#   - Tasks in data: ['aki' 'mortality' 'sepsis']
#   - Datasets in data: ['eicu']
#
# System Message Index: 4 (n=2064)
# Title: Llama3 - System Message 4
#   - Mean probability: 0.548
#   - Median probability: 0.850
#   - Standard deviation: 0.406
#   - Unique probability values: 10
#   - Min: 0.020
#   - Max: 0.950
#   - Target distribution: {0: 1705, 1: 359}
#   - Tasks in data: ['aki' 'mortality' 'sepsis']
#   - Datasets in data: ['eicu']
#
# ============================================================
# Model: Mistral
# ============================================================
#
# System Message Index: 0 (n=2064)
# Title: Mistral - System Message 0
#   - Mean probability: 0.184
#   - Median probability: 0.000
#   - Standard deviation: 0.354
#   - Unique probability values: 7
#   - Min: 0.000
#   - Max: 0.950
#   - Target distribution: {0: 1705, 1: 359}
#   - Tasks in data: ['aki' 'mortality' 'sepsis']
#   - Datasets in data: ['eicu']
#
# System Message Index: 1 (n=2064)
# Title: Mistral - System Message 1
#   - Mean probability: 0.572
#   - Median probability: 0.850
#   - Standard deviation: 0.415
#   - Unique probability values: 8
#   - Min: 0.120
#   - Max: 0.990
#   - Target distribution: {0: 1705, 1: 359}
#   - Tasks in data: ['aki' 'mortality' 'sepsis']
#   - Datasets in data: ['eicu']
#
# System Message Index: 2 (n=2064)
# Title: Mistral - System Message 2
#   - Mean probability: 0.202
#   - Median probability: 0.120
#   - Standard deviation: 0.247
#   - Unique probability values: 11
#   - Min: 0.020
#   - Max: 0.950
#   - Target distribution: {0: 1705, 1: 359}
#   - Tasks in data: ['aki' 'mortality' 'sepsis']
#   - Datasets in data: ['eicu']
#
# System Message Index: 3 (n=2064)
# Title: Mistral - System Message 3
#   - Mean probability: 0.196
#   - Median probability: 0.120
#   - Standard deviation: 0.241
#   - Unique probability values: 10
#   - Min: 0.020
#   - Max: 0.950
#   - Target distribution: {0: 1705, 1: 359}
#   - Tasks in data: ['aki' 'mortality' 'sepsis']
#   - Datasets in data: ['eicu']
#
# System Message Index: 4 (n=2064)
# Title: Mistral - System Message 4
#   - Mean probability: 0.341
#   - Median probability: 0.120
#   - Standard deviation: 0.344
#   - Unique probability values: 13
#   - Min: 0.010
#   - Max: 0.950
#   - Target distribution: {0: 1705, 1: 359}
#   - Tasks in data: ['aki' 'mortality' 'sepsis']
#   - Datasets in data: ['eicu']
#
# ============================================================
# Model: DeepseekR1Llama8b
# ============================================================
#
# System Message Index: 0 (n=2064)
# Title: DeepseekR1Llama8b - System Message 0
#   - Mean probability: 0.337
#   - Median probability: 0.100
#   - Standard deviation: 0.382
#   - Unique probability values: 15
#   - Min: 0.000
#   - Max: 1.000
#   - Target distribution: {0: 1705, 1: 359}
#   - Tasks in data: ['aki' 'mortality' 'sepsis']
#   - Datasets in data: ['eicu']
#
# System Message Index: 1 (n=2064)
# Title: DeepseekR1Llama8b - System Message 1
#   - Mean probability: 0.347
#   - Median probability: 0.150
#   - Standard deviation: 0.322
#   - Unique probability values: 23
#   - Min: 0.080
#   - Max: 1.000
#   - Target distribution: {0: 1705, 1: 359}
#   - Tasks in data: ['aki' 'mortality' 'sepsis']
#   - Datasets in data: ['eicu']
#
# System Message Index: 2 (n=2064)
# Title: DeepseekR1Llama8b - System Message 2
#   - Mean probability: 0.368
#   - Median probability: 0.200
#   - Standard deviation: 0.287
#   - Unique probability values: 22
#   - Min: 0.080
#   - Max: 0.900
#   - Target distribution: {0: 1705, 1: 359}
#   - Tasks in data: ['aki' 'mortality' 'sepsis']
#   - Datasets in data: ['eicu']
#
# System Message Index: 3 (n=2064)
# Title: DeepseekR1Llama8b - System Message 3
#   - Mean probability: 0.363
#   - Median probability: 0.200
#   - Standard deviation: 0.273
#   - Unique probability values: 23
#   - Min: 0.050
#   - Max: 0.950
#   - Target distribution: {0: 1705, 1: 359}
#   - Tasks in data: ['aki' 'mortality' 'sepsis']
#   - Datasets in data: ['eicu']
#
# System Message Index: 4 (n=2064)
# Title: DeepseekR1Llama8b - System Message 4
#   - Mean probability: 0.355
#   - Median probability: 0.200
#   - Standard deviation: 0.265
#   - Unique probability values: 24
#   - Min: 0.050
#   - Max: 0.900
#   - Target distribution: {0: 1705, 1: 359}
#   - Tasks in data: ['aki' 'mortality' 'sepsis']
#   - Datasets in data: ['eicu']

# %% [markdown]
# ---
# ## System Messages in DataFrame

# %%
# You are a helpful assistant and experienced medical professional analyzing ICU time-series data for detecting acute kidney injury (AKI) ≥ stage 1 according to KDIGO 2012 criteria.

# Your response must strictly follow this format:
# Output a valid JSON object with three keys: 'diagnosis', 'probability' and 'explanation'.

# 1. 'diagnosis' a string with either 'diagnosis' or 'not-diagnosis'
# 2. 'probability' an integer between 0 and 100, where 0 means not diagnosed and 100 means diagnosed.
# 3. 'explanation' should be a string providing a brief explanation of your diagnosis.

# Do not include any other text or explanations outside of the JSON object.
# Think about the probability of your prediction carefully before answering.

# %%
# You are a helpful assistant and experienced medical professional analyzing ICU time-series data for detecting acute kidney injury (AKI) ≥ stage 1 according to KDIGO 2012 criteria.

# Your response must strictly follow this format:
# Output a valid JSON object with three keys: 'diagnosis', 'probability' and 'explanation'.

# 1. 'diagnosis' a string with either 'diagnosis' or 'not-diagnosis'
# 2. 'probability' an integer between 0 and 100, where 0 means not diagnosed and 100 means diagnosed.
# 3. 'explanation' should be a string providing a brief explanation of your diagnosis.

# Here is a positive example:
# {
#   "diagnosis": "aki",
#   "probability": "89",
#   "explanation": "Acute kidney injury evident: serum creatinine increased from baseline 1.1 to 2.7 mg/dL within 24 hours (>2x increase), urine output decreased to 0.3 mL/kg/h over 6 hours, meeting KDIGO Stage 2 criteria."
# }

# Here is a negative example:
# {
#   "diagnosis": "not-aki",
#   "probability": "8",
#   "explanation": "Kidney function stable: creatinine 1.3 mg/dL (minimal change from baseline 1.2), adequate urine output at 1.1 mL/kg/h, no signs of acute kidney injury."
# }

# Do not include any other text or explanations outside of the JSON object.
# Think about the probability of your prediction carefully before answering.

# %%
# You are a helpful assistant and experienced medical professional analyzing ICU time-series data for detecting acute kidney injury (AKI) ≥ stage 1 according to KDIGO 2012 criteria.

# Your response must strictly follow this format:
# Output a valid JSON object with three keys: 'diagnosis', 'probability' and 'explanation'.

# 1. 'diagnosis' a string with either 'diagnosis' or 'not-diagnosis'
# 2. 'probability' an integer between 0 and 100, where 0 means not diagnosed and 100 means diagnosed.
# 3. 'explanation' should be a string providing a brief explanation of your diagnosis.

# Here is a positive example:
# {
#   "diagnosis": "aki",
#   "probability": "89",
#   "explanation": "Acute kidney injury evident: serum creatinine increased from baseline 1.1 to 2.7 mg/dL within 24 hours (>2x increase), urine output decreased to 0.3 mL/kg/h over 6 hours, meeting KDIGO Stage 2 criteria."
# }

# Here is a negative example:
# {
#   "diagnosis": "not-aki",
#   "probability": "8",
#   "explanation": "Kidney function stable: creatinine 1.3 mg/dL (minimal change from baseline 1.2), adequate urine output at 1.1 mL/kg/h, no signs of acute kidney injury."
# }

# CRITICAL: Probability calibration guidelines:
# - 0-20: Very unlikely, clear absence of condition with normal parameters
# - 20-40: Unlikely, some concerning signs but insufficient evidence
# - 40-60: Uncertain, mixed evidence or borderline findings
# - 60-80: Likely, multiple indicators support diagnosis
# - 80-100: Very likely, strong evidence with clear clinical criteria met

# Do not include any other text or explanations outside of the JSON object.
# Think about the probability of your prediction carefully before answering.

# %%
# You are a helpful assistant and experienced medical professional analyzing ICU time-series data for detecting acute kidney injury (AKI) ≥ stage 1 according to KDIGO 2012 criteria.

# Your response must strictly follow this format:
# Output a valid JSON object with three keys: 'diagnosis', 'probability' and 'explanation'.

# 1. 'diagnosis' a string with either 'diagnosis' or 'not-diagnosis'
# 2. 'probability' an integer between 0 and 100, where 0 means not diagnosed and 100 means diagnosed.
# 3. 'explanation' should be a string providing a brief explanation of your diagnosis.

# Here is a positive example:
# {
#   "diagnosis": "aki",
#   "probability": "89",
#   "explanation": "Acute kidney injury evident: serum creatinine increased from baseline 1.1 to 2.7 mg/dL within 24 hours (>2x increase), urine output decreased to 0.3 mL/kg/h over 6 hours, meeting KDIGO Stage 2 criteria."
# }

# Here is a negative example:
# {
#   "diagnosis": "not-aki",
#   "probability": "8",
#   "explanation": "Kidney function stable: creatinine 1.3 mg/dL (minimal change from baseline 1.2), adequate urine output at 1.1 mL/kg/h, no signs of acute kidney injury."
# }

# CRITICAL: Probability calibration guidelines:
# - 0-20: Very unlikely, clear absence of condition with normal parameters
# - 20-40: Unlikely, some concerning signs but insufficient evidence
# - 40-60: Uncertain, mixed evidence or borderline findings
# - 60-80: Likely, multiple indicators support diagnosis
# - 80-100: Very likely, strong evidence with clear clinical criteria met

# Note: ICU patients often present with abnormal baseline values due to their critical condition. Consider the clinical context and severity of deviations when assessing for the target condition.

# Do not include any other text or explanations outside of the JSON object.
# Think about the probability of your prediction carefully before answering.

# %%
# You are a helpful assistant and experienced medical professional analyzing ICU time-series data for detecting acute kidney injury (AKI) ≥ stage 1 according to KDIGO 2012 criteria.

# Your response must strictly follow this format:
# Output a valid JSON object with three keys: 'diagnosis', 'probability' and 'explanation'.

# 1. 'diagnosis' a string with either 'diagnosis' or 'not-diagnosis'
# 2. 'probability' an integer between 0 and 100, where 0 means not diagnosed and 100 means diagnosed.
# 3. 'explanation' should be a string providing a brief explanation of your diagnosis.

# Here is a positive example:
# {
#   "diagnosis": "aki",
#   "probability": "89",
#   "explanation": "Acute kidney injury evident: serum creatinine increased from baseline 1.1 to 2.7 mg/dL within 24 hours (>2x increase), urine output decreased to 0.3 mL/kg/h over 6 hours, meeting KDIGO Stage 2 criteria."
# }

# Here is a negative example:
# {
#   "diagnosis": "not-aki",
#   "probability": "8",
#   "explanation": "Kidney function stable: creatinine 1.3 mg/dL (minimal change from baseline 1.2), adequate urine output at 1.1 mL/kg/h, no signs of acute kidney injury."
# }

# CRITICAL: Probability calibration guidelines:
# - 0-20: Very unlikely, clear absence of condition with normal parameters
# - 20-40: Unlikely, some concerning signs but insufficient evidence
# - 40-60: Uncertain, mixed evidence or borderline findings
# - 60-80: Likely, multiple indicators support diagnosis
# - 80-100: Very likely, strong evidence with clear clinical criteria met

# --- JSON Schema ---
# {
#   "diagnosis": "string"  // Must be either "aki" or "not-aki"
#   "probability": "integer" // Value between 0 (no diagnosis) and 100 (definite diagnosis)
#   "explanation": "string" // Concise clinical reasoning for the diagnosis and probability
# }

# Note: ICU patients often present with abnormal baseline values due to their critical condition. Consider the clinical context and severity of deviations when assessing for the target condition.

# Do not include any other text or explanations outside of the JSON object.
# Think about the probability of your prediction carefully before answering.
