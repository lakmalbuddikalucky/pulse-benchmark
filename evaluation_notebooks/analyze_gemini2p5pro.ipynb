# %% [markdown]
# # Gemini 2.5 Pro
# ---
#
# | Parameter         | Value                                         | Description                                                                                 |
# |-------------------|-----------------------------------------------|---------------------------------------------------------------------------------------------|
# | mode              | inference                                     | Mode of operation (inference, training)                                                     |
# | model_id          | gemini-2.5-flash-preview-05-20                | Model ID                                                                                    |
# | type              | LLM                                           | Type of model (convML for conventional ML, convDL for deep learning, LLM for large language models) |
# | verbose           | 2                                             | Verbosity level                                                                             |
# | max_new_tokens    | 300                                           | Maximum number of new tokens to generate                                                    |
# | max_length        | 30000                                         | Maximum length of input sequences                                                           |
# | temperature       | 0.4                                           | Temperature for sampling (0.0 = greedy sampling)                                            |
# | thinking_budget   | 1500                                             | 0 = no thinking budget, -1 = dynamic thinking budget                                        |

# %%
# Imports
import os
import sys
import pandas as pd
import ipywidgets as widgets
from IPython.display import display

sys.path.append(r"C:\Users\janbe\OneDrive\Dokumente\GitRepos\pulse")
from src.eval.llm_analyzer import LLMAnalyzer
from src.eval.pulse_score import PULSEScoreCalculator

# %% [markdown]
# ## Analysis of different prompting approaches
# ---

# %%
model_id = "gemini2p5pro"
base_output_dir = (
    r"C:\Users\janbe\OneDrive\Dokumente\GitRepos\pulse\output_to_keep\results_benchmark"
)
model_output_dir = os.path.join(base_output_dir, "llms", model_id)
results_output_dir = os.path.join(base_output_dir, r"results_output")
results_output_jsons = os.path.join(results_output_dir, "jsons")
results_json_path = f"{model_id}_results.json"

prompt_approaches = os.listdir(model_output_dir)
for i, approach in enumerate(prompt_approaches, 1):
    print(f"{i}. {approach}")


best_prompt_approach = None
results_dict = {}
mdata_dict = {}
cost_df = pd.DataFrame()

for prompt_approach in prompt_approaches:

    if not os.path.isdir(os.path.join(model_output_dir, prompt_approach)):
        continue

    print("=" * 50)
    print(f"\nPrompting Approach {prompt_approach}\n")

    cat_files = LLMAnalyzer.categorize_files(
        [os.path.join(model_output_dir, prompt_approach)],
        verbose=False,
    )

    df_mdata = LLMAnalyzer.load_metadata(
        cat_files["metadata_files"], verbose=True
    )

    summary = LLMAnalyzer.print_approach_summary(
        df_mdata, input_token_cost=1.25, output_token_cost=10
    )

    # Filter for final prediction step if agent is used
    if "Step Name" in df_mdata.columns:
        df_mdata = df_mdata[df_mdata["Step Name"] == "final_prediction"].reset_index(
            drop=True
        )

    ps = PULSEScoreCalculator()
    pulse_score = ps.calculate_pulse_score_from_raw_data(
        df=df_mdata,
    )
    pulse_score["model_id"] = model_id
    pulse_score["prompting_id"] = prompt_approach
    pulse_score_temp = pulse_score["overall"]["overall_score"]
    results_dict[prompt_approach] = pulse_score
    mdata_dict[prompt_approach] = df_mdata
    cost_df[prompt_approach] = [
        summary["input_cost"].sum(),
        summary["output_cost"].sum(),
        summary["thinking_cost"].sum(),
        summary["total_cost"].sum(),
    ]

    cost_df.index = ["input_cost", "output_cost", "thinking_cost", "total_cost"]
    if best_prompt_approach is None or pulse_score_temp > best_prompt_approach[1]:

        best_prompt_approach = (prompt_approach, pulse_score_temp)

display(cost_df)
print(
    f"\nBest prompt approach: {best_prompt_approach[0]} with PULSE score: {best_prompt_approach[1]}"
)

# Save results as json. Uses pulse-result format
json_output_path = os.path.join(results_output_jsons, f"{model_id}_results.json")
final_json = LLMAnalyzer.save_results_dict_as_json(results_dict, json_output_path)
# Out:
# 1. hybrid_reasoning_agent_preprocessor
# 2. zhu_2024b_zero_shot_preprocessor
# ==================================================
#
# Prompting Approach hybrid_reasoning_agent_preprocessor
#
# Extracting metadata from files:
# Model Name: Gemini2p5pro, Task: aki, Dataset: eicu, Timestamp: 20250712_173710
# Model Name: Gemini2p5pro, Task: aki, Dataset: hirid, Timestamp: 20250707_112055
# Model Name: Gemini2p5pro, Task: aki, Dataset: miiv, Timestamp: 20250707_112055
# Model Name: Gemini2p5pro, Task: mortality, Dataset: eicu, Timestamp: 20250707_112055
# Model Name: Gemini2p5pro, Task: mortality, Dataset: hirid, Timestamp: 20250707_112055
# Model Name: Gemini2p5pro, Task: mortality, Dataset: miiv, Timestamp: 20250707_112055
# Model Name: Gemini2p5pro, Task: sepsis, Dataset: eicu, Timestamp: 20250710_103102
# Model Name: Gemini2p5pro, Task: sepsis, Dataset: hirid, Timestamp: 20250710_103102
# Model Name: Gemini2p5pro, Task: sepsis, Dataset: miiv, Timestamp: 20250710_103102
#
# =====Overall=====:
# Number of Samples: 6188
# Number of Requests: 27392
# Total Input Tokens: 18725314
# Total Output Tokens: 3847717
# Total Thinking Tokens: 0
# Average Thinking Tokens: 0.00
# Total Cost (USD): $61.88
# =================
# Preparing data for Gemini2p5pro PULSE score calculation...
# Model Type: LLM
# ✓ No invalid predictions detected
# ✅ Data format is correct for PULSE calculation!
#
# Data distribution by task:
#
# AKI:
#   Total samples: 2950/2950
#   Positive labels: 693
#   Valid predictions: 2950
#   Positive predictions: 600.0
#   Probability range: [0.020, 1.000]
#   Probability mean: 0.273
#   Probability std: 0.289
#   Probability median: 0.130
#
# MORTALITY:
#   Total samples: 300/300
#   Positive labels: 30
#   Valid predictions: 300
#   Positive predictions: 41.0
#   Probability range: [0.020, 1.000]
#   Probability mean: 0.199
#   Probability std: 0.278
#   Probability median: 0.060
#
# SEPSIS:
#   Total samples: 2938/2939
#   Positive labels: 144
#   Valid predictions: 2938
#   Positive predictions: 787.0
#   Probability range: [0.020, 0.980]
#   Probability mean: 0.287
#   Probability std: 0.354
#   Probability median: 0.080
#
# Data types and unique values:
#   Target Label: int64, values: [0 1]
#   Predicted Diagnosis: object, values: ['not-aki' 'aki' 'not-diagnosis' 'not-mortality' 'mortality' 'sepsis'
#  'not-sepsis']
#
# Data source information:
#   • Predictions from explicit prediction column
#   • Tasks: aki, mortality, sepsis
#   • Datasets: eicu, hirid, miiv
#
# ✅ PULSE scores calculated successfully for Gemini2p5pro!
# PULSE SCORE DETAILED REPORT
# Model Type: LLM
# Weights: AUPRC=0.33, AUROC=0.33, MCC=0.34
#
# OVERALL SCORES
# --------------------------------------------------
#               Metric      Value
# 0      overall_score  51.472721
# 1        overall_aki  58.418558
# 2       overall_eicu  50.297643
# 3  overall_mortality  52.704620
# 4      overall_hirid  50.299583
# 5     overall_sepsis  43.294985
# 6       overall_miiv  53.820938
#
# TASK DATASET SCORES
# --------------------------------------------------
#                  pulse_score     auprc     auroc       mcc       ccf
# aki_eicu           61.576966  0.487018  0.714532  0.647845  0.998364
# aki_hirid          53.467523  0.280674  0.743823  0.600146  0.986242
# aki_miiv           60.211185  0.460369  0.740692  0.613081  0.995559
# mortality_eicu     46.746615  0.134503  0.771121  0.569953  0.948900
# mortality_hirid    47.619183  0.180073  0.719101  0.590614  0.957100
# mortality_miiv     63.748062  0.365654  0.810133  0.763258  0.984500
# sepsis_eicu        42.569347  0.068031  0.665385  0.547371  0.994300
# sepsis_hirid       49.812042  0.190882  0.730331  0.576420  0.996275
# sepsis_miiv        37.503567  0.030578  0.569948  0.521420  0.998879
# ==================================================
#
# Prompting Approach zhu_2024b_zero_shot_preprocessor
#
# Extracting metadata from files:
# Model Name: Gemini2p5pro, Task: aki, Dataset: eicu, Timestamp: 20250731_182349
# Model Name: Gemini2p5pro, Task: aki, Dataset: hirid, Timestamp: 20250731_182349
# Model Name: Gemini2p5pro, Task: aki, Dataset: miiv, Timestamp: 20250731_182349
# Model Name: Gemini2p5pro, Task: mortality, Dataset: eicu, Timestamp: 20250730_124402
# Model Name: Gemini2p5pro, Task: mortality, Dataset: hirid, Timestamp: 20250731_130823
# Model Name: Gemini2p5pro, Task: mortality, Dataset: miiv, Timestamp: 20250731_130823
# Model Name: Gemini2p5pro, Task: sepsis, Dataset: eicu, Timestamp: 20250731_182349
# Model Name: Gemini2p5pro, Task: sepsis, Dataset: hirid, Timestamp: 20250731_182349
# Model Name: Gemini2p5pro, Task: sepsis, Dataset: miiv, Timestamp: 20250731_182349
#
# =====Overall=====:
# Number of Samples: 6189
# Number of Requests: 6189
# Total Input Tokens: 26389475
# Total Output Tokens: 748444
# Total Thinking Tokens: 11327015
# Average Thinking Tokens: 1830.19
# Total Cost (USD): $1059.90
# =================
# Preparing data for Gemini2p5pro PULSE score calculation...
# Model Type: LLM
#
# ⚠️ Wrongly labled predictions: 2
# Wrongly labeled predictions:
#   - error: 2 occurrences
# ✅ Data format is correct for PULSE calculation!
#
# Data distribution by task:
#
# AKI:
#   Total samples: 2950/2950
#   Positive labels: 693
#   Valid predictions: 2950
#   Positive predictions: 528.0
#   Probability range: [0.020, 1.000]
#   Probability mean: 0.233
#   Probability std: 0.337
#   Probability median: 0.050
#
# MORTALITY:
#   Total samples: 300/300
#   Positive labels: 30
#   Valid predictions: 300
#   Positive predictions: 214.0
#   Probability range: [0.100, 0.980]
#   Probability mean: 0.694
#   Probability std: 0.314
#   Probability median: 0.850
#
# SEPSIS:
#   Total samples: 2939/2939
#   Positive labels: 145
#   Valid predictions: 2939
#   Positive predictions: 2650.0
#   Probability range: [0.100, 0.980]
#   Probability mean: 0.839
#   Probability std: 0.186
#   Probability median: 0.900
#
# Data types and unique values:
#   Target Label: int64, values: [0 1]
#   Predicted Diagnosis: object, values: ['not-aki' 'aki' 'error' 'mortality' 'not-mortality' 'sepsis' 'not-sepsis']
#
# Data source information:
#   • Predictions from explicit prediction column
#   • Tasks: aki, mortality, sepsis
#   • Datasets: eicu, hirid, miiv
#
# ✅ PULSE scores calculated successfully for Gemini2p5pro!
# PULSE SCORE DETAILED REPORT
# Model Type: LLM
# Weights: AUPRC=0.33, AUROC=0.33, MCC=0.34
#
# OVERALL SCORES
# --------------------------------------------------
#               Metric      Value
# 0      overall_score  47.835183
# 1        overall_aki  53.771204
# 2       overall_eicu  48.258687
# 3  overall_mortality  50.880994
# 4      overall_hirid  46.592387
# 5     overall_sepsis  38.853351
# 6       overall_miiv  48.654476
#
# TASK DATASET SCORES
# --------------------------------------------------
#                  pulse_score     auprc     auroc       mcc       ccf
# aki_eicu           57.146434  0.432508  0.652791  0.639467  0.992872
# aki_hirid          49.812341  0.278239  0.662704  0.559298  0.994908
# aki_miiv           54.354836  0.398890  0.630351  0.605409  0.996443
# mortality_eicu     48.005585  0.135625  0.739631  0.564537  0.998500
# mortality_hirid    48.435922  0.260000  0.684372  0.507990  1.000000
# mortality_miiv     56.201475  0.257160  0.809186  0.618002  1.000000
# sepsis_eicu        39.624041  0.061273  0.592951  0.530431  1.000000
# sepsis_hirid       41.528896  0.165846  0.601081  0.477068  1.000000
# sepsis_miiv        35.407116  0.022526  0.507627  0.526826  1.000000
#                hybrid_reasoning_agent_preprocessor  \
# input_cost                               23.406643
# output_cost                              38.477170
# thinking_cost                             0.000000
# total_cost                               61.883812
#
#                zhu_2024b_zero_shot_preprocessor
# input_cost                            32.986844
# output_cost                            7.484440
# thinking_cost                       1019.431350
# total_cost                          1059.902634
# Best prompt approach: hybrid_reasoning_agent_preprocessor with PULSE score: 51.47272099621813
# Saved 18 result entries to C:\Users\janbe\OneDrive\Dokumente\GitRepos\pulse\output_to_keep\results_benchmark\results_output\jsons\gemini2p5pro_results.json

# %% [markdown]
# Summary Metrics of all Prompting Appraches

# %%
df_results = LLMAnalyzer.load_metrics_from_prompt_approaches(
    model_output_dir, prompt_approaches
)



LLMAnalyzer.plot_metrics(
    df_results, group=["prompting_id"], title_prefix="Gemini 2.5 Pro - "
)
# Out:
# C:\Users\janbe\OneDrive\Dokumente\GitRepos\pulse\src\eval\llm_analyzer.py:1162: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   agg_df = plot_df.groupby(["Group", "Metric"], as_index=False).agg(

# %% [markdown]
# Metrics per Prompt and Task

# %%
LLMAnalyzer.plot_metrics(
    df_results,
    group=["task_id", "prompting_id"],
    title_prefix="Gemini 2.5 Pro - ",
)
# Out:
# C:\Users\janbe\OneDrive\Dokumente\GitRepos\pulse\src\eval\llm_analyzer.py:1162: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   agg_df = plot_df.groupby(["Group", "Metric"], as_index=False).agg(

# %% [markdown]
# ---
