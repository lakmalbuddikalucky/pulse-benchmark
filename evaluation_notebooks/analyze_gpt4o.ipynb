# %% [markdown]
# # OpenAI GPT4o - Evaluation

# %% [markdown]
# | Parameter        | Value                | Description                                                                                   |
# |------------------|----------------------|-----------------------------------------------------------------------------------------------|
# | trainer_name     | DummyTrainer         |                                                                                               |
# | mode             | inference            | Mode of operation (inference, training)                                                       |
# | model_id         | GPT4o                | Model ID for Llama3, path to pretrained model (if any)                                        |
# | deployment       | gpt-4o               | Deployment name                                                                               |
# | api_version      | 2024-12-01-preview   |                                                                                               |
# | api_key_name     | AZURE_GPT4O_KEY      |                                                                                               |
# | api_uri_name     | AZURE_GPT4O_URI      |                                                                                               |
# | type             | LLM                  | Type of model (convML for conventional ML, convDL for conventional DL, LLM for large models)  |
# | verbose          | 2                    |                                                                                               |
# | max_new_tokens   | 300                  |                                                                                               |
# | max_length       | 30000                | Maximum length of input sequences                                                             |
# | temperature      | 0.4                  | Temperature for sampling (0.0 = greedy sampling)                                              |

# %%
import pandas as pd
import numpy as np
import os
import sys
import matplotlib.pyplot as plt

sys.path.append(r"C:\Users\janbe\OneDrive\Dokumente\GitRepos\pulse")
from src.eval.llm_analyzer import LLMAnalyzer
from src.eval.pulse_score import PULSEScoreCalculator

# %%
model_id = "gpt4o"

base_output_dir = (
    r"C:\Users\janbe\OneDrive\Dokumente\GitRepos\pulse\output_to_keep\results_benchmark"
)
model_output_dir = os.path.join(base_output_dir, "llms", model_id)
results_output_dir = os.path.join(base_output_dir, r"results_output")
results_output_jsons = os.path.join(results_output_dir, "jsons")
results_json_path = f"{model_id}_results.json"

prompt_approaches = os.listdir(model_output_dir)
for i, approach in enumerate(prompt_approaches, 1):
    print(f"{i}. {approach}")


best_prompt_approach = None
results_dict = {}
mdata_dict = {}
cost_df = pd.DataFrame()

for prompt_approach in prompt_approaches:
    if not os.path.isdir(os.path.join(model_output_dir, prompt_approach)):
        continue

    print("=" * 50)
    print(f"\nPrompting Approach {prompt_approach}\n")

    cat_files = LLMAnalyzer.categorize_files(
        [os.path.join(model_output_dir, prompt_approach)],
        verbose=False,
    )

    df_mdata = LLMAnalyzer.load_metadata(
        cat_files["metadata_files"], verbose=True
    )

    summary = LLMAnalyzer.print_approach_summary(
        df_mdata, input_token_cost=2.5, output_token_cost=10
    )

    # Filter for final prediction step if agent is used
    if "Step Name" in df_mdata.columns:
        df_mdata = df_mdata[df_mdata["Step Name"] == "final_prediction"].reset_index(
            drop=True
        )

    ps = PULSEScoreCalculator()
    pulse_score = ps.calculate_pulse_score_from_raw_data(
        df=df_mdata,
    )
    pulse_score["model_id"] = model_id
    pulse_score["prompting_id"] = prompt_approach
    pulse_score_temp = pulse_score["overall"]["overall_score"]
    results_dict[prompt_approach] = pulse_score
    mdata_dict[prompt_approach] = df_mdata
    cost_df[prompt_approach] = [
        summary["input_cost"].sum(),
        summary["output_cost"].sum(),
        summary["thinking_cost"].sum(),
        summary["total_cost"].sum(),
    ]

    cost_df.index = ["input_cost", "output_cost", "thinking_cost", "total_cost"]
    if best_prompt_approach is None or pulse_score_temp > best_prompt_approach[1]:

        best_prompt_approach = (prompt_approach, pulse_score_temp)

display(cost_df)
print(
    f"\nBest prompt approach: {best_prompt_approach[0]} with PULSE score: {best_prompt_approach[1]}"
)

# Save results as json. Uses pulse-result format
json_output_path = os.path.join(results_output_jsons, f"{model_id}_results.json")
final_json = LLMAnalyzer.save_results_dict_as_json(results_dict, json_output_path)
# Out:
# 1. sarvari_2024_aggregation_preprocessor
# 2. zhu_2024b_zero_shot_preprocessor
# ==================================================
#
# Prompting Approach sarvari_2024_aggregation_preprocessor
#
# Extracting metadata from files:
# Model Name: GPT4o, Task: aki, Dataset: eicu, Timestamp: 20250623_084058
# Model Name: GPT4o, Task: aki, Dataset: hirid, Timestamp: 20250623_084058
# Model Name: GPT4o, Task: aki, Dataset: miiv, Timestamp: 20250623_084058
# Model Name: GPT4o, Task: mortality, Dataset: eicu, Timestamp: 20250623_084058
# Model Name: GPT4o, Task: mortality, Dataset: hirid, Timestamp: 20250623_084058
# Model Name: GPT4o, Task: mortality, Dataset: miiv, Timestamp: 20250623_084058
# Model Name: GPT4o, Task: sepsis, Dataset: eicu, Timestamp: 20250623_084058
# Model Name: GPT4o, Task: sepsis, Dataset: hirid, Timestamp: 20250623_084058
# Model Name: GPT4o, Task: sepsis, Dataset: miiv, Timestamp: 20250623_084058
#
# =====Overall=====:
# Number of Samples: 6189
# Number of Requests: 6189
# Total Input Tokens: 11180780
# Total Output Tokens: 626985
# Total Thinking Tokens: 0
# Average Thinking Tokens: 0.00
# Total Cost (USD): $34.22
# =================
# Preparing data for GPT4o PULSE score calculation...
# Model Type: LLM
# ✓ No invalid predictions detected
# ✅ Data format is correct for PULSE calculation!
#
# Data distribution by task:
#
# AKI:
#   Total samples: 2950/2950
#   Positive labels: 693
#   Valid predictions: 2950
#   Positive predictions: 332.0
#   Probability range: [0.050, 0.950]
#   Probability mean: 0.150
#   Probability std: 0.268
#   Probability median: 0.050
#
# MORTALITY:
#   Total samples: 300/300
#   Positive labels: 30
#   Valid predictions: 300
#   Positive predictions: 79.0
#   Probability range: [0.100, 0.950]
#   Probability mean: 0.399
#   Probability std: 0.280
#   Probability median: 0.250
#
# SEPSIS:
#   Total samples: 2939/2939
#   Positive labels: 145
#   Valid predictions: 2939
#   Positive predictions: 497.0
#   Probability range: [0.050, 0.950]
#   Probability mean: 0.288
#   Probability std: 0.252
#   Probability median: 0.150
#
# Data types and unique values:
#   Target Label: int64, values: [0 1]
#   Predicted Diagnosis: object, values: ['not-aki' 'aki' 'not-mortality' 'mortality' 'not-sepsis' 'sepsis']
#
# Data source information:
#   • Predictions from explicit prediction column
#   • Tasks: aki, mortality, sepsis
#   • Datasets: eicu, hirid, miiv
#
# ✅ PULSE scores calculated successfully for GPT4o!
# PULSE SCORE DETAILED REPORT
# Model Type: LLM
# Weights: AUPRC=0.33, AUROC=0.33, MCC=0.34
#
# OVERALL SCORES
# --------------------------------------------------
#               Metric      Value
# 0      overall_score  50.006228
# 1        overall_aki  52.542158
# 2       overall_eicu  48.775991
# 3  overall_mortality  59.289130
# 4      overall_hirid  49.967231
# 5     overall_sepsis  38.187395
# 6       overall_miiv  51.275462
#
# TASK DATASET SCORES
# --------------------------------------------------
#                  pulse_score     auprc     auroc       mcc  ccf
# aki_eicu           55.036062  0.451491  0.597137  0.600922  1.0
# aki_hirid          47.878830  0.318143  0.554724  0.561006  1.0
# aki_miiv           54.711582  0.433504  0.587839  0.617861  1.0
# mortality_eicu     55.842730  0.358995  0.698157  0.616374  1.0
# mortality_hirid    53.098774  0.304948  0.671093  0.614395  1.0
# mortality_miiv     68.925887  0.583346  0.809186  0.675657  1.0
# sepsis_eicu        35.449180  0.046027  0.543431  0.470502  1.0
# sepsis_hirid       48.924088  0.154043  0.696604  0.613316  1.0
# sepsis_miiv        30.188917  0.018271  0.409575  0.472647  1.0
# ==================================================
#
# Prompting Approach zhu_2024b_zero_shot_preprocessor
#
# Extracting metadata from files:
# Model Name: GPT4o, Task: aki, Dataset: eicu, Timestamp: 20250622_142837
# Model Name: GPT4o, Task: aki, Dataset: hirid, Timestamp: 20250622_142837
# Model Name: GPT4o, Task: aki, Dataset: miiv, Timestamp: 20250622_142837
# Model Name: GPT4o, Task: mortality, Dataset: eicu, Timestamp: 20250622_142837
# Model Name: GPT4o, Task: mortality, Dataset: hirid, Timestamp: 20250622_142837
# Model Name: GPT4o, Task: mortality, Dataset: miiv, Timestamp: 20250622_142837
# Model Name: GPT4o, Task: sepsis, Dataset: eicu, Timestamp: 20250622_142837
# Model Name: GPT4o, Task: sepsis, Dataset: hirid, Timestamp: 20250622_142837
# Model Name: GPT4o, Task: sepsis, Dataset: miiv, Timestamp: 20250622_142837
#
# =====Overall=====:
# Number of Samples: 6189
# Number of Requests: 6189
# Total Input Tokens: 21727931
# Total Output Tokens: 649558
# Total Thinking Tokens: 0
# Average Thinking Tokens: 0.00
# Total Cost (USD): $60.82
# =================
# Preparing data for GPT4o PULSE score calculation...
# Model Type: LLM
# ✓ No invalid predictions detected
# ✅ Data format is correct for PULSE calculation!
#
# Data distribution by task:
#
# AKI:
#   Total samples: 2950/2950
#   Positive labels: 693
#   Valid predictions: 2950
#   Positive predictions: 636.0
#   Probability range: [0.050, 0.950]
#   Probability mean: 0.256
#   Probability std: 0.324
#   Probability median: 0.100
#
# MORTALITY:
#   Total samples: 300/300
#   Positive labels: 30
#   Valid predictions: 300
#   Positive predictions: 235.0
#   Probability range: [0.200, 0.950]
#   Probability mean: 0.729
#   Probability std: 0.257
#   Probability median: 0.850
#
# SEPSIS:
#   Total samples: 2939/2939
#   Positive labels: 145
#   Valid predictions: 2939
#   Positive predictions: 2065.0
#   Probability range: [0.100, 0.950]
#   Probability mean: 0.660
#   Probability std: 0.280
#   Probability median: 0.850
#
# Data types and unique values:
#   Target Label: int64, values: [0 1]
#   Predicted Diagnosis: object, values: ['not-aki' 'aki' 'not-mortality' 'mortality' 'sepsis' 'not-sepsis']
#
# Data source information:
#   • Predictions from explicit prediction column
#   • Tasks: aki, mortality, sepsis
#   • Datasets: eicu, hirid, miiv
#
# ✅ PULSE scores calculated successfully for GPT4o!
# PULSE SCORE DETAILED REPORT
# Model Type: LLM
# Weights: AUPRC=0.33, AUROC=0.33, MCC=0.34
#
# OVERALL SCORES
# --------------------------------------------------
#               Metric      Value
# 0      overall_score  49.784232
# 1        overall_aki  52.327219
# 2       overall_eicu  50.476732
# 3  overall_mortality  58.183119
# 4      overall_hirid  49.445268
# 5     overall_sepsis  38.842358
# 6       overall_miiv  49.430696
#
# TASK DATASET SCORES
# --------------------------------------------------
#                  pulse_score     auprc     auroc       mcc  ccf
# aki_eicu           54.200407  0.430771  0.622714  0.571629  1.0
# aki_hirid          47.838293  0.275705  0.605184  0.552029  1.0
# aki_miiv           54.942958  0.437011  0.614945  0.594953  1.0
# mortality_eicu     56.910952  0.390274  0.784178  0.533942  1.0
# mortality_hirid    51.507210  0.319318  0.665986  0.558594  1.0
# mortality_miiv     66.131196  0.613843  0.785038  0.587297  1.0
# sepsis_eicu        40.318839  0.058658  0.599234  0.547307  1.0
# sepsis_hirid       48.990300  0.249247  0.673006  0.545763  1.0
# sepsis_miiv        27.217935  0.015749  0.350591  0.444963  1.0
#                sarvari_2024_aggregation_preprocessor  \
# input_cost                                  27.95195
# output_cost                                  6.26985
# thinking_cost                                0.00000
# total_cost                                  34.22180
#
#                zhu_2024b_zero_shot_preprocessor
# input_cost                            54.319828
# output_cost                            6.495580
# thinking_cost                          0.000000
# total_cost                            60.815407
# Best prompt approach: sarvari_2024_aggregation_preprocessor with PULSE score: 50.00622792624384
# Saved 18 result entries to C:\Users\janbe\OneDrive\Dokumente\GitRepos\pulse\output_to_keep\results_benchmark\results_output\jsons\gpt4o_results.json

# %% [markdown]
# ## Model Metrics

# %%
df_results = LLMAnalyzer.load_metrics_from_prompt_approaches(model_output_dir, prompt_approaches)

# %%
LLMAnalyzer.plot_metrics(
    df_results, group=["prompting_id"], title_prefix="GPT-4o - ",
)
# Out:
# C:\Users\janbe\OneDrive\Dokumente\GitRepos\pulse\src\eval\llm_analyzer.py:1162: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   agg_df = plot_df.groupby(["Group", "Metric"], as_index=False).agg(

# %%
LLMAnalyzer.plot_metrics(
    df_results,
    group=["task_id", "prompting_id"],
    title_prefix="GPT-4o - ",
)
# Out:
# C:\Users\janbe\OneDrive\Dokumente\GitRepos\pulse\src\eval\llm_analyzer.py:1162: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   agg_df = plot_df.groupby(["Group", "Metric"], as_index=False).agg(
