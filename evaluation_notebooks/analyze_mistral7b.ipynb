# %% [markdown]
# # Mistral 7B - Evaluation

# %% [markdown]
# | Parameter        | Value                                         | Description                                                                                   |
# |------------------|-----------------------------------------------|-----------------------------------------------------------------------------------------------|
# | trainer_name     | MistralTrainer                                | Name of the trainer                                                                           |
# | model_id         | mistralai/Mistral-7B-Instruct-v0.3            | Model ID                                      |
# | type             | LLM                                           | Type of model (convML for conventional ML, convDL for conventional DL, LLM for large language models) |
# | mode             | inference                                     | Mode of operation (inference, training)                                                       |
# | verbose          | 2                                             | Verbosity level                                                                               |
# | tuning           | false                                         | Whether to use prompt tuning                                                                  |
# | num_epochs       | 10                                            | Number of epochs for training                                                                 |
# | max_new_tokens   | 300                                           | Maximum number of new tokens to generate                                                      |
# | max_length       | 30000                                         | Maximum length of input sequences                                                             |
# | do_sample        | true                                          | Whether to sample new tokens (false = greedy decoding for full determinism)                   |
# | temperature      | 0.4                                           | Temperature for sampling (0.0 = greedy sampling, like do_sample: false)                       |

# %%
import pandas as pd
import numpy as np
import os
import sys
import matplotlib.pyplot as plt

sys.path.append(r"C:\Users\janbe\OneDrive\Dokumente\GitRepos\pulse")
from src.eval.llm_analyzer import LLMAnalyzer
from src.eval.pulse_score import PULSEScoreCalculator

# %%
model_id = "mistral7b"

base_output_dir = (
    r"C:\Users\janbe\OneDrive\Dokumente\GitRepos\pulse\output_to_keep\results_benchmark"
)
model_output_dir = os.path.join(base_output_dir, "llms", model_id)
results_output_dir = os.path.join(base_output_dir, r"results_output")
results_output_jsons = os.path.join(results_output_dir, "jsons")
results_json_path = f"{model_id}_results.json"

prompt_approaches = os.listdir(model_output_dir)
for i, approach in enumerate(prompt_approaches, 1):
    print(f"{i}. {approach}")


best_prompt_approach = None
results_dict = {}
mdata_dict = {}
cost_df = pd.DataFrame()

for prompt_approach in prompt_approaches:
    if not os.path.isdir(os.path.join(model_output_dir, prompt_approach)):
        continue

    print("=" * 50)
    print(f"\nPrompting Approach {prompt_approach}\n")

    cat_files = LLMAnalyzer.categorize_files(
        [os.path.join(model_output_dir, prompt_approach)],
        verbose=False,
    )

    df_mdata = LLMAnalyzer.load_metadata(
        cat_files["metadata_files"], verbose=True
    )

    summary = LLMAnalyzer.print_approach_summary(
        df_mdata, input_token_cost=0, output_token_cost=0
    )

    # Filter for final prediction step if agent is used
    if "Step Name" in df_mdata.columns:
        df_mdata = df_mdata[df_mdata["Step Name"] == "final_prediction"].reset_index(
            drop=True
        )

    ps = PULSEScoreCalculator()
    pulse_score = ps.calculate_pulse_score_from_raw_data(
        df=df_mdata,
    )
    pulse_score["model_id"] = model_id
    pulse_score["prompting_id"] = prompt_approach
    pulse_score_temp = pulse_score["overall"]["overall_score"]
    results_dict[prompt_approach] = pulse_score
    mdata_dict[prompt_approach] = df_mdata
    cost_df[prompt_approach] = [
        summary["input_cost"].sum(),
        summary["output_cost"].sum(),
        summary["thinking_cost"].sum(),
        summary["total_cost"].sum(),
    ]

    cost_df.index = ["input_cost", "output_cost", "thinking_cost", "total_cost"]
    if best_prompt_approach is None or pulse_score_temp > best_prompt_approach[1]:

        best_prompt_approach = (prompt_approach, pulse_score_temp)

display(cost_df)
print(
    f"\nBest prompt approach: {best_prompt_approach[0]} with PULSE score: {best_prompt_approach[1]}"
)

# Save results as json. Uses pulse-result format
json_output_path = os.path.join(results_output_jsons, f"{model_id}_results.json")
final_json = LLMAnalyzer.save_results_dict_as_json(results_dict, json_output_path)
# Out:
# 1. clinical_workflow_agent_preprocessor
# 2. collaborative_reasoning_agent_preprocessor
# 3. hybrid_reasoning_agent_preprocessor
# 4. liu_2023_few_shot_preprocessor
# 5. sarvari_2024_aggregation_preprocessor
# 6. zhu_2024a_cot_preprocessor
# 7. zhu_2024b_one_shot_preprocessor
# 8. zhu_2024b_zero_shot_preprocessor
# 9. zhu_2024c_categorization_summary_agent_preprocessor
# ==================================================
#
# Prompting Approach clinical_workflow_agent_preprocessor
#
# Extracting metadata from files:
# Model Name: Mistral, Task: aki, Dataset: eicu, Timestamp: 20250702_034243
# Model Name: Mistral, Task: aki, Dataset: hirid, Timestamp: 20250702_034243
# Model Name: Mistral, Task: aki, Dataset: miiv, Timestamp: 20250702_034243
# Model Name: Mistral, Task: mortality, Dataset: eicu, Timestamp: 20250702_034243
# Model Name: Mistral, Task: mortality, Dataset: hirid, Timestamp: 20250702_034243
# Model Name: Mistral, Task: mortality, Dataset: miiv, Timestamp: 20250702_034243
# Model Name: Mistral, Task: sepsis, Dataset: eicu, Timestamp: 20250702_034243
# Model Name: Mistral, Task: sepsis, Dataset: hirid, Timestamp: 20250707_133237
# Model Name: Mistral, Task: sepsis, Dataset: miiv, Timestamp: 20250708_145720
#
# =====Overall=====:
# Number of Samples: 6189
# Number of Requests: 55524
# Total Input Tokens: 64165169
# Total Output Tokens: 11397479
# Total Thinking Tokens: 0
# Average Thinking Tokens: 0.00
# Total Cost (USD): $0.00
# =================
# Preparing data for Mistral PULSE score calculation...
# Model Type: LLM
#
# ⚠️ Wrongly labled predictions: 5
# Wrongly labeled predictions:
#   - possibly-sepsis: 2 occurrences
#   - unknown: 1 occurrences
#   - suspected sepsis: 1 occurrences
#   - severe sepsis: 1 occurrences
# ✅ Data format is correct for PULSE calculation!
#
# Data distribution by task:
#
# AKI:
#   Total samples: 2950/2950
#   Positive labels: 693
#   Valid predictions: 2950
#   Positive predictions: 2679.0
#   Probability range: [0.000, 1.000]
#   Probability mean: 0.815
#   Probability std: 0.221
#   Probability median: 0.900
#
# MORTALITY:
#   Total samples: 300/300
#   Positive labels: 30
#   Valid predictions: 300
#   Positive predictions: 287.0
#   Probability range: [0.150, 0.990]
#   Probability mean: 0.816
#   Probability std: 0.142
#   Probability median: 0.850
#
# SEPSIS:
#   Total samples: 2939/2939
#   Positive labels: 145
#   Valid predictions: 2939
#   Positive predictions: 2317.0
#   Probability range: [0.050, 0.990]
#   Probability mean: 0.756
#   Probability std: 0.293
#   Probability median: 0.900
#
# Data types and unique values:
#   Target Label: int64, values: [0 1]
#   Predicted Diagnosis: object, values: ['not-aki' 'aki' 'unknown' 'mortality' 'not-mortality' 'sepsis'
#  'not-sepsis' 'possibly-sepsis' 'suspected sepsis' 'severe sepsis']
#
# Data source information:
#   • Predictions from explicit prediction column
#   • Tasks: aki, mortality, sepsis
#   • Datasets: eicu, hirid, miiv
#
# ✅ PULSE scores calculated successfully for Mistral!
# PULSE SCORE DETAILED REPORT
# Model Type: LLM
# Weights: AUPRC=0.33, AUROC=0.33, MCC=0.34
#
# OVERALL SCORES
# --------------------------------------------------
#               Metric      Value
# 0      overall_score  39.945725
# 1        overall_aki  34.485612
# 2       overall_eicu  40.592863
# 3  overall_mortality  47.305558
# 4      overall_hirid  38.829352
# 5     overall_sepsis  38.046006
# 6       overall_miiv  40.414962
#
# TASK DATASET SCORES
# --------------------------------------------------
#                  pulse_score     auprc     auroc       mcc       ccf
# aki_eicu           35.141036  0.315366  0.494012  0.484451  0.813811
# aki_hirid          33.045694  0.211769  0.513713  0.492507  0.812210
# aki_miiv           35.270107  0.264092  0.525440  0.505282  0.815793
# mortality_eicu     47.381010  0.168498  0.803379  0.534657  0.942900
# mortality_hirid    43.833711  0.234860  0.595506  0.500000  0.987200
# mortality_miiv     50.701952  0.388257  0.706913  0.442274  0.990700
# sepsis_eicu        39.256543  0.080927  0.577957  0.515099  1.000000
# sepsis_hirid       39.608650  0.102679  0.550651  0.533738  0.997523
# sepsis_miiv        35.272825  0.022792  0.522238  0.509380  0.999091
# ==================================================
#
# Prompting Approach collaborative_reasoning_agent_preprocessor
#
# Extracting metadata from files:
# Model Name: Mistral, Task: aki, Dataset: eicu, Timestamp: 20250628_161008
# Model Name: Mistral, Task: aki, Dataset: hirid, Timestamp: 20250628_161008
# Model Name: Mistral, Task: aki, Dataset: miiv, Timestamp: 20250628_161008
# Model Name: Mistral, Task: mortality, Dataset: eicu, Timestamp: 20250628_161008
# Model Name: Mistral, Task: mortality, Dataset: hirid, Timestamp: 20250628_161008
# Model Name: Mistral, Task: mortality, Dataset: miiv, Timestamp: 20250628_161008
# Model Name: Mistral, Task: sepsis, Dataset: eicu, Timestamp: 20250628_161008
# Model Name: Mistral, Task: sepsis, Dataset: hirid, Timestamp: 20250628_161008
# Model Name: Mistral, Task: sepsis, Dataset: miiv, Timestamp: 20250628_161008
#
# =====Overall=====:
# Number of Samples: 6189
# Number of Requests: 30945
# Total Input Tokens: 35052321
# Total Output Tokens: 6300906
# Total Thinking Tokens: 0
# Average Thinking Tokens: 0.00
# Total Cost (USD): $0.00
# =================
# Preparing data for Mistral PULSE score calculation...
# Model Type: LLM
#
# ⚠️ Wrongly labled predictions: 207
# Wrongly labeled predictions:
#   - possibly-sepsis: 206 occurrences
#   - potential-sepsis: 1 occurrences
# ✅ Data format is correct for PULSE calculation!
#
# Data distribution by task:
#
# AKI:
#   Total samples: 2950/2950
#   Positive labels: 693
#   Valid predictions: 2950
#   Positive predictions: 2797.0
#   Probability range: [0.080, 0.950]
#   Probability mean: 0.721
#   Probability std: 0.128
#   Probability median: 0.730
#
# MORTALITY:
#   Total samples: 300/300
#   Positive labels: 30
#   Valid predictions: 300
#   Positive predictions: 300.0
#   Probability range: [0.600, 0.950]
#   Probability mean: 0.844
#   Probability std: 0.051
#   Probability median: 0.850
#
# SEPSIS:
#   Total samples: 2939/2939
#   Positive labels: 145
#   Valid predictions: 2939
#   Positive predictions: 2770.0
#   Probability range: [0.120, 0.950]
#   Probability mean: 0.740
#   Probability std: 0.148
#   Probability median: 0.770
#
# Data types and unique values:
#   Target Label: int64, values: [0 1]
#   Predicted Diagnosis: object, values: ['not-aki' 'aki' 'mortality' 'not-mortality' 'sepsis' 'not-sepsis'
#  'possibly-sepsis' 'potential-sepsis']
#
# Data source information:
#   • Predictions from explicit prediction column
#   • Tasks: aki, mortality, sepsis
#   • Datasets: eicu, hirid, miiv
#
# ✅ PULSE scores calculated successfully for Mistral!
# PULSE SCORE DETAILED REPORT
# Model Type: LLM
# Weights: AUPRC=0.33, AUROC=0.33, MCC=0.34
#
# OVERALL SCORES
# --------------------------------------------------
#               Metric      Value
# 0      overall_score  41.139792
# 1        overall_aki  41.463285
# 2       overall_eicu  40.879568
# 3  overall_mortality  47.265082
# 4      overall_hirid  41.309944
# 5     overall_sepsis  34.691007
# 6       overall_miiv  41.229863
#
# TASK DATASET SCORES
# --------------------------------------------------
#                  pulse_score     auprc     auroc       mcc       ccf
# aki_eicu           41.548503  0.314729  0.507653  0.523091  0.924868
# aki_hirid          39.619766  0.206075  0.487169  0.501268  0.992475
# aki_miiv           43.221588  0.295121  0.552989  0.517761  0.948018
# mortality_eicu     46.243332  0.216736  0.674347  0.500000  0.996500
# mortality_hirid    41.381616  0.180614  0.558223  0.500000  1.000000
# mortality_miiv     54.170298  0.370691  0.755682  0.500000  1.000000
# sepsis_eicu        34.846870  0.048938  0.534287  0.515102  0.947959
# sepsis_hirid       42.928450  0.132214  0.662297  0.508628  0.986584
# sepsis_miiv        26.297702  0.020240  0.341119  0.454874  0.960101
# ==================================================
#
# Prompting Approach hybrid_reasoning_agent_preprocessor
#
# Extracting metadata from files:
# Model Name: Mistral, Task: aki, Dataset: eicu, Timestamp: 20250704_012550
# Model Name: Mistral, Task: aki, Dataset: hirid, Timestamp: 20250704_012550
# Model Name: Mistral, Task: aki, Dataset: miiv, Timestamp: 20250704_012550
# Model Name: Mistral, Task: mortality, Dataset: eicu, Timestamp: 20250704_012550
# Model Name: Mistral, Task: mortality, Dataset: hirid, Timestamp: 20250704_012550
# Model Name: Mistral, Task: mortality, Dataset: miiv, Timestamp: 20250704_012550
# Model Name: Mistral, Task: sepsis, Dataset: eicu, Timestamp: 20250704_012550
# Model Name: Mistral, Task: sepsis, Dataset: hirid, Timestamp: 20250707_224734
# Model Name: Mistral, Task: sepsis, Dataset: miiv, Timestamp: 20250707_224734
#
# =====Overall=====:
# Number of Samples: 6189
# Number of Requests: 26494
# Total Input Tokens: 20261961
# Total Output Tokens: 5027478
# Total Thinking Tokens: 0
# Average Thinking Tokens: 0.00
# Total Cost (USD): $0.00
# =================
# Preparing data for Mistral PULSE score calculation...
# Model Type: LLM
#
# ⚠️ Wrongly labled predictions: 53
# Wrongly labeled predictions:
#   - possibly-sepsis: 53 occurrences
# ✅ Data format is correct for PULSE calculation!
#
# Data distribution by task:
#
# AKI:
#   Total samples: 2950/2950
#   Positive labels: 693
#   Valid predictions: 2950
#   Positive predictions: 1837.0
#   Probability range: [0.020, 1.000]
#   Probability mean: 0.560
#   Probability std: 0.314
#   Probability median: 0.640
#
# MORTALITY:
#   Total samples: 300/300
#   Positive labels: 30
#   Valid predictions: 300
#   Positive predictions: 245.0
#   Probability range: [0.050, 1.000]
#   Probability mean: 0.737
#   Probability std: 0.271
#   Probability median: 0.850
#
# SEPSIS:
#   Total samples: 2939/2939
#   Positive labels: 145
#   Valid predictions: 2939
#   Positive predictions: 1416.0
#   Probability range: [0.020, 1.000]
#   Probability mean: 0.483
#   Probability std: 0.420
#   Probability median: 0.200
#
# Data types and unique values:
#   Target Label: int64, values: [0 1]
#   Predicted Diagnosis: object, values: ['not-aki' 'aki' 'not-mortality' 'mortality' 'not-sepsis' 'sepsis'
#  'possibly-sepsis']
#
# Data source information:
#   • Predictions from explicit prediction column
#   • Tasks: aki, mortality, sepsis
#   • Datasets: eicu, hirid, miiv
#
# ✅ PULSE scores calculated successfully for Mistral!
# PULSE SCORE DETAILED REPORT
# Model Type: LLM
# Weights: AUPRC=0.33, AUROC=0.33, MCC=0.34
#
# OVERALL SCORES
# --------------------------------------------------
#               Metric      Value
# 0      overall_score  29.199672
# 1        overall_aki  36.036200
# 2       overall_eicu  28.236576
# 3  overall_mortality  22.962711
# 4      overall_hirid  29.094220
# 5     overall_sepsis  28.600106
# 6       overall_miiv  30.268221
#
# TASK DATASET SCORES
# --------------------------------------------------
#                  pulse_score     auprc     auroc       mcc       ccf
# aki_eicu           39.285115  0.283526  0.504780  0.528228  0.893374
# aki_hirid          31.629110  0.137733  0.469948  0.517896  0.839817
# aki_miiv           37.194374  0.214494  0.508658  0.534618  0.884715
# mortality_eicu     18.513462  0.044497  0.252688  0.474500  0.713700
# mortality_hirid    27.335708  0.089514  0.442288  0.537011  0.763400
# mortality_miiv     23.038964  0.083334  0.331439  0.501638  0.749400
# sepsis_eicu        26.911152  0.052045  0.482783  0.483973  0.789082
# sepsis_hirid       28.317843  0.064978  0.474063  0.521090  0.797564
# sepsis_miiv        30.571323  0.024923  0.565430  0.503181  0.835515
# ==================================================
#
# Prompting Approach liu_2023_few_shot_preprocessor
#
# Extracting metadata from files:
# Model Name: Mistral, Task: aki, Dataset: eicu, Timestamp: 20250625_032111
# Model Name: Mistral, Task: aki, Dataset: hirid, Timestamp: 20250625_032111
# Model Name: Mistral, Task: aki, Dataset: miiv, Timestamp: 20250625_032111
# Model Name: Mistral, Task: mortality, Dataset: eicu, Timestamp: 20250625_032111
# Model Name: Mistral, Task: mortality, Dataset: hirid, Timestamp: 20250627_183806
# Model Name: Mistral, Task: mortality, Dataset: miiv, Timestamp: 20250625_032111
# Model Name: Mistral, Task: sepsis, Dataset: eicu, Timestamp: 20250625_032111
# Model Name: Mistral, Task: sepsis, Dataset: hirid, Timestamp: 20250625_032111
# Model Name: Mistral, Task: sepsis, Dataset: miiv, Timestamp: 20250625_032111
#
# =====Overall=====:
# Number of Samples: 6189
# Number of Requests: 6189
# Total Input Tokens: 69602982
# Total Output Tokens: 637000
# Total Thinking Tokens: 0
# Average Thinking Tokens: 0.00
# Total Cost (USD): $0.00
# =================
# Preparing data for Mistral PULSE score calculation...
# Model Type: LLM
#
# ⚠️ Wrongly labled predictions: 275
# Wrongly labeled predictions:
#   - unknown: 275 occurrences
# ✅ Data format is correct for PULSE calculation!
#
# Data distribution by task:
#
# AKI:
#   Total samples: 2950/2950
#   Positive labels: 693
#   Valid predictions: 2950
#   Positive predictions: 2911.0
#   Probability range: [0.100, 0.990]
#   Probability mean: 0.941
#   Probability std: 0.107
#   Probability median: 0.950
#
# MORTALITY:
#   Total samples: 300/300
#   Positive labels: 30
#   Valid predictions: 300
#   Positive predictions: 33.0
#   Probability range: [0.500, 0.900]
#   Probability mean: 0.537
#   Probability std: 0.106
#   Probability median: 0.500
#
# SEPSIS:
#   Total samples: 2939/2939
#   Positive labels: 145
#   Valid predictions: 2939
#   Positive predictions: 647.0
#   Probability range: [0.050, 1.000]
#   Probability mean: 0.290
#   Probability std: 0.344
#   Probability median: 0.100
#
# Data types and unique values:
#   Target Label: int64, values: [0 1]
#   Predicted Diagnosis: object, values: ['not-aki' 'aki' 'unknown' 'mortality' 'not-mortality' 'not-sepsis'
#  'sepsis']
#
# Data source information:
#   • Predictions from explicit prediction column
#   • Tasks: aki, mortality, sepsis
#   • Datasets: eicu, hirid, miiv
#
# ✅ PULSE scores calculated successfully for Mistral!
# PULSE SCORE DETAILED REPORT
# Model Type: LLM
# Weights: AUPRC=0.33, AUROC=0.33, MCC=0.34
#
# OVERALL SCORES
# --------------------------------------------------
#               Metric      Value
# 0      overall_score  27.089984
# 1        overall_aki  25.558853
# 2       overall_eicu  27.684676
# 3  overall_mortality  22.936455
# 4      overall_hirid  25.491605
# 5     overall_sepsis  32.774643
# 6       overall_miiv  28.093670
#
# TASK DATASET SCORES
# --------------------------------------------------
#                  pulse_score     auprc     auroc       mcc       ccf
# aki_eicu           28.492257  0.465652  0.454359  0.500000  0.601606
# aki_hirid          21.828946  0.146529  0.443075  0.512736  0.591731
# aki_miiv           26.355356  0.439468  0.494595  0.519679  0.543486
# mortality_eicu     21.612984  0.196667  0.559908  0.500000  0.515000
# mortality_hirid    21.520259  0.217172  0.533574  0.500000  0.515152
# mortality_miiv     25.676121  0.203991  0.506155  0.500000  0.635000
# sepsis_eicu        32.948787  0.139926  0.493102  0.498238  0.870969
# sepsis_hirid       33.125609  0.066001  0.418275  0.522483  0.981631
# sepsis_miiv        32.249533  0.035104  0.549658  0.518147  0.873636
# ==================================================
#
# Prompting Approach sarvari_2024_aggregation_preprocessor
#
# Extracting metadata from files:
# Model Name: Mistral, Task: aki, Dataset: eicu, Timestamp: 20250623_184546
# Model Name: Mistral, Task: aki, Dataset: hirid, Timestamp: 20250623_184546
# Model Name: Mistral, Task: aki, Dataset: miiv, Timestamp: 20250623_184546
# Model Name: Mistral, Task: mortality, Dataset: eicu, Timestamp: 20250623_184546
# Model Name: Mistral, Task: mortality, Dataset: hirid, Timestamp: 20250623_184546
# Model Name: Mistral, Task: mortality, Dataset: miiv, Timestamp: 20250623_184546
# Model Name: Mistral, Task: sepsis, Dataset: eicu, Timestamp: 20250623_184546
# Model Name: Mistral, Task: sepsis, Dataset: hirid, Timestamp: 20250623_184546
# Model Name: Mistral, Task: sepsis, Dataset: miiv, Timestamp: 20250623_184546
#
# =====Overall=====:
# Number of Samples: 6189
# Number of Requests: 6189
# Total Input Tokens: 15020576
# Total Output Tokens: 689236
# Total Thinking Tokens: 0
# Average Thinking Tokens: 0.00
# Total Cost (USD): $0.00
# =================
# Preparing data for Mistral PULSE score calculation...
# Model Type: LLM
# ✓ No invalid predictions detected
# ✅ Data format is correct for PULSE calculation!
#
# Data distribution by task:
#
# AKI:
#   Total samples: 2950/2950
#   Positive labels: 693
#   Valid predictions: 2950
#   Positive predictions: 2950.0
#   Probability range: [0.700, 0.990]
#   Probability mean: 0.918
#   Probability std: 0.080
#   Probability median: 0.950
#
# MORTALITY:
#   Total samples: 300/300
#   Positive labels: 30
#   Valid predictions: 300
#   Positive predictions: 300.0
#   Probability range: [0.600, 0.950]
#   Probability mean: 0.810
#   Probability std: 0.069
#   Probability median: 0.850
#
# SEPSIS:
#   Total samples: 2939/2939
#   Positive labels: 145
#   Valid predictions: 2939
#   Positive predictions: 2939.0
#   Probability range: [0.900, 0.980]
#   Probability mean: 0.979
#   Probability std: 0.007
#   Probability median: 0.980
#
# Data types and unique values:
#   Target Label: int64, values: [0 1]
#   Predicted Diagnosis: object, values: ['not-aki' 'aki' 'mortality' 'not-mortality' 'not-sepsis']
#
# Data source information:
#   • Predictions from explicit prediction column
#   • Tasks: aki, mortality, sepsis
#   • Datasets: eicu, hirid, miiv
#
# ✅ PULSE scores calculated successfully for Mistral!
# PULSE SCORE DETAILED REPORT
# Model Type: LLM
# Weights: AUPRC=0.33, AUROC=0.33, MCC=0.34
#
# OVERALL SCORES
# --------------------------------------------------
#               Metric      Value
# 0      overall_score  31.315575
# 1        overall_aki  26.329614
# 2       overall_eicu  30.103140
# 3  overall_mortality  41.080743
# 4      overall_hirid  34.430054
# 5     overall_sepsis  26.536367
# 6       overall_miiv  29.413531
#
# TASK DATASET SCORES
# --------------------------------------------------
#                  pulse_score     auprc     auroc  mcc       ccf
# aki_eicu           26.414139  0.365234  0.478708  0.5  0.588943
# aki_hirid          26.463333  0.210133  0.532497  0.5  0.637566
# aki_miiv           26.111371  0.258128  0.440050  0.5  0.652134
# mortality_eicu     37.401148  0.065455  0.603687  0.5  0.957000
# mortality_hirid    49.941711  0.476783  0.521450  0.5  1.000000
# mortality_miiv     35.899370  0.085020  0.538352  0.5  0.955500
# sepsis_eicu        26.494133  0.524127  0.503215  0.5  0.520490
# sepsis_hirid       26.885117  0.538340  0.509487  0.5  0.521249
# sepsis_miiv        26.229852  0.512639  0.500518  0.5  0.520081
# ==================================================
#
# Prompting Approach zhu_2024a_cot_preprocessor
#
# Extracting metadata from files:
# Model Name: Mistral, Task: aki, Dataset: eicu, Timestamp: 20250622_033525
# Model Name: Mistral, Task: aki, Dataset: hirid, Timestamp: 20250622_033525
# Model Name: Mistral, Task: aki, Dataset: miiv, Timestamp: 20250622_033525
# Model Name: Mistral, Task: mortality, Dataset: eicu, Timestamp: 20250622_033525
# Model Name: Mistral, Task: mortality, Dataset: hirid, Timestamp: 20250622_033525
# Model Name: Mistral, Task: mortality, Dataset: miiv, Timestamp: 20250622_033525
# Model Name: Mistral, Task: sepsis, Dataset: eicu, Timestamp: 20250622_033525
# Model Name: Mistral, Task: sepsis, Dataset: hirid, Timestamp: 20250622_033525
# Model Name: Mistral, Task: sepsis, Dataset: miiv, Timestamp: 20250622_033525
#
# =====Overall=====:
# Number of Samples: 6189
# Number of Requests: 6189
# Total Input Tokens: 32462354
# Total Output Tokens: 671451
# Total Thinking Tokens: 0
# Average Thinking Tokens: 0.00
# Total Cost (USD): $0.00
# =================
# Preparing data for Mistral PULSE score calculation...
# Model Type: LLM
#
# ⚠️ Wrongly labled predictions: 6
# Wrongly labeled predictions:
#   - unknown: 6 occurrences
# ✅ Data format is correct for PULSE calculation!
#
# Data distribution by task:
#
# AKI:
#   Total samples: 2950/2950
#   Positive labels: 693
#   Valid predictions: 2950
#   Positive predictions: 92.0
#   Probability range: [0.080, 0.850]
#   Probability mean: 0.312
#   Probability std: 0.110
#   Probability median: 0.350
#
# MORTALITY:
#   Total samples: 300/300
#   Positive labels: 30
#   Valid predictions: 300
#   Positive predictions: 203.0
#   Probability range: [0.350, 0.940]
#   Probability mean: 0.677
#   Probability std: 0.230
#   Probability median: 0.850
#
# SEPSIS:
#   Total samples: 2939/2939
#   Positive labels: 145
#   Valid predictions: 2939
#   Positive predictions: 4.0
#   Probability range: [0.350, 0.650]
#   Probability mean: 0.350
#   Probability std: 0.011
#   Probability median: 0.350
#
# Data types and unique values:
#   Target Label: int64, values: [0 1]
#   Predicted Diagnosis: object, values: ['not-aki' 'unknown' 'aki' 'not-mortality' 'mortality' 'not-sepsis'
#  'sepsis']
#
# Data source information:
#   • Predictions from explicit prediction column
#   • Tasks: aki, mortality, sepsis
#   • Datasets: eicu, hirid, miiv
#
# ✅ PULSE scores calculated successfully for Mistral!
# PULSE SCORE DETAILED REPORT
# Model Type: LLM
# Weights: AUPRC=0.33, AUROC=0.33, MCC=0.34
#
# OVERALL SCORES
# --------------------------------------------------
#               Metric      Value
# 0      overall_score  38.951218
# 1        overall_aki  44.851575
# 2       overall_eicu  33.916362
# 3  overall_mortality  25.561492
# 4      overall_hirid  43.245778
# 5     overall_sepsis  46.440585
# 6       overall_miiv  39.691513
#
# TASK DATASET SCORES
# --------------------------------------------------
#                  pulse_score     auprc     auroc       mcc       ccf
# aki_eicu           42.176513  0.271364  0.510160  0.485209  0.997378
# aki_hirid          46.877601  0.263829  0.562335  0.578786  0.998625
# aki_miiv           45.500612  0.317722  0.517239  0.531327  0.997409
# mortality_eicu     25.489160  0.047719  0.430108  0.486273  0.789100
# mortality_hirid    28.038056  0.255100  0.394280  0.444180  0.767500
# mortality_miiv     23.157261  0.196812  0.303504  0.382037  0.785000
# sepsis_eicu        34.083412  0.023980  0.498928  0.494925  1.000000
# sepsis_hirid       54.821678  0.550334  0.513699  0.579664  1.000000
# sepsis_miiv        50.416667  0.512626  0.500000  0.500000  1.000000
# ==================================================
#
# Prompting Approach zhu_2024b_one_shot_preprocessor
#
# Extracting metadata from files:
# Model Name: Mistral, Task: aki, Dataset: eicu, Timestamp: 20250621_194738
# Model Name: Mistral, Task: aki, Dataset: hirid, Timestamp: 20250621_194738
# Model Name: Mistral, Task: aki, Dataset: miiv, Timestamp: 20250621_194738
# Model Name: Mistral, Task: mortality, Dataset: eicu, Timestamp: 20250621_194738
# Model Name: Mistral, Task: mortality, Dataset: hirid, Timestamp: 20250621_194738
# Model Name: Mistral, Task: mortality, Dataset: miiv, Timestamp: 20250621_194738
# Model Name: Mistral, Task: sepsis, Dataset: eicu, Timestamp: 20250621_194738
# Model Name: Mistral, Task: sepsis, Dataset: hirid, Timestamp: 20250621_194738
# Model Name: Mistral, Task: sepsis, Dataset: miiv, Timestamp: 20250621_194738
#
# =====Overall=====:
# Number of Samples: 6189
# Number of Requests: 6189
# Total Input Tokens: 46171872
# Total Output Tokens: 711165
# Total Thinking Tokens: 0
# Average Thinking Tokens: 0.00
# Total Cost (USD): $0.00
# =================
# Preparing data for Mistral PULSE score calculation...
# Model Type: LLM
# ✓ No invalid predictions detected
# ✅ Data format is correct for PULSE calculation!
#
# Data distribution by task:
#
# AKI:
#   Total samples: 2950/2950
#   Positive labels: 693
#   Valid predictions: 2950
#   Positive predictions: 2945.0
#   Probability range: [0.100, 1.000]
#   Probability mean: 0.945
#   Probability std: 0.074
#   Probability median: 0.950
#
# MORTALITY:
#   Total samples: 300/300
#   Positive labels: 30
#   Valid predictions: 300
#   Positive predictions: 300.0
#   Probability range: [0.700, 0.950]
#   Probability mean: 0.916
#   Probability std: 0.041
#   Probability median: 0.900
#
# SEPSIS:
#   Total samples: 2939/2939
#   Positive labels: 145
#   Valid predictions: 2939
#   Positive predictions: 1946.0
#   Probability range: [0.050, 0.990]
#   Probability mean: 0.650
#   Probability std: 0.398
#   Probability median: 0.950
#
# Data types and unique values:
#   Target Label: int64, values: [0 1]
#   Predicted Diagnosis: object, values: ['not-aki' 'aki' 'not-mortality' 'mortality' 'sepsis' 'not-sepsis']
#
# Data source information:
#   • Predictions from explicit prediction column
#   • Tasks: aki, mortality, sepsis
#   • Datasets: eicu, hirid, miiv
#
# ✅ PULSE scores calculated successfully for Mistral!
# PULSE SCORE DETAILED REPORT
# Model Type: LLM
# Weights: AUPRC=0.33, AUROC=0.33, MCC=0.34
#
# OVERALL SCORES
# --------------------------------------------------
#               Metric      Value
# 0      overall_score  24.093618
# 1        overall_aki  22.045999
# 2       overall_eicu  24.136193
# 3  overall_mortality  25.720220
# 4      overall_hirid  23.983644
# 5     overall_sepsis  24.514636
# 6       overall_miiv  24.161018
#
# TASK DATASET SCORES
# --------------------------------------------------
#                  pulse_score     auprc     auroc       mcc       ccf
# aki_eicu           22.824352  0.210515  0.430329  0.500000  0.598313
# aki_hirid          22.621333  0.160229  0.443507  0.500000  0.612658
# aki_miiv           20.692313  0.221966  0.378429  0.485855  0.569533
# mortality_eicu     27.111388  0.468054  0.493088  0.500000  0.556500
# mortality_hirid    24.964264  0.271955  0.507150  0.500000  0.584500
# mortality_miiv     25.085008  0.168905  0.356534  0.500000  0.730500
# sepsis_eicu        22.472839  0.031499  0.412203  0.472546  0.731806
# sepsis_hirid       24.365336  0.114182  0.414942  0.467330  0.730588
# sepsis_miiv        26.705733  0.045274  0.504580  0.500000  0.759869
# ==================================================
#
# Prompting Approach zhu_2024b_zero_shot_preprocessor
#
# Extracting metadata from files:
# Model Name: Mistral, Task: aki, Dataset: eicu, Timestamp: 20250620_114127
# Model Name: Mistral, Task: aki, Dataset: hirid, Timestamp: 20250620_114127
# Model Name: Mistral, Task: aki, Dataset: miiv, Timestamp: 20250620_114127
# Model Name: Mistral, Task: mortality, Dataset: eicu, Timestamp: 20250620_114127
# Model Name: Mistral, Task: mortality, Dataset: hirid, Timestamp: 20250620_114127
# Model Name: Mistral, Task: mortality, Dataset: miiv, Timestamp: 20250620_114127
# Model Name: Mistral, Task: sepsis, Dataset: eicu, Timestamp: 20250620_114127
# Model Name: Mistral, Task: sepsis, Dataset: hirid, Timestamp: 20250620_114127
# Model Name: Mistral, Task: sepsis, Dataset: miiv, Timestamp: 20250620_114127
#
# =====Overall=====:
# Number of Samples: 6189
# Number of Requests: 6189
# Total Input Tokens: 28478149
# Total Output Tokens: 793772
# Total Thinking Tokens: 0
# Average Thinking Tokens: 0.00
# Total Cost (USD): $0.00
# =================
# Preparing data for Mistral PULSE score calculation...
# Model Type: LLM
# ✓ No invalid predictions detected
# ✅ Data format is correct for PULSE calculation!
#
# Data distribution by task:
#
# AKI:
#   Total samples: 2950/2950
#   Positive labels: 693
#   Valid predictions: 2950
#   Positive predictions: 2950.0
#   Probability range: [0.750, 0.990]
#   Probability mean: 0.943
#   Probability std: 0.082
#   Probability median: 0.990
#
# MORTALITY:
#   Total samples: 300/300
#   Positive labels: 30
#   Valid predictions: 300
#   Positive predictions: 300.0
#   Probability range: [0.850, 0.950]
#   Probability mean: 0.913
#   Probability std: 0.042
#   Probability median: 0.950
#
# SEPSIS:
#   Total samples: 2939/2939
#   Positive labels: 145
#   Valid predictions: 2939
#   Positive predictions: 61.0
#   Probability range: [0.120, 0.990]
#   Probability mean: 0.137
#   Probability std: 0.114
#   Probability median: 0.120
#
# Data types and unique values:
#   Target Label: int64, values: [0 1]
#   Predicted Diagnosis: object, values: ['not-aki' 'aki' 'not-mortality' 'mortality' 'not-sepsis' 'sepsis']
#
# Data source information:
#   • Predictions from explicit prediction column
#   • Tasks: aki, mortality, sepsis
#   • Datasets: eicu, hirid, miiv
#
# ✅ PULSE scores calculated successfully for Mistral!
# PULSE SCORE DETAILED REPORT
# Model Type: LLM
# Weights: AUPRC=0.33, AUROC=0.33, MCC=0.34
#
# OVERALL SCORES
# --------------------------------------------------
#               Metric      Value
# 0      overall_score  30.339512
# 1        overall_aki  27.752757
# 2       overall_eicu  29.347459
# 3  overall_mortality  26.032704
# 4      overall_hirid  33.392474
# 5     overall_sepsis  37.233076
# 6       overall_miiv  28.278603
#
# TASK DATASET SCORES
# --------------------------------------------------
#                  pulse_score     auprc     auroc       mcc       ccf
# aki_eicu           27.865182  0.557937  0.496255  0.500000  0.538059
# aki_hirid          29.399102  0.250692  0.451791  0.500000  0.731650
# aki_miiv           25.993986  0.479958  0.452283  0.500000  0.544217
# mortality_eicu     23.574596  0.259908  0.404762  0.500000  0.605500
# mortality_hirid    28.587156  0.352354  0.501021  0.500000  0.633000
# mortality_miiv     25.936360  0.296870  0.453598  0.500000  0.621000
# sepsis_eicu        36.602600  0.084343  0.507332  0.508584  0.994173
# sepsis_hirid       42.191165  0.189450  0.522314  0.551331  0.998999
# sepsis_miiv        32.905462  0.012626  0.490155  0.488742  0.990859
# ==================================================
#
# Prompting Approach zhu_2024c_categorization_summary_agent_preprocessor
#
# Extracting metadata from files:
# Model Name: Mistral, Task: aki, Dataset: eicu, Timestamp: 20250625_122103
# Model Name: Mistral, Task: aki, Dataset: hirid, Timestamp: 20250625_122103
# Model Name: Mistral, Task: aki, Dataset: miiv, Timestamp: 20250625_122103
# Model Name: Mistral, Task: mortality, Dataset: eicu, Timestamp: 20250625_122103
# Model Name: Mistral, Task: mortality, Dataset: hirid, Timestamp: 20250625_122103
# Model Name: Mistral, Task: mortality, Dataset: miiv, Timestamp: 20250625_122103
# Model Name: Mistral, Task: sepsis, Dataset: eicu, Timestamp: 20250625_122103
# Model Name: Mistral, Task: sepsis, Dataset: hirid, Timestamp: 20250625_122103
# Model Name: Mistral, Task: sepsis, Dataset: miiv, Timestamp: 20250625_122103
#
# =====Overall=====:
# Number of Samples: 6189
# Number of Requests: 12378
# Total Input Tokens: 7874797
# Total Output Tokens: 2665752
# Total Thinking Tokens: 0
# Average Thinking Tokens: 0.00
# Total Cost (USD): $0.00
# =================
# Preparing data for Mistral PULSE score calculation...
# Model Type: LLM
#
# ⚠️ Wrongly labled predictions: 3187
# Wrongly labeled predictions:
#   - possible-sepsis: 1227 occurrences
#   - possibly-sepsis: 715 occurrences
#   - possible-aki: 460 occurrences
#   - aki_risk: 245 occurrences
#   - aki_possible: 223 occurrences
#   - aki-risk: 92 occurrences
#   - suspected-sepsis: 73 occurrences
#   - potential-sepsis: 34 occurrences
#   - aki_suspected: 29 occurrences
#   - possibly-aki: 27 occurrences
#   - aki-possible: 21 occurrences
#   - monitor: 14 occurrences
#   - aki-suspected: 14 occurrences
#   - potential-risk: 5 occurrences
#   - high-risk-for-sepsis: 3 occurrences
#   - high-risk: 2 occurrences
#   - aki_risk_elevated: 1 occurrences
#   - aki-suspect: 1 occurrences
#   - increased-risk: 1 occurrences
# ✅ Data format is correct for PULSE calculation!
#
# Data distribution by task:
#
# AKI:
#   Total samples: 2950/2950
#   Positive labels: 693
#   Valid predictions: 2950
#   Positive predictions: 1529.0
#   Probability range: [0.050, 0.950]
#   Probability mean: 0.461
#   Probability std: 0.247
#   Probability median: 0.600
#
# MORTALITY:
#   Total samples: 300/300
#   Positive labels: 30
#   Valid predictions: 300
#   Positive predictions: 300.0
#   Probability range: [0.750, 0.850]
#   Probability mean: 0.820
#   Probability std: 0.046
#   Probability median: 0.850
#
# SEPSIS:
#   Total samples: 2939/2939
#   Positive labels: 145
#   Valid predictions: 2939
#   Positive predictions: 2189.0
#   Probability range: [0.100, 0.950]
#   Probability mean: 0.546
#   Probability std: 0.203
#   Probability median: 0.650
#
# Data types and unique values:
#   Target Label: int64, values: [0 1]
#   Predicted Diagnosis: object, values: ['aki_possible' 'possible-aki' 'aki' 'not-aki' 'aki_risk' 'aki-risk'
#  'aki_suspected' 'possibly-aki' 'aki-suspected' 'aki-possible'
#  'aki_risk_elevated' 'aki-suspect' 'monitor' 'mortality' 'high-risk'
#  'possible-sepsis' 'not-sepsis' 'possibly-sepsis' 'sepsis'
#  'suspected-sepsis' 'potential-sepsis' 'increased-risk'
#  'high-risk-for-sepsis' 'potential-risk']
#
# Data source information:
#   • Predictions from explicit prediction column
#   • Tasks: aki, mortality, sepsis
#   • Datasets: eicu, hirid, miiv
#
# ✅ PULSE scores calculated successfully for Mistral!
# PULSE SCORE DETAILED REPORT
# Model Type: LLM
# Weights: AUPRC=0.33, AUROC=0.33, MCC=0.34
#
# OVERALL SCORES
# --------------------------------------------------
#               Metric      Value
# 0      overall_score  38.726171
# 1        overall_aki  37.689325
# 2       overall_eicu  39.468172
# 3  overall_mortality  54.622926
# 4      overall_hirid  37.033012
# 5     overall_sepsis  23.866262
# 6       overall_miiv  39.677330
#
# TASK DATASET SCORES
# --------------------------------------------------
#                  pulse_score     auprc     auroc       mcc       ccf
# aki_eicu           39.991391  0.365909  0.593515  0.565533  0.785854
# aki_hirid          33.664181  0.193414  0.533812  0.508780  0.815173
# aki_miiv           39.412403  0.321491  0.567697  0.541696  0.825203
# mortality_eicu     59.231821  0.559322  0.720430  0.500000  1.000000
# mortality_hirid    50.666873  0.515101  0.505107  0.500000  1.000000
# mortality_miiv     53.970084  0.507312  0.621212  0.500000  0.995000
# sepsis_eicu        19.181303  0.031684  0.376126  0.462017  0.657653
# sepsis_hirid       26.767981  0.171948  0.596303  0.501912  0.631063
# sepsis_miiv        25.649502  0.026381  0.605513  0.529542  0.660101
#                clinical_workflow_agent_preprocessor  \
# input_cost                                      0.0
# output_cost                                     0.0
# thinking_cost                                   0.0
# total_cost                                      0.0
#
#                collaborative_reasoning_agent_preprocessor  \
# input_cost                                            0.0
# output_cost                                           0.0
# thinking_cost                                         0.0
# total_cost                                            0.0
#
#                hybrid_reasoning_agent_preprocessor  \
# input_cost                                     0.0
# output_cost                                    0.0
# thinking_cost                                  0.0
# total_cost                                     0.0
#
#                liu_2023_few_shot_preprocessor  \
# input_cost                                0.0
# output_cost                               0.0
# thinking_cost                             0.0
# total_cost                                0.0
#
#                sarvari_2024_aggregation_preprocessor  \
# input_cost                                       0.0
# output_cost                                      0.0
# thinking_cost                                    0.0
# total_cost                                       0.0
#
#                zhu_2024a_cot_preprocessor  zhu_2024b_one_shot_preprocessor  \
# input_cost                            0.0                              0.0
# output_cost                           0.0                              0.0
# thinking_cost                         0.0                              0.0
# total_cost                            0.0                              0.0
#
#                zhu_2024b_zero_shot_preprocessor  \
# input_cost                                  0.0
# output_cost                                 0.0
# thinking_cost                               0.0
# total_cost                                  0.0
#
#                zhu_2024c_categorization_summary_agent_preprocessor
# input_cost                                                   0.0
# output_cost                                                  0.0
# thinking_cost                                                0.0
# total_cost                                                   0.0
# Best prompt approach: collaborative_reasoning_agent_preprocessor with PULSE score: 41.139791614546
# Saved 81 result entries to C:\Users\janbe\OneDrive\Dokumente\GitRepos\pulse\output_to_keep\results_benchmark\results_output\jsons\mistral7b_results.json

# %% [markdown]
# ## Model Metrics

# %%
df_results = LLMAnalyzer.load_metrics_from_prompt_approaches(model_output_dir, prompt_approaches)

# %%
LLMAnalyzer.plot_metrics(
    df_results, group=["prompting_id"], title_prefix="Mistral 7B - "
)
# Out:
# C:\Users\janbe\OneDrive\Dokumente\GitRepos\pulse\src\eval\llm_analyzer.py:1162: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   agg_df = plot_df.groupby(["Group", "Metric"], as_index=False).agg(

# %%
LLMAnalyzer.plot_metrics(
    df_results, group=["task_id", "prompting_id"], title_prefix="Mistral 7B - "
)
# Out:
# C:\Users\janbe\OneDrive\Dokumente\GitRepos\pulse\src\eval\llm_analyzer.py:1162: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   agg_df = plot_df.groupby(["Group", "Metric"], as_index=False).agg(
